# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing
import sklearn
import os
from datetime import datetime, timedelta
from tqdm import tqdm

import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LSTM, GRU, Bidirectional, Dense, Dropout, Input, TimeDistributed, LeakyReLU, BatchNormalization
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau,TensorBoard
# Out:
# /home/sprkzoff/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/sprkzoff/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/sprkzoff/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/sprkzoff/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/sprkzoff/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/sprkzoff/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/sprkzoff/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/sprkzoff/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/sprkzoff/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/sprkzoff/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/sprkzoff/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/sprkzoff/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
os.listdir('./data/')
# Out:
# ['DJI_ema.csv',
#  'DJI_STO_20period_sma10.csv',
#  'DJI_modified_sma.csv',
#  '.DS_Store',
#  'DJI_modified_features - DJI.csv',
#  'nk_fe.csv',
#  'DJI_fe.csv',
#  'N225withoutNULL.csv',
#  'dowjone1985_2019.csv',
#  'N225fillVOL.csv',
#  'test_djia.csv',
#  'DJI_denoise.csv',
#  'N225.csv',
#  'stocknews',
#  'preprocessed',
#  'downjone5y.csv']

# %%
df_nikkei = pd.read_csv('./data/N225withoutNULL.csv')
df_djia = pd.read_csv('./data/DJI_modified_sma.csv')

# %%
df_nikkei.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  1985-01-29  11843.070313  11843.070313  11843.070313  11843.070313
# 1  1985-01-30  11960.629883  11960.629883  11960.629883  11960.629883
# 2  1985-01-31  11992.309570  11992.309570  11992.309570  11992.309570
# 3  1985-02-01  11946.959961  11946.959961  11946.959961  11946.959961
# 4  1985-02-04  11891.080078  11891.080078  11891.080078  11891.080078
#
#       Adj Close  Volume
# 0  11843.070313       0
# 1  11960.629883       0
# 2  11992.309570       0
# 3  11946.959961       0
# 4  11891.080078       0

# %%
df_djia['Date'][0]
# Out:
# '1985-01-29'

# %% [markdown]
# # Preprocess

# %%
# postpone 1 day and concatenate both table

# decrement datetime of djia first
df_djia_dc = df_djia.copy()
# df_djia_dc['Date'] = df_djia['Date'] + timedelta(days=-1)
for i in tqdm(range(len(df_djia))):
    df_djia_dc['Date'][i] = str((datetime.strptime(df_djia.iloc[i]['Date'], '%Y-%m-%d') + timedelta(days=-1)).date())

# df_djia_dc.head()
df = pd.merge(df_nikkei, df_djia_dc, on='Date', how='inner')
df = df.rename({'Open_x': 'Open(Nikkei)', 'High_x': 'High(Nikkei)', 'Low_x': 'Low(Nikkei)', 'Close_x': 'Close(Nikkei)',
                'Open_y': 'Open(DJIA)', 'High_y': 'High(DJIA)', 'Low_y': 'Low(DJIA)', 'Close_y': 'Close(DJIA)'
               }, axis=1)
# Out:
#   0%|          | 0/8762 [00:00<?, ?it/s]/usr/lib/python3/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# 100%|██████████| 8762/8762 [00:21<00:00, 409.20it/s]

# %%
df.head()
# Out:
#          Date  Open(Nikkei)  High(Nikkei)   Low(Nikkei)  Close(Nikkei)  \
# 0  1985-01-29  11843.070313  11843.070313  11843.070313   11843.070313
# 1  1985-01-30  11960.629883  11960.629883  11960.629883   11960.629883
# 2  1985-01-31  11992.309570  11992.309570  11992.309570   11992.309570
# 3  1985-02-04  11891.080078  11891.080078  11891.080078   11891.080078
# 4  1985-02-05  11823.429688  11823.429688  11823.429688   11823.429688
#
#     Adj Close_x  Volume_x   Open(DJIA)   High(DJIA)    Low(DJIA)  Close(DJIA)  \
# 0  11843.070313         0  1297.369995  1305.099976  1278.930054  1287.880005
# 1  11960.629883         0  1283.239990  1293.400024  1272.640015  1286.770020
# 2  11992.309570         0  1276.939941  1286.109985  1269.770020  1277.719971
# 3  11891.080078         0  1294.060059  1301.130005  1278.599976  1285.229980
# 4  11823.429688         0  1284.890015  1294.500000  1275.069946  1280.589966
#
#    Adj Close_y  Volume_y         sma5        sma10        sma25        sma75  \
# 0  1287.880005  16820000  1287.880005  1287.880005  1287.880005  1287.880005
# 1  1286.770020  14070000  1286.770020  1286.770020  1286.770020  1286.770020
# 2  1277.719971  10980000  1277.719971  1277.719971  1277.719971  1277.719971
# 3  1285.229980  13800000  1285.535986  1285.229980  1285.229980  1285.229980
# 4  1280.589966  14610000  1284.077979  1280.589966  1280.589966  1280.589966
#
#         sma125       sma200
# 0  1287.880005  1287.880005
# 1  1286.770020  1286.770020
# 2  1277.719971  1277.719971
# 3  1285.229980  1285.229980
# 4  1280.589966  1280.589966

# %%
event_col = ['Open(Nikkei)', 'High(Nikkei)', 'Low(Nikkei)', 'Close(Nikkei)',
            'Open(DJIA)', 'High(DJIA)', 'Low(DJIA)', 'Close(DJIA)'
            ]
total_col = df.columns
for col in total_col:
    if col not in event_col:
        df = df.drop(col, axis=1)

# %%
df.tail()
# Out:
#       Open(Nikkei)  High(Nikkei)   Low(Nikkei)  Close(Nikkei)   Open(DJIA)  \
# 6906  22619.769531  22648.810547  22457.890625   22625.380859  26893.92969
# 6907  22725.439453  22780.990234  22704.330078   22750.599609  26789.60938
# 6908  22854.439453  22896.220703  22830.570313   22867.269531  27061.07031
# 6909  22950.789063  23008.429688  22935.349609   22974.130859  27110.71094
# 6910  22953.169922  22961.230469  22827.929688   22843.119141  27188.36914
#
#        High(DJIA)    Low(DJIA)  Close(DJIA)
# 6906  26931.77930  26714.33984  26805.52930
# 6907  27015.36914  26765.67969  26958.06055
# 6908  27165.93945  27039.75977  27071.46094
# 6909  27204.35938  26999.64063  27186.68945
# 6910  27188.36914  26918.28906  27046.23047

# %%
def normalize_data(df, event_col):
    min_max_scaler = sklearn.preprocessing.MinMaxScaler()
    for col in event_col:
        if col != 'Date':
            df[col] = min_max_scaler.fit_transform(df[col].to_numpy().reshape(-1, 1))
    return df

def load_data(stock, seq_len):
    data_raw = stock.as_matrix()
    data = list()
    for index in range(len(data_raw) - seq_len):
        data.append(data_raw[index: index+seq_len])
    data = np.array(data)
    val_set_size = int(np.round(val_set_size_percentage/100*data.shape[0]))
    test_set_size = int(np.round(test_set_size_percentage/100*data.shape[0]))
    train_set_size = data.shape[0] - (val_set_size + test_set_size)
    
    x_train = data[:train_set_size, :-1, :]
    y_train = data[:train_set_size, -1, :]
    
    x_val = data[train_set_size:train_set_size + val_set_size, :-1, :]
    y_val = data[train_set_size:train_set_size + val_set_size, -1, :]
    
    x_test = data[train_set_size+val_set_size:,:-1,:]
    y_test = data[train_set_size+val_set_size:,-1,:]
    
    return [x_train, y_train, x_val, y_val, x_test, y_test]

# %%
# parameter for preprocessing #

val_set_size_percentage = 10
test_set_size_percentage = 10
seq_len = 20

#*****************************#

# normalize index
df_norm = normalize_data(df, event_col)

# split train, val, test data

x_train, y_train, x_val, y_val, x_test, y_test = load_data(df_norm, seq_len)

print('x_train.shape = ', x_train.shape)
print('y_train.shape = ', y_train.shape)
print('x_val.shape = ', x_val.shape)
print('y_val.shape = ', y_val.shape)
print('x_test.shape = ', x_test.shape)
print('y_test.shape = ', y_test.shape)
# Out:
# x_train.shape =  (5513, 19, 8)
# y_train.shape =  (5513, 8)
# x_val.shape =  (689, 19, 8)
# y_val.shape =  (689, 8)
# x_test.shape =  (689, 19, 8)
# y_test.shape =  (689, 8)
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
# plot graph before train

# !set color in graph
# color_palette = ...
plt.figure(figsize=(15, 10))
plt.grid()
color_palette = plt.get_cmap('Set1')
for i, col in enumerate(event_col):
    plt.plot(df_norm[col], color=color_palette(i), label=col)
plt.title('Stock price')
plt.xlabel('Time [days]')
plt.ylabel('Normalized price / volume')
plt.legend()
plt.show()

# %%
start = 0
for i in range(df.shape[0]) :
    if df.loc[i]['Close(DJIA)'] >= df.loc[i]['Close(Nikkei)'] :
        start = i
        break
print(start)
df_2 = df[start:]
df_2
# Out:
# 2638
#       Open(Nikkei)  High(Nikkei)  Low(Nikkei)  Close(Nikkei)  Open(DJIA)  \
# 2638      0.258003      0.256758     0.237947       0.243070    0.252139
# 2639      0.258003      0.256758     0.237947       0.243070    0.247315
# 2640      0.247327      0.270863     0.249590       0.258785    0.246054
# 2641      0.243875      0.243346     0.235396       0.242311    0.251280
# 2642      0.244138      0.256102     0.246399       0.257487    0.255874
# ...            ...           ...          ...            ...         ...
# 6906      0.488358      0.488062     0.485756       0.488699    0.983626
# 6907      0.491674      0.492212     0.493498       0.492630    0.979626
# 6908      0.495723      0.495829     0.497464       0.496292    0.990036
# 6909      0.498747      0.499351     0.500755       0.499646    0.991939
# 6910      0.498822      0.497869     0.497381       0.495534    0.994917
#
#       High(DJIA)  Low(DJIA)  Close(DJIA)
# 2638    0.251625   0.248385     0.247049
# 2639    0.248459   0.247263     0.245836
# 2640    0.247600   0.247225     0.246570
# 2641    0.255440   0.252319     0.255637
# 2642    0.256852   0.255978     0.255342
# ...          ...        ...          ...
# 6906    0.983267   0.980601     0.979176
# 6907    0.986467   0.982577     0.985018
# 6908    0.992232   0.993125     0.989362
# 6909    0.993703   0.991581     0.993776
# 6910    0.993091   0.988450     0.988396
#
# [4273 rows x 8 columns]

# %%
# plot graph after 2 graph sync

# !set color in graph
# color_palette = ...
plt.figure(figsize=(15, 10))
plt.grid()
color_palette = plt.get_cmap('Set1')
plt.plot(df_2['Close(DJIA)'],color='magenta')
plt.plot(df_2['Close(Nikkei)'],color='purple')

# %%
# parameter for preprocessing #

val_set_size_percentage = 10
test_set_size_percentage = 10
seq_len = 20

#*****************************#

# normalize index
df_2_norm = normalize_data(df_2, event_col)

# split train, val, test data

x2_train, y2_train, x2_val, y2_val, x2_test, y2_test = load_data(df_2_norm, seq_len)

print('x_train.shape = ', x2_train.shape)
print('y_train.shape = ', y2_train.shape)
print('x_val.shape = ', x2_val.shape)
print('y_val.shape = ', y2_val.shape)
print('x_test.shape = ', x2_test.shape)
print('y_test.shape = ', y2_test.shape)
# Out:
# x_train.shape =  (3403, 19, 8)
# y_train.shape =  (3403, 8)
# x_val.shape =  (425, 19, 8)
# y_val.shape =  (425, 8)
# x_test.shape =  (425, 19, 8)
# y_test.shape =  (425, 8)
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
df_2_norm
# Out:
#       Open(Nikkei)  High(Nikkei)  Low(Nikkei)  Close(Nikkei)  Open(DJIA)  \
# 2638      0.474720      0.471511     0.439808       0.449848    0.061221
# 2639      0.474720      0.471511     0.439808       0.449848    0.055165
# 2640      0.455077      0.497415     0.461328       0.478932    0.053581
# 2641      0.448725      0.446881     0.435092       0.448443    0.060142
# 2642      0.449209      0.470308     0.455429       0.476530    0.065909
# ...            ...           ...          ...            ...         ...
# 6906      0.898570      0.896280     0.897844       0.904434    0.979446
# 6907      0.904672      0.903900     0.912153       0.911707    0.974425
# 6908      0.912122      0.910542     0.919483       0.918484    0.987492
# 6909      0.917686      0.917011     0.925567       0.924691    0.989882
# 6910      0.917824      0.914290     0.919330       0.917081    0.993620
#
#       High(DJIA)  Low(DJIA)  Close(DJIA)
# 2638    0.051805   0.058767     0.052873
# 2639    0.047793   0.057362     0.051347
# 2640    0.046705   0.057315     0.052270
# 2641    0.056639   0.063694     0.063675
# 2642    0.058427   0.068276     0.063304
# ...          ...        ...          ...
# 6906    0.978799   0.975707     0.973806
# 6907    0.982854   0.978181     0.981155
# 6908    0.990158   0.991391     0.986619
# 6909    0.992022   0.989458     0.992170
# 6910    0.991247   0.985537     0.985403
#
# [4273 rows x 8 columns]

# %% [markdown]
# # Training

# %%
# hyperparameter 
batch_size = 1000
epochs = 500

# set up callback_list
weight_path_model = "saved_model/model_djia_support_nikkei_sync_period_V2.h5"
tensorboard_path = 'Graph/djia_support_nikkei_sync_period_V2'
callbacks_list_model = [
    TensorBoard(log_dir=tensorboard_path),
    ModelCheckpoint(
            weight_path_model,
            save_best_only=True,
            save_weights_only=True,
            monitor='val_loss',
            mode='min',
            verbose=2
        ),
    ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=3, min_lr=1e-9)
]

# %%
K.clear_session()

def get_bi_gru():
    
    input1 = Input(shape=(19,8,))
    x = GRU(256,return_sequences=True,kernel_initializer='Orthogonal')(input1)
    x = TimeDistributed(LeakyReLU())(x)
    x = TimeDistributed(BatchNormalization())(x)
    x = GRU(128,kernel_initializer='Orthogonal')(x)
    x =(LeakyReLU())(x)
    x = (BatchNormalization())(x)
    x = (Dropout(0.25))(x)
    out = Dense(8,kernel_initializer='he_normal')(x)

    
    
    model = Model(inputs=input1, outputs=out)
    model.compile(optimizer=Adam(lr=1e-2, decay=1e-2),
                loss='mse',
                metrics=['mse'])   
    
    return model

model = get_bi_gru()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 19, 8)]           0
# _________________________________________________________________
# gru (GRU)                    (None, 19, 256)           203520
# _________________________________________________________________
# time_distributed (TimeDistri (None, 19, 256)           0
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 19, 256)           1024
# _________________________________________________________________
# gru_1 (GRU)                  (None, 128)               147840
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 8)                 1032
# =================================================================
# Total params: 353,928
# Trainable params: 353,160
# Non-trainable params: 768
# _________________________________________________________________

# %% [markdown]
# # Experiment and Result

# %%
history = model.fit(x_train, y_train, epochs=epochs , callbacks=callbacks_list_model,
          validation_data=(x_val, y_val),batch_size=batch_size)
# Out:
# Train on 5513 samples, validate on 689 samples
# WARNING:tensorflow:From /home/sprkzoff/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/500
# 5000/5513 [==========================>...] - ETA: 1s - loss: 3.0930 - mean_squared_error: 3.0930
# Epoch 00001: val_loss improved from inf to 0.14129, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 14s 3ms/sample - loss: 2.8852 - mean_squared_error: 2.8851 - val_loss: 0.1413 - val_mean_squared_error: 0.1413
# Epoch 2/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.6921 - mean_squared_error: 0.6921
# Epoch 00002: val_loss did not improve from 0.14129
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.6829 - mean_squared_error: 0.6829 - val_loss: 0.2918 - val_mean_squared_error: 0.2918
# Epoch 3/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.6990 - mean_squared_error: 0.6990
# Epoch 00003: val_loss did not improve from 0.14129
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.6946 - mean_squared_error: 0.6946 - val_loss: 0.1908 - val_mean_squared_error: 0.1908
# Epoch 4/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.5784 - mean_squared_error: 0.5784
# Epoch 00004: val_loss improved from 0.14129 to 0.12748, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.5702 - mean_squared_error: 0.5702 - val_loss: 0.1275 - val_mean_squared_error: 0.1275
# Epoch 5/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.4519 - mean_squared_error: 0.4519
# Epoch 00005: val_loss improved from 0.12748 to 0.12426, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.4490 - mean_squared_error: 0.4490 - val_loss: 0.1243 - val_mean_squared_error: 0.1243
# Epoch 6/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.4091 - mean_squared_error: 0.4091
# Epoch 00006: val_loss improved from 0.12426 to 0.11470, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.4074 - mean_squared_error: 0.4074 - val_loss: 0.1147 - val_mean_squared_error: 0.1147
# Epoch 7/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.3569 - mean_squared_error: 0.3569
# Epoch 00007: val_loss improved from 0.11470 to 0.09082, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.3552 - mean_squared_error: 0.3552 - val_loss: 0.0908 - val_mean_squared_error: 0.0908
# Epoch 8/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.3139 - mean_squared_error: 0.3139
# Epoch 00008: val_loss improved from 0.09082 to 0.06873, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.3142 - mean_squared_error: 0.3142 - val_loss: 0.0687 - val_mean_squared_error: 0.0687
# Epoch 9/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.2825 - mean_squared_error: 0.2825
# Epoch 00009: val_loss improved from 0.06873 to 0.06482, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.2809 - mean_squared_error: 0.2809 - val_loss: 0.0648 - val_mean_squared_error: 0.0648
# Epoch 10/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.2572 - mean_squared_error: 0.2572
# Epoch 00010: val_loss improved from 0.06482 to 0.06029, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.2560 - mean_squared_error: 0.2560 - val_loss: 0.0603 - val_mean_squared_error: 0.0603
# Epoch 11/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.2316 - mean_squared_error: 0.2316
# Epoch 00011: val_loss improved from 0.06029 to 0.05555, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.2304 - mean_squared_error: 0.2304 - val_loss: 0.0555 - val_mean_squared_error: 0.0555
# Epoch 12/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.2139 - mean_squared_error: 0.2139
# Epoch 00012: val_loss improved from 0.05555 to 0.05433, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.2130 - mean_squared_error: 0.2130 - val_loss: 0.0543 - val_mean_squared_error: 0.0543
# Epoch 13/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.1963 - mean_squared_error: 0.1963
# Epoch 00013: val_loss improved from 0.05433 to 0.04927, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.1956 - mean_squared_error: 0.1956 - val_loss: 0.0493 - val_mean_squared_error: 0.0493
# Epoch 14/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.1793 - mean_squared_error: 0.1793
# Epoch 00014: val_loss improved from 0.04927 to 0.04852, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.1784 - mean_squared_error: 0.1784 - val_loss: 0.0485 - val_mean_squared_error: 0.0485
# Epoch 15/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.1660 - mean_squared_error: 0.1660
# Epoch 00015: val_loss improved from 0.04852 to 0.04599, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.1654 - mean_squared_error: 0.1654 - val_loss: 0.0460 - val_mean_squared_error: 0.0460
# Epoch 16/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.1541 - mean_squared_error: 0.1541
# Epoch 00016: val_loss did not improve from 0.04599
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.1536 - mean_squared_error: 0.1536 - val_loss: 0.0471 - val_mean_squared_error: 0.0471
# Epoch 17/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.1430 - mean_squared_error: 0.1430
# Epoch 00017: val_loss improved from 0.04599 to 0.04582, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.1422 - mean_squared_error: 0.1422 - val_loss: 0.0458 - val_mean_squared_error: 0.0458
# Epoch 18/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.1333 - mean_squared_error: 0.1333
# Epoch 00018: val_loss did not improve from 0.04582
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.1327 - mean_squared_error: 0.1327 - val_loss: 0.0484 - val_mean_squared_error: 0.0484
# Epoch 19/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.1244 - mean_squared_error: 0.1244
# Epoch 00019: val_loss did not improve from 0.04582
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.1237 - mean_squared_error: 0.1237 - val_loss: 0.0489 - val_mean_squared_error: 0.0489
# Epoch 20/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.1162 - mean_squared_error: 0.1162
# Epoch 00020: val_loss did not improve from 0.04582
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.1159 - mean_squared_error: 0.1159 - val_loss: 0.0483 - val_mean_squared_error: 0.0483
# Epoch 21/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.1074 - mean_squared_error: 0.1074
# Epoch 00021: val_loss improved from 0.04582 to 0.04579, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.1070 - mean_squared_error: 0.1070 - val_loss: 0.0458 - val_mean_squared_error: 0.0458
# Epoch 22/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.1019 - mean_squared_error: 0.1019
# Epoch 00022: val_loss improved from 0.04579 to 0.04422, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.1011 - mean_squared_error: 0.1011 - val_loss: 0.0442 - val_mean_squared_error: 0.0442
# Epoch 23/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0959 - mean_squared_error: 0.0959
# Epoch 00023: val_loss improved from 0.04422 to 0.04421, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0959 - mean_squared_error: 0.0959 - val_loss: 0.0442 - val_mean_squared_error: 0.0442
# Epoch 24/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0905 - mean_squared_error: 0.0905
# Epoch 00024: val_loss did not improve from 0.04421
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0904 - mean_squared_error: 0.0904 - val_loss: 0.0460 - val_mean_squared_error: 0.0460
# Epoch 25/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0838 - mean_squared_error: 0.0838
# Epoch 00025: val_loss did not improve from 0.04421
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0836 - mean_squared_error: 0.0836 - val_loss: 0.0460 - val_mean_squared_error: 0.0460
# Epoch 26/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0803 - mean_squared_error: 0.0803
# Epoch 00026: val_loss did not improve from 0.04421
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0805 - mean_squared_error: 0.0805 - val_loss: 0.0461 - val_mean_squared_error: 0.0461
# Epoch 27/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0771 - mean_squared_error: 0.0771
# Epoch 00027: val_loss did not improve from 0.04421
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0771 - mean_squared_error: 0.0771 - val_loss: 0.0447 - val_mean_squared_error: 0.0447
# Epoch 28/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0734 - mean_squared_error: 0.0734
# Epoch 00028: val_loss did not improve from 0.04421
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0734 - mean_squared_error: 0.0734 - val_loss: 0.0450 - val_mean_squared_error: 0.0450
# Epoch 29/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0711 - mean_squared_error: 0.0711
# Epoch 00029: val_loss did not improve from 0.04421
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0710 - mean_squared_error: 0.0710 - val_loss: 0.0462 - val_mean_squared_error: 0.0462
# Epoch 30/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0674 - mean_squared_error: 0.0674
# Epoch 00030: val_loss did not improve from 0.04421
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0672 - mean_squared_error: 0.0672 - val_loss: 0.0457 - val_mean_squared_error: 0.0457
# Epoch 31/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0664 - mean_squared_error: 0.0664
# Epoch 00031: val_loss did not improve from 0.04421
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0660 - mean_squared_error: 0.0660 - val_loss: 0.0465 - val_mean_squared_error: 0.0465
# Epoch 32/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0627 - mean_squared_error: 0.0627
# Epoch 00032: val_loss did not improve from 0.04421
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0628 - mean_squared_error: 0.0628 - val_loss: 0.0484 - val_mean_squared_error: 0.0484
# Epoch 33/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0610 - mean_squared_error: 0.0610
# Epoch 00033: val_loss did not improve from 0.04421
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0609 - mean_squared_error: 0.0609 - val_loss: 0.0479 - val_mean_squared_error: 0.0479
# Epoch 34/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0590 - mean_squared_error: 0.0590
# Epoch 00034: val_loss did not improve from 0.04421
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0588 - mean_squared_error: 0.0588 - val_loss: 0.0470 - val_mean_squared_error: 0.0470
# Epoch 35/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0582 - mean_squared_error: 0.0582
# Epoch 00035: val_loss did not improve from 0.04421
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0580 - mean_squared_error: 0.0580 - val_loss: 0.0485 - val_mean_squared_error: 0.0485
# Epoch 36/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0553 - mean_squared_error: 0.0553
# Epoch 00036: val_loss did not improve from 0.04421
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0551 - mean_squared_error: 0.0551 - val_loss: 0.0494 - val_mean_squared_error: 0.0494
# Epoch 37/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0537 - mean_squared_error: 0.0537
# Epoch 00037: val_loss did not improve from 0.04421
# 5513/5513 [==============================] - 6s 1ms/sample - loss: 0.0538 - mean_squared_error: 0.0538 - val_loss: 0.0490 - val_mean_squared_error: 0.0490
# Epoch 38/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0527 - mean_squared_error: 0.0527
# Epoch 00038: val_loss did not improve from 0.04421
# 5513/5513 [==============================] - 6s 1ms/sample - loss: 0.0526 - mean_squared_error: 0.0526 - val_loss: 0.0485 - val_mean_squared_error: 0.0485
# Epoch 39/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0511 - mean_squared_error: 0.0511
# Epoch 00039: val_loss did not improve from 0.04421
# 5513/5513 [==============================] - 6s 1ms/sample - loss: 0.0510 - mean_squared_error: 0.0510 - val_loss: 0.0484 - val_mean_squared_error: 0.0484
# Epoch 40/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0498 - mean_squared_error: 0.0498
# Epoch 00040: val_loss did not improve from 0.04421
# 5513/5513 [==============================] - 6s 1ms/sample - loss: 0.0500 - mean_squared_error: 0.0500 - val_loss: 0.0477 - val_mean_squared_error: 0.0477
# Epoch 41/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0491 - mean_squared_error: 0.0491
# Epoch 00041: val_loss did not improve from 0.04421
# 5513/5513 [==============================] - 6s 1ms/sample - loss: 0.0488 - mean_squared_error: 0.0488 - val_loss: 0.0468 - val_mean_squared_error: 0.0468
# Epoch 42/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0472 - mean_squared_error: 0.0472
# Epoch 00042: val_loss did not improve from 0.04421
# 5513/5513 [==============================] - 6s 1ms/sample - loss: 0.0471 - mean_squared_error: 0.0471 - val_loss: 0.0464 - val_mean_squared_error: 0.0464
# Epoch 43/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0464 - mean_squared_error: 0.0464
# Epoch 00043: val_loss did not improve from 0.04421
# 5513/5513 [==============================] - 6s 1ms/sample - loss: 0.0466 - mean_squared_error: 0.0466 - val_loss: 0.0448 - val_mean_squared_error: 0.0448
# Epoch 44/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0456 - mean_squared_error: 0.0456
# Epoch 00044: val_loss improved from 0.04421 to 0.04378, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 6s 1ms/sample - loss: 0.0456 - mean_squared_error: 0.0456 - val_loss: 0.0438 - val_mean_squared_error: 0.0438
# Epoch 45/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0455 - mean_squared_error: 0.0455
# Epoch 00045: val_loss improved from 0.04378 to 0.04300, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 5s 959us/sample - loss: 0.0454 - mean_squared_error: 0.0454 - val_loss: 0.0430 - val_mean_squared_error: 0.0430
# Epoch 46/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0438 - mean_squared_error: 0.0438
# Epoch 00046: val_loss improved from 0.04300 to 0.04205, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 5s 963us/sample - loss: 0.0440 - mean_squared_error: 0.0440 - val_loss: 0.0420 - val_mean_squared_error: 0.0420
# Epoch 47/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0437 - mean_squared_error: 0.0437
# Epoch 00047: val_loss improved from 0.04205 to 0.04104, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0439 - mean_squared_error: 0.0439 - val_loss: 0.0410 - val_mean_squared_error: 0.0410
# Epoch 48/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0424 - mean_squared_error: 0.0424
# Epoch 00048: val_loss improved from 0.04104 to 0.03973, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0424 - mean_squared_error: 0.0424 - val_loss: 0.0397 - val_mean_squared_error: 0.0397
# Epoch 49/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0411 - mean_squared_error: 0.0411
# Epoch 00049: val_loss improved from 0.03973 to 0.03869, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0410 - mean_squared_error: 0.0410 - val_loss: 0.0387 - val_mean_squared_error: 0.0387
# Epoch 50/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0411 - mean_squared_error: 0.0411
# Epoch 00050: val_loss did not improve from 0.03869
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0411 - mean_squared_error: 0.0411 - val_loss: 0.0389 - val_mean_squared_error: 0.0389
# Epoch 51/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0404 - mean_squared_error: 0.0404
# Epoch 00051: val_loss improved from 0.03869 to 0.03861, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0403 - mean_squared_error: 0.0403 - val_loss: 0.0386 - val_mean_squared_error: 0.0386
# Epoch 52/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0391 - mean_squared_error: 0.0391
# Epoch 00052: val_loss improved from 0.03861 to 0.03617, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0391 - mean_squared_error: 0.0391 - val_loss: 0.0362 - val_mean_squared_error: 0.0362
# Epoch 53/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0399 - mean_squared_error: 0.0399
# Epoch 00053: val_loss improved from 0.03617 to 0.03524, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0397 - mean_squared_error: 0.0397 - val_loss: 0.0352 - val_mean_squared_error: 0.0352
# Epoch 54/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0381 - mean_squared_error: 0.0381
# Epoch 00054: val_loss did not improve from 0.03524
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0382 - mean_squared_error: 0.0382 - val_loss: 0.0353 - val_mean_squared_error: 0.0353
# Epoch 55/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0378 - mean_squared_error: 0.0378
# Epoch 00055: val_loss did not improve from 0.03524
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0375 - mean_squared_error: 0.0375 - val_loss: 0.0356 - val_mean_squared_error: 0.0356
# Epoch 56/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0373 - mean_squared_error: 0.0373
# Epoch 00056: val_loss improved from 0.03524 to 0.03450, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0371 - mean_squared_error: 0.0371 - val_loss: 0.0345 - val_mean_squared_error: 0.0345
# Epoch 57/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0363 - mean_squared_error: 0.0363
# Epoch 00057: val_loss improved from 0.03450 to 0.03430, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0364 - mean_squared_error: 0.0364 - val_loss: 0.0343 - val_mean_squared_error: 0.0343
# Epoch 58/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0361 - mean_squared_error: 0.0361
# Epoch 00058: val_loss improved from 0.03430 to 0.03330, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0360 - mean_squared_error: 0.0360 - val_loss: 0.0333 - val_mean_squared_error: 0.0333
# Epoch 59/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0349 - mean_squared_error: 0.0349
# Epoch 00059: val_loss improved from 0.03330 to 0.03296, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0350 - mean_squared_error: 0.0350 - val_loss: 0.0330 - val_mean_squared_error: 0.0330
# Epoch 60/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0350 - mean_squared_error: 0.0350
# Epoch 00060: val_loss improved from 0.03296 to 0.03266, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0350 - mean_squared_error: 0.0350 - val_loss: 0.0327 - val_mean_squared_error: 0.0327
# Epoch 61/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0348 - mean_squared_error: 0.0348
# Epoch 00061: val_loss improved from 0.03266 to 0.03088, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0347 - mean_squared_error: 0.0347 - val_loss: 0.0309 - val_mean_squared_error: 0.0309
# Epoch 62/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0342 - mean_squared_error: 0.0342
# Epoch 00062: val_loss improved from 0.03088 to 0.03082, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0339 - mean_squared_error: 0.0339 - val_loss: 0.0308 - val_mean_squared_error: 0.0308
# Epoch 63/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0329 - mean_squared_error: 0.0329
# Epoch 00063: val_loss did not improve from 0.03082
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0330 - mean_squared_error: 0.0330 - val_loss: 0.0309 - val_mean_squared_error: 0.0309
# Epoch 64/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0324 - mean_squared_error: 0.0324
# Epoch 00064: val_loss improved from 0.03082 to 0.03033, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0324 - mean_squared_error: 0.0324 - val_loss: 0.0303 - val_mean_squared_error: 0.0303
# Epoch 65/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0322 - mean_squared_error: 0.0322
# Epoch 00065: val_loss improved from 0.03033 to 0.02919, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0321 - mean_squared_error: 0.0321 - val_loss: 0.0292 - val_mean_squared_error: 0.0292
# Epoch 66/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0319 - mean_squared_error: 0.0319
# Epoch 00066: val_loss improved from 0.02919 to 0.02889, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0320 - mean_squared_error: 0.0320 - val_loss: 0.0289 - val_mean_squared_error: 0.0289
# Epoch 67/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0312 - mean_squared_error: 0.0312
# Epoch 00067: val_loss improved from 0.02889 to 0.02838, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0311 - mean_squared_error: 0.0311 - val_loss: 0.0284 - val_mean_squared_error: 0.0284
# Epoch 68/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0309 - mean_squared_error: 0.0309
# Epoch 00068: val_loss improved from 0.02838 to 0.02766, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0308 - mean_squared_error: 0.0308 - val_loss: 0.0277 - val_mean_squared_error: 0.0277
# Epoch 69/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0302 - mean_squared_error: 0.0302
# Epoch 00069: val_loss improved from 0.02766 to 0.02757, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0301 - mean_squared_error: 0.0301 - val_loss: 0.0276 - val_mean_squared_error: 0.0276
# Epoch 70/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0298 - mean_squared_error: 0.0298
# Epoch 00070: val_loss improved from 0.02757 to 0.02636, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0297 - mean_squared_error: 0.0297 - val_loss: 0.0264 - val_mean_squared_error: 0.0264
# Epoch 71/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0290 - mean_squared_error: 0.0290
# Epoch 00071: val_loss improved from 0.02636 to 0.02570, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0291 - mean_squared_error: 0.0291 - val_loss: 0.0257 - val_mean_squared_error: 0.0257
# Epoch 72/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0289 - mean_squared_error: 0.0289
# Epoch 00072: val_loss improved from 0.02570 to 0.02526, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0288 - mean_squared_error: 0.0288 - val_loss: 0.0253 - val_mean_squared_error: 0.0253
# Epoch 73/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0282 - mean_squared_error: 0.0282
# Epoch 00073: val_loss improved from 0.02526 to 0.02459, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.0246 - val_mean_squared_error: 0.0246
# Epoch 74/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0283 - mean_squared_error: 0.0283
# Epoch 00074: val_loss improved from 0.02459 to 0.02415, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0283 - mean_squared_error: 0.0283 - val_loss: 0.0241 - val_mean_squared_error: 0.0241
# Epoch 75/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0275 - mean_squared_error: 0.0275
# Epoch 00075: val_loss improved from 0.02415 to 0.02329, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0273 - mean_squared_error: 0.0273 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
# Epoch 76/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0277 - mean_squared_error: 0.0277
# Epoch 00076: val_loss improved from 0.02329 to 0.02298, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0276 - mean_squared_error: 0.0276 - val_loss: 0.0230 - val_mean_squared_error: 0.0230
# Epoch 77/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0274 - mean_squared_error: 0.0274
# Epoch 00077: val_loss improved from 0.02298 to 0.02248, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0274 - mean_squared_error: 0.0274 - val_loss: 0.0225 - val_mean_squared_error: 0.0225
# Epoch 78/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0269 - mean_squared_error: 0.0269
# Epoch 00078: val_loss improved from 0.02248 to 0.02152, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0270 - mean_squared_error: 0.0270 - val_loss: 0.0215 - val_mean_squared_error: 0.0215
# Epoch 79/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0262 - mean_squared_error: 0.0262
# Epoch 00079: val_loss improved from 0.02152 to 0.02144, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0262 - mean_squared_error: 0.0262 - val_loss: 0.0214 - val_mean_squared_error: 0.0214
# Epoch 80/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0263 - mean_squared_error: 0.0263
# Epoch 00080: val_loss improved from 0.02144 to 0.02067, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0262 - mean_squared_error: 0.0262 - val_loss: 0.0207 - val_mean_squared_error: 0.0207
# Epoch 81/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0258 - mean_squared_error: 0.0258
# Epoch 00081: val_loss improved from 0.02067 to 0.02032, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0257 - mean_squared_error: 0.0257 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 82/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0254 - mean_squared_error: 0.0254
# Epoch 00082: val_loss improved from 0.02032 to 0.02024, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0254 - mean_squared_error: 0.0254 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 83/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0253 - mean_squared_error: 0.0253
# Epoch 00083: val_loss improved from 0.02024 to 0.01969, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0253 - mean_squared_error: 0.0253 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 84/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0247 - mean_squared_error: 0.0247
# Epoch 00084: val_loss improved from 0.01969 to 0.01867, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0247 - mean_squared_error: 0.0247 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 85/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0238 - mean_squared_error: 0.0238
# Epoch 00085: val_loss improved from 0.01867 to 0.01832, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0240 - mean_squared_error: 0.0240 - val_loss: 0.0183 - val_mean_squared_error: 0.0183
# Epoch 86/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0243 - mean_squared_error: 0.0243
# Epoch 00086: val_loss improved from 0.01832 to 0.01800, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0244 - mean_squared_error: 0.0244 - val_loss: 0.0180 - val_mean_squared_error: 0.0180
# Epoch 87/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0236 - mean_squared_error: 0.0236
# Epoch 00087: val_loss improved from 0.01800 to 0.01745, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0237 - mean_squared_error: 0.0237 - val_loss: 0.0174 - val_mean_squared_error: 0.0174
# Epoch 88/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0231 - mean_squared_error: 0.0231
# Epoch 00088: val_loss improved from 0.01745 to 0.01708, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 89/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0231 - mean_squared_error: 0.0231
# Epoch 00089: val_loss did not improve from 0.01708
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 90/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0225 - mean_squared_error: 0.0225
# Epoch 00090: val_loss improved from 0.01708 to 0.01637, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0164 - val_mean_squared_error: 0.0164
# Epoch 91/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0224 - mean_squared_error: 0.0224
# Epoch 00091: val_loss improved from 0.01637 to 0.01608, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 2ms/sample - loss: 0.0223 - mean_squared_error: 0.0223 - val_loss: 0.0161 - val_mean_squared_error: 0.0161
# Epoch 92/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0218 - mean_squared_error: 0.0218
# Epoch 00092: val_loss improved from 0.01608 to 0.01546, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0218 - mean_squared_error: 0.0218 - val_loss: 0.0155 - val_mean_squared_error: 0.0155
# Epoch 93/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0216 - mean_squared_error: 0.0216
# Epoch 00093: val_loss improved from 0.01546 to 0.01516, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0215 - mean_squared_error: 0.0215 - val_loss: 0.0152 - val_mean_squared_error: 0.0152
# Epoch 94/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0215 - mean_squared_error: 0.0215
# Epoch 00094: val_loss did not improve from 0.01516
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0215 - mean_squared_error: 0.0215 - val_loss: 0.0153 - val_mean_squared_error: 0.0153
# Epoch 95/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0212 - mean_squared_error: 0.0212
# Epoch 00095: val_loss improved from 0.01516 to 0.01461, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0211 - mean_squared_error: 0.0211 - val_loss: 0.0146 - val_mean_squared_error: 0.0146
# Epoch 96/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0212 - mean_squared_error: 0.0212
# Epoch 00096: val_loss improved from 0.01461 to 0.01461, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0212 - mean_squared_error: 0.0212 - val_loss: 0.0146 - val_mean_squared_error: 0.0146
# Epoch 97/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0209 - mean_squared_error: 0.0209
# Epoch 00097: val_loss did not improve from 0.01461
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0209 - mean_squared_error: 0.0209 - val_loss: 0.0147 - val_mean_squared_error: 0.0147
# Epoch 98/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0207 - mean_squared_error: 0.0207
# Epoch 00098: val_loss improved from 0.01461 to 0.01401, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0207 - mean_squared_error: 0.0207 - val_loss: 0.0140 - val_mean_squared_error: 0.0140
# Epoch 99/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0201 - mean_squared_error: 0.0201
# Epoch 00099: val_loss improved from 0.01401 to 0.01356, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0202 - mean_squared_error: 0.0202 - val_loss: 0.0136 - val_mean_squared_error: 0.0136
# Epoch 100/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0199 - mean_squared_error: 0.0199
# Epoch 00100: val_loss did not improve from 0.01356
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0200 - mean_squared_error: 0.0200 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
# Epoch 101/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0199 - mean_squared_error: 0.0199
# Epoch 00101: val_loss did not improve from 0.01356
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0198 - mean_squared_error: 0.0198 - val_loss: 0.0136 - val_mean_squared_error: 0.0136
# Epoch 102/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0196 - mean_squared_error: 0.0196
# Epoch 00102: val_loss improved from 0.01356 to 0.01305, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0195 - mean_squared_error: 0.0195 - val_loss: 0.0131 - val_mean_squared_error: 0.0131
# Epoch 103/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0193 - mean_squared_error: 0.0193
# Epoch 00103: val_loss did not improve from 0.01305
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0194 - mean_squared_error: 0.0194 - val_loss: 0.0131 - val_mean_squared_error: 0.0131
# Epoch 104/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0191 - mean_squared_error: 0.0191
# Epoch 00104: val_loss improved from 0.01305 to 0.01289, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0129 - val_mean_squared_error: 0.0129
# Epoch 105/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0187 - mean_squared_error: 0.0187
# Epoch 00105: val_loss improved from 0.01289 to 0.01253, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0187 - mean_squared_error: 0.0187 - val_loss: 0.0125 - val_mean_squared_error: 0.0125
# Epoch 106/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0185 - mean_squared_error: 0.0185
# Epoch 00106: val_loss improved from 0.01253 to 0.01248, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.0125 - val_mean_squared_error: 0.0125
# Epoch 107/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0183 - mean_squared_error: 0.0183
# Epoch 00107: val_loss improved from 0.01248 to 0.01235, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 2ms/sample - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0124 - val_mean_squared_error: 0.0124
# Epoch 108/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0178 - mean_squared_error: 0.0178
# Epoch 00108: val_loss did not improve from 0.01235
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0124 - val_mean_squared_error: 0.0124
# Epoch 109/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0184 - mean_squared_error: 0.0184
# Epoch 00109: val_loss did not improve from 0.01235
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0124 - val_mean_squared_error: 0.0124
# Epoch 110/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0178 - mean_squared_error: 0.0178
# Epoch 00110: val_loss did not improve from 0.01235
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.0124 - val_mean_squared_error: 0.0124
# Epoch 111/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0176 - mean_squared_error: 0.0176
# Epoch 00111: val_loss did not improve from 0.01235
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0124 - val_mean_squared_error: 0.0124
# Epoch 112/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0174 - mean_squared_error: 0.0174
# Epoch 00112: val_loss improved from 0.01235 to 0.01213, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0121 - val_mean_squared_error: 0.0121
# Epoch 113/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0176 - mean_squared_error: 0.0176
# Epoch 00113: val_loss improved from 0.01213 to 0.01194, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0119 - val_mean_squared_error: 0.0119
# Epoch 114/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0174 - mean_squared_error: 0.0174
# Epoch 00114: val_loss did not improve from 0.01194
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0123 - val_mean_squared_error: 0.0123
# Epoch 115/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0173 - mean_squared_error: 0.0173
# Epoch 00115: val_loss improved from 0.01194 to 0.01190, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0119 - val_mean_squared_error: 0.0119
# Epoch 116/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0169 - mean_squared_error: 0.0169
# Epoch 00116: val_loss improved from 0.01190 to 0.01174, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 117/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0160 - mean_squared_error: 0.0160
# Epoch 00117: val_loss did not improve from 0.01174
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0121 - val_mean_squared_error: 0.0121
# Epoch 118/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0165 - mean_squared_error: 0.0165
# Epoch 00118: val_loss did not improve from 0.01174
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0120 - val_mean_squared_error: 0.0120
# Epoch 119/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0164 - mean_squared_error: 0.0164
# Epoch 00119: val_loss improved from 0.01174 to 0.01157, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 120/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0162 - mean_squared_error: 0.0162
# Epoch 00120: val_loss improved from 0.01157 to 0.01132, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0113 - val_mean_squared_error: 0.0113
# Epoch 121/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0159 - mean_squared_error: 0.0159
# Epoch 00121: val_loss improved from 0.01132 to 0.01085, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0109 - val_mean_squared_error: 0.0109
# Epoch 122/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0158 - mean_squared_error: 0.0158
# Epoch 00122: val_loss did not improve from 0.01085
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0111 - val_mean_squared_error: 0.0111
# Epoch 123/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0157 - mean_squared_error: 0.0157
# Epoch 00123: val_loss did not improve from 0.01085
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0110 - val_mean_squared_error: 0.0110
# Epoch 124/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0156 - mean_squared_error: 0.0156
# Epoch 00124: val_loss did not improve from 0.01085
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0109 - val_mean_squared_error: 0.0109
# Epoch 125/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0155 - mean_squared_error: 0.0155
# Epoch 00125: val_loss did not improve from 0.01085
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0111 - val_mean_squared_error: 0.0111
# Epoch 126/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0154 - mean_squared_error: 0.0154
# Epoch 00126: val_loss did not improve from 0.01085
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0111 - val_mean_squared_error: 0.0111
# Epoch 127/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0149 - mean_squared_error: 0.0149
# Epoch 00127: val_loss did not improve from 0.01085
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0111 - val_mean_squared_error: 0.0111
# Epoch 128/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0150 - mean_squared_error: 0.0150
# Epoch 00128: val_loss improved from 0.01085 to 0.01069, saving model to saved_model/model_djia_support_nikkei_sync_period_V2.h5
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0107 - val_mean_squared_error: 0.0107
# Epoch 129/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0148 - mean_squared_error: 0.0148
# Epoch 00129: val_loss did not improve from 0.01069
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0108 - val_mean_squared_error: 0.0108
# Epoch 130/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0148 - mean_squared_error: 0.0148
# Epoch 00130: val_loss did not improve from 0.01069
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0109 - val_mean_squared_error: 0.0109
# Epoch 131/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0144 - mean_squared_error: 0.0144
# Epoch 00131: val_loss did not improve from 0.01069
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0107 - val_mean_squared_error: 0.0107
# Epoch 132/500
# ...
# Epoch 451/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0113 - mean_squared_error: 0.0113
# Epoch 00451: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 452/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 00452: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 453/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0119 - mean_squared_error: 0.0119
# Epoch 00453: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 454/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 00454: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 455/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 00455: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 456/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 00456: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 457/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 00457: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 458/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 00458: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 459/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 00459: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 460/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 00460: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 461/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 00461: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 462/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 00462: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 463/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0114 - mean_squared_error: 0.0114
# Epoch 00463: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 464/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0119 - mean_squared_error: 0.0119
# Epoch 00464: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 465/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0120 - mean_squared_error: 0.0120
# Epoch 00465: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 466/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 00466: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 467/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 00467: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 468/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0119 - mean_squared_error: 0.0119
# Epoch 00468: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 469/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 00469: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 470/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 00470: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 471/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 00471: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 472/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 00472: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 473/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 00473: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 474/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0117 - mean_squared_error: 0.0117
# Epoch 00474: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 475/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0119 - mean_squared_error: 0.0119
# Epoch 00475: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 476/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 00476: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 477/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0117 - mean_squared_error: 0.0117
# Epoch 00477: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 478/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0114 - mean_squared_error: 0.0114
# Epoch 00478: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 479/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0119 - mean_squared_error: 0.0119
# Epoch 00479: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 480/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0117 - mean_squared_error: 0.0117
# Epoch 00480: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 481/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 00481: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 482/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 00482: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 483/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 00483: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 484/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0117 - mean_squared_error: 0.0117
# Epoch 00484: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 485/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 00485: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 486/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 00486: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 487/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0119 - mean_squared_error: 0.0119
# Epoch 00487: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 488/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 00488: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 489/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 00489: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 490/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 00490: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 491/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 00491: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 492/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 00492: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 493/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0117 - mean_squared_error: 0.0117
# Epoch 00493: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 494/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 00494: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 495/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 00495: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 7s 1ms/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 496/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 00496: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 497/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 00497: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 498/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 00498: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 499/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 00499: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 500/500
# 5000/5513 [==========================>...] - ETA: 0s - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 00500: val_loss did not improve from 0.01021
# 5513/5513 [==============================] - 8s 1ms/sample - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0102 - val_mean_squared_error: 0.0102

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'mean_squared_error', 'val_loss', 'val_mean_squared_error', 'lr'])

# %%
plt.title("Loss (MSE)")
plt.plot(history.history['loss'],color = 'blue',label="train_loss")
plt.plot(history.history['val_loss'],color = 'red',label="val_loss")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.legend()
plt.savefig('loss_support_sync_data2.png')

# %%
y_train_pred = model.predict(x_train)
y_val_pred = model.predict(x_val)
y_test_pred = model.predict(x_test)

# %%
#fix!
def plot_compare(x, event_col):
#     Col = {'Open':0, 'High':1, 'Low':2, 'Close':3}
    Col = dict()
    count = 0
    for i, col in enumerate(event_col):
        Col[col] = i
    ft = Col[x]
    plt.figure(figsize=(15, 5))
    plt.subplot(1, 2, 1)

    plt.plot(np.arange(y_train.shape[0]), y_train[:, ft], color='blue', label='train target')

    plt.plot(np.arange(y_train.shape[0], y_train.shape[0] + y_val.shape[0]), y_val[:, ft], 
             color='gray', label='val target')
    plt.plot(np.arange(y_train.shape[0] + y_val.shape[0], y_train.shape[0] + y_val.shape[0] + y_test.shape[0]),
            y_test[:, ft], color='black', label='test target')
    plt.plot(np.arange(y_train_pred.shape[0]), y_train_pred[:, ft],
            color='red', label='train prediction') 
    plt.plot(np.arange(y_train_pred.shape[0], y_train_pred.shape[0] + y_val_pred.shape[0]),
            y_val_pred[:, ft], color='orange', label='val prediction')
    plt.plot(np.arange(y_train_pred.shape[0] + y_val_pred.shape[0],
            y_train_pred.shape[0] + y_val_pred.shape[0] + y_test_pred.shape[0]),
            y_test_pred[:, ft], color ='green', label='test prediction')
    plt.title('past and future stock price :' + x)
    plt.xlabel('Time [Days]')
    plt.ylabel('Normalized price')
    plt.legend(loc='best')

    plt.subplot(1, 2, 2)
    plt.plot(np.arange(y_train.shape[0], y_train.shape[0] + y_test.shape[0]),
            y_test[:, ft], color='black', label='test target')
    plt.plot(np.arange(y_train.shape[0], y_train.shape[0] + y_test_pred.shape[0]),
            y_test_pred[:, ft], color='green', label='test prediction')
    plt.title('future stock prices :' + x)
    plt.xlabel('Time [Days]')
    plt.ylabel('Normalized price')
    plt.legend(loc='best')

# %%
plot_compare('Close(Nikkei)', event_col)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-80aa5ffb69ad> in <module>()
# ----> 1 plot_compare('Close(Nikkei)', event_col)
#
# <ipython-input-23-2069d5f9ffba> in plot_compare(x, event_col)
#      20     plt.plot(np.arange(y_train_pred.shape[0], y_train_pred.shape[0] + y_val_pred.shape[0]),
#      21             y_val_pred[:, ft], color='orange', label='val prediction')
# ---> 22     plt.plot(np.arange(y2_train_pred.shape[0] + y2_val_pred.shape[0],
#      23             y_train_pred.shape[0] + y_val_pred.shape[0] + y_test_pred.shape[0]),
#      24             y_test_pred[:, ft], color ='green', label='test prediction')
#
# NameError: name 'y2_train_pred' is not defined

# %%
model.evaluate(x_test,y_test)
