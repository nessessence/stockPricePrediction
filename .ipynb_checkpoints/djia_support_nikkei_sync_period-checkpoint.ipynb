# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing
import sklearn
import os
from datetime import datetime, timedelta
from tqdm import tqdm

import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LSTM, GRU, Bidirectional, Dense, Dropout, Input, TimeDistributed, LeakyReLU, BatchNormalization
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau,TensorBoard
# Out:
# /home/sprkzoff/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/sprkzoff/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/sprkzoff/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/sprkzoff/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/sprkzoff/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/sprkzoff/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/sprkzoff/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/sprkzoff/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/sprkzoff/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/sprkzoff/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/sprkzoff/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/sprkzoff/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
os.listdir('./data/')
# Out:
# ['DJI_ema.csv',
#  'DJI_STO_20period_sma10.csv',
#  'DJI_modified_sma.csv',
#  '.DS_Store',
#  'DJI_modified_features - DJI.csv',
#  'DJI_fe.csv',
#  'N225withoutNULL.csv',
#  'dowjone1985_2019.csv',
#  'N225fillVOL.csv',
#  'test_djia.csv',
#  'DJI_denoise.csv',
#  'N225.csv',
#  'stocknews',
#  'preprocessed',
#  'downjone5y.csv']

# %%
df_nikkei = pd.read_csv('./data/N225withoutNULL.csv')
df_djia = pd.read_csv('./data/DJI_modified_sma.csv')

# %%
df_nikkei.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  1985-01-29  11843.070313  11843.070313  11843.070313  11843.070313
# 1  1985-01-30  11960.629883  11960.629883  11960.629883  11960.629883
# 2  1985-01-31  11992.309570  11992.309570  11992.309570  11992.309570
# 3  1985-02-01  11946.959961  11946.959961  11946.959961  11946.959961
# 4  1985-02-04  11891.080078  11891.080078  11891.080078  11891.080078
#
#       Adj Close  Volume
# 0  11843.070313       0
# 1  11960.629883       0
# 2  11992.309570       0
# 3  11946.959961       0
# 4  11891.080078       0

# %%
df_djia['Date'][0]
# Out:
# '1985-01-29'

# %% [markdown]
# # Preprocess

# %%
# postpone 1 day and concatenate both table

# decrement datetime of djia first
df_djia_dc = df_djia.copy()
# df_djia_dc['Date'] = df_djia['Date'] + timedelta(days=-1)
for i in tqdm(range(len(df_djia))):
    df_djia_dc['Date'][i] = str((datetime.strptime(df_djia.iloc[i]['Date'], '%Y-%m-%d') + timedelta(days=-1)).date())

# df_djia_dc.head()
df = pd.merge(df_nikkei, df_djia_dc, on='Date', how='inner')
df = df.rename({'Open_x': 'Open(Nikkei)', 'High_x': 'High(Nikkei)', 'Low_x': 'Low(Nikkei)', 'Close_x': 'Close(Nikkei)',
                'Open_y': 'Open(DJIA)', 'High_y': 'High(DJIA)', 'Low_y': 'Low(DJIA)', 'Close_y': 'Close(DJIA)'
               }, axis=1)
# Out:
#   0%|          | 0/8762 [00:00<?, ?it/s]/usr/lib/python3/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# 100%|██████████| 8762/8762 [00:02<00:00, 3528.20it/s]

# %%
df.head()
# Out:
#          Date  Open(Nikkei)  High(Nikkei)   Low(Nikkei)  Close(Nikkei)  \
# 0  1985-01-29  11843.070313  11843.070313  11843.070313   11843.070313
# 1  1985-01-30  11960.629883  11960.629883  11960.629883   11960.629883
# 2  1985-01-31  11992.309570  11992.309570  11992.309570   11992.309570
# 3  1985-02-04  11891.080078  11891.080078  11891.080078   11891.080078
# 4  1985-02-05  11823.429688  11823.429688  11823.429688   11823.429688
#
#     Adj Close_x  Volume_x   Open(DJIA)   High(DJIA)    Low(DJIA)  Close(DJIA)  \
# 0  11843.070313         0  1297.369995  1305.099976  1278.930054  1287.880005
# 1  11960.629883         0  1283.239990  1293.400024  1272.640015  1286.770020
# 2  11992.309570         0  1276.939941  1286.109985  1269.770020  1277.719971
# 3  11891.080078         0  1294.060059  1301.130005  1278.599976  1285.229980
# 4  11823.429688         0  1284.890015  1294.500000  1275.069946  1280.589966
#
#    Adj Close_y  Volume_y         sma5        sma10        sma25        sma75  \
# 0  1287.880005  16820000  1287.880005  1287.880005  1287.880005  1287.880005
# 1  1286.770020  14070000  1286.770020  1286.770020  1286.770020  1286.770020
# 2  1277.719971  10980000  1277.719971  1277.719971  1277.719971  1277.719971
# 3  1285.229980  13800000  1285.535986  1285.229980  1285.229980  1285.229980
# 4  1280.589966  14610000  1284.077979  1280.589966  1280.589966  1280.589966
#
#         sma125       sma200
# 0  1287.880005  1287.880005
# 1  1286.770020  1286.770020
# 2  1277.719971  1277.719971
# 3  1285.229980  1285.229980
# 4  1280.589966  1280.589966

# %%
event_col = ['Open(Nikkei)', 'High(Nikkei)', 'Low(Nikkei)', 'Close(Nikkei)',
            'Open(DJIA)', 'High(DJIA)', 'Low(DJIA)', 'Close(DJIA)'
            ]
total_col = df.columns
for col in total_col:
    if col not in event_col:
        df = df.drop(col, axis=1)

# %%
df.tail()
# Out:
#       Open(Nikkei)  High(Nikkei)   Low(Nikkei)  Close(Nikkei)   Open(DJIA)  \
# 6906  22619.769531  22648.810547  22457.890625   22625.380859  26893.92969
# 6907  22725.439453  22780.990234  22704.330078   22750.599609  26789.60938
# 6908  22854.439453  22896.220703  22830.570313   22867.269531  27061.07031
# 6909  22950.789063  23008.429688  22935.349609   22974.130859  27110.71094
# 6910  22953.169922  22961.230469  22827.929688   22843.119141  27188.36914
#
#        High(DJIA)    Low(DJIA)  Close(DJIA)
# 6906  26931.77930  26714.33984  26805.52930
# 6907  27015.36914  26765.67969  26958.06055
# 6908  27165.93945  27039.75977  27071.46094
# 6909  27204.35938  26999.64063  27186.68945
# 6910  27188.36914  26918.28906  27046.23047

# %%
def normalize_data(df, event_col):
    min_max_scaler = sklearn.preprocessing.MinMaxScaler()
    for col in event_col:
        if col != 'Date':
            df[col] = min_max_scaler.fit_transform(df[col].to_numpy().reshape(-1, 1))
    return df

def load_data(stock, seq_len):
    data_raw = stock.as_matrix()
    data = list()
    for index in range(len(data_raw) - seq_len):
        data.append(data_raw[index: index+seq_len])
    data = np.array(data)
    val_set_size = int(np.round(val_set_size_percentage/100*data.shape[0]))
    test_set_size = int(np.round(test_set_size_percentage/100*data.shape[0]))
    train_set_size = data.shape[0] - (val_set_size + test_set_size)
    
    x_train = data[:train_set_size, :-1, :]
    y_train = data[:train_set_size, -1, :4]
    
    x_val = data[train_set_size:train_set_size + val_set_size, :-1, :]
    y_val = data[train_set_size:train_set_size + val_set_size, -1, :4]
    
    x_test = data[train_set_size+val_set_size:,:-1,:]
    y_test = data[train_set_size+val_set_size:,-1,:4]
    
    return [x_train, y_train, x_val, y_val, x_test, y_test]

# %%
# parameter for preprocessing #

val_set_size_percentage = 10
test_set_size_percentage = 10
seq_len = 20

#*****************************#

# normalize index
df_norm = normalize_data(df, event_col)

# split train, val, test data

x_train, y_train, x_val, y_val, x_test, y_test = load_data(df_norm, seq_len)

print('x_train.shape = ', x_train.shape)
print('y_train.shape = ', y_train.shape)
print('x_val.shape = ', x_val.shape)
print('y_val.shape = ', y_val.shape)
print('x_test.shape = ', x_test.shape)
print('y_test.shape = ', y_test.shape)
# Out:
# x_train.shape =  (5513, 19, 8)
# y_train.shape =  (5513, 8)
# x_val.shape =  (689, 19, 8)
# y_val.shape =  (689, 8)
# x_test.shape =  (689, 19, 8)
# y_test.shape =  (689, 8)
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
# plot graph before train

# !set color in graph
# color_palette = ...
plt.figure(figsize=(15, 10))
plt.grid()
color_palette = plt.get_cmap('Set1')
for i, col in enumerate(event_col):
    plt.plot(df_norm[col], color=color_palette(i), label=col)
plt.title('Stock price')
plt.xlabel('Time [days]')
plt.ylabel('Normalized price / volume')
plt.legend()
plt.show()

# %%
start = 0
for i in range(df.shape[0]) :
    if df.loc[i]['Close(DJIA)'] >= df.loc[i]['Close(Nikkei)'] :
        start = i
        break
print(start)
df_2 = df[start:]
df_2
# Out:
# 2638
#       Open(Nikkei)  High(Nikkei)  Low(Nikkei)  Close(Nikkei)  Open(DJIA)  \
# 2638      0.258003      0.256758     0.237947       0.243070    0.252139
# 2639      0.258003      0.256758     0.237947       0.243070    0.247315
# 2640      0.247327      0.270863     0.249590       0.258785    0.246054
# 2641      0.243875      0.243346     0.235396       0.242311    0.251280
# 2642      0.244138      0.256102     0.246399       0.257487    0.255874
# ...            ...           ...          ...            ...         ...
# 6906      0.488358      0.488062     0.485756       0.488699    0.983626
# 6907      0.491674      0.492212     0.493498       0.492630    0.979626
# 6908      0.495723      0.495829     0.497464       0.496292    0.990036
# 6909      0.498747      0.499351     0.500755       0.499646    0.991939
# 6910      0.498822      0.497869     0.497381       0.495534    0.994917
#
#       High(DJIA)  Low(DJIA)  Close(DJIA)
# 2638    0.251625   0.248385     0.247049
# 2639    0.248459   0.247263     0.245836
# 2640    0.247600   0.247225     0.246570
# 2641    0.255440   0.252319     0.255637
# 2642    0.256852   0.255978     0.255342
# ...          ...        ...          ...
# 6906    0.983267   0.980601     0.979176
# 6907    0.986467   0.982577     0.985018
# 6908    0.992232   0.993125     0.989362
# 6909    0.993703   0.991581     0.993776
# 6910    0.993091   0.988450     0.988396
#
# [4273 rows x 8 columns]

# %%
# plot graph after 2 graph sync

# !set color in graph
# color_palette = ...
plt.figure(figsize=(15, 10))
plt.grid()
color_palette = plt.get_cmap('Set1')
plt.plot(df_2['Close(DJIA)'],color='magenta')
plt.plot(df_2['Close(Nikkei)'],color='purple')

# %%
# parameter for preprocessing #

val_set_size_percentage = 10
test_set_size_percentage = 10
seq_len = 20

#*****************************#

# normalize index
df_2_norm = normalize_data(df_2, event_col)

# split train, val, test data

x2_train, y2_train, x2_val, y2_val, x2_test, y2_test = load_data(df_2_norm, seq_len)

print('x_train.shape = ', x2_train.shape)
print('y_train.shape = ', y2_train.shape)
print('x_val.shape = ', x2_val.shape)
print('y_val.shape = ', y2_val.shape)
print('x_test.shape = ', x2_test.shape)
print('y_test.shape = ', y2_test.shape)
# Out:
# x_train.shape =  (3403, 19, 8)
# y_train.shape =  (3403, 8)
# x_val.shape =  (425, 19, 8)
# y_val.shape =  (425, 8)
# x_test.shape =  (425, 19, 8)
# y_test.shape =  (425, 8)
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
df_2_norm
# Out:
#       Open(Nikkei)  High(Nikkei)  Low(Nikkei)  Close(Nikkei)  Open(DJIA)  \
# 2638      0.474720      0.471511     0.439808       0.449848    0.061221
# 2639      0.474720      0.471511     0.439808       0.449848    0.055165
# 2640      0.455077      0.497415     0.461328       0.478932    0.053581
# 2641      0.448725      0.446881     0.435092       0.448443    0.060142
# 2642      0.449209      0.470308     0.455429       0.476530    0.065909
# ...            ...           ...          ...            ...         ...
# 6906      0.898570      0.896280     0.897844       0.904434    0.979446
# 6907      0.904672      0.903900     0.912153       0.911707    0.974425
# 6908      0.912122      0.910542     0.919483       0.918484    0.987492
# 6909      0.917686      0.917011     0.925567       0.924691    0.989882
# 6910      0.917824      0.914290     0.919330       0.917081    0.993620
#
#       High(DJIA)  Low(DJIA)  Close(DJIA)
# 2638    0.051805   0.058767     0.052873
# 2639    0.047793   0.057362     0.051347
# 2640    0.046705   0.057315     0.052270
# 2641    0.056639   0.063694     0.063675
# 2642    0.058427   0.068276     0.063304
# ...          ...        ...          ...
# 6906    0.978799   0.975707     0.973806
# 6907    0.982854   0.978181     0.981155
# 6908    0.990158   0.991391     0.986619
# 6909    0.992022   0.989458     0.992170
# 6910    0.991247   0.985537     0.985403
#
# [4273 rows x 8 columns]

# %% [markdown]
# # Training

# %%
# hyperparameter 
batch_size = 1000
epochs = 500

# set up callback_list
weight_path_model = "saved_model/model_djia_support_nikkei_sync_period.h5"
tensorboard_path = 'Graph/djia_support_nikkei_sync_period'
callbacks_list_model = [
    TensorBoard(log_dir=tensorboard_path),
    ModelCheckpoint(
            weight_path_model,
            save_best_only=True,
            save_weights_only=True,
            monitor='val_loss',
            mode='min',
            verbose=2
        ),
    ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=3, min_lr=1e-9)
]

# %%
K.clear_session()

def get_bi_gru():
    
    input1 = Input(shape=(19,8,))
    x = Bidirectional(LSTM(256, return_sequences=True,  kernel_initializer='Orthogonal'))(input1)
    x = TimeDistributed(LeakyReLU())(x)
    x = TimeDistributed(BatchNormalization())(x)
    x = GRU(128,kernel_initializer='Orthogonal')(x)
    x =(LeakyReLU())(x)
    x = (BatchNormalization())(x)
    x = (Dropout(0.25))(x)
    out = Dense(8,kernel_initializer='he_normal')(x)

    
    
    model = Model(inputs=input1, outputs=out)
    model.compile(optimizer=Adam(lr=1e-2, decay=1e-2),
                loss='mse',
                metrics=['mse'])   
    
    return model

model = get_bi_gru()
model.summary()
# Out:
# WARNING:tensorflow:From /home/sprkzoff/.local/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:97: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/sprkzoff/.local/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 19, 8)]           0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 19, 512)           542720
# _________________________________________________________________
# time_distributed (TimeDistri (None, 19, 512)           0
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 19, 512)           2048
# _________________________________________________________________
# gru (GRU)                    (None, 128)               246144
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 8)                 1032
# =================================================================
# Total params: 792,456
# Trainable params: 791,176
# Non-trainable params: 1,280
# _________________________________________________________________

# %% [markdown]
# # Experiment and Result

# %%
history = model.fit(x2_train, y2_train, epochs=epochs , callbacks=callbacks_list_model,
          validation_data=(x2_val, y2_val),batch_size=batch_size)
# Out:
# Train on 3403 samples, validate on 425 samples
# WARNING:tensorflow:From /home/sprkzoff/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 4.5127 - mean_squared_error: 4.5127
# Epoch 00001: val_loss improved from inf to 0.36576, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 4s 1ms/sample - loss: 4.1226 - mean_squared_error: 4.1226 - val_loss: 0.3658 - val_mean_squared_error: 0.3658
# Epoch 2/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.4389 - mean_squared_error: 0.4389
# Epoch 00002: val_loss improved from 0.36576 to 0.34864, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 3s 832us/sample - loss: 0.4008 - mean_squared_error: 0.4008 - val_loss: 0.3486 - val_mean_squared_error: 0.3486
# Epoch 3/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0775 - mean_squared_error: 0.0775
# Epoch 00003: val_loss improved from 0.34864 to 0.33951, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 3s 826us/sample - loss: 0.0745 - mean_squared_error: 0.0745 - val_loss: 0.3395 - val_mean_squared_error: 0.3395
# Epoch 4/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0374 - mean_squared_error: 0.0374
# Epoch 00004: val_loss did not improve from 0.33951
# 3403/3403 [==============================] - 3s 831us/sample - loss: 0.0375 - mean_squared_error: 0.0375 - val_loss: 0.4176 - val_mean_squared_error: 0.4176
# Epoch 5/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0185 - mean_squared_error: 0.0185
# Epoch 00005: val_loss did not improve from 0.33951
# 3403/3403 [==============================] - 3s 827us/sample - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.4969 - val_mean_squared_error: 0.4969
# Epoch 6/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 00006: val_loss did not improve from 0.33951
# 3403/3403 [==============================] - 3s 869us/sample - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.5523 - val_mean_squared_error: 0.5523
# Epoch 7/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 00007: val_loss did not improve from 0.33951
# 3403/3403 [==============================] - 3s 1ms/sample - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.5895 - val_mean_squared_error: 0.5895
# Epoch 8/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0080 - mean_squared_error: 0.0080
# Epoch 00008: val_loss did not improve from 0.33951
# 3403/3403 [==============================] - 3s 986us/sample - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.6395 - val_mean_squared_error: 0.6395
# Epoch 9/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0068 - mean_squared_error: 0.0068
# Epoch 00009: val_loss did not improve from 0.33951
# 3403/3403 [==============================] - 3s 945us/sample - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.6779 - val_mean_squared_error: 0.6779
# Epoch 10/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 00010: val_loss did not improve from 0.33951
# 3403/3403 [==============================] - 3s 987us/sample - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.6946 - val_mean_squared_error: 0.6946
# Epoch 11/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 00011: val_loss did not improve from 0.33951
# 3403/3403 [==============================] - 3s 959us/sample - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.7027 - val_mean_squared_error: 0.7027
# Epoch 12/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 00012: val_loss did not improve from 0.33951
# 3403/3403 [==============================] - 3s 1ms/sample - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.6991 - val_mean_squared_error: 0.6991
# Epoch 13/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0052 - mean_squared_error: 0.0052
# Epoch 00013: val_loss did not improve from 0.33951
# 3403/3403 [==============================] - 4s 1ms/sample - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.6778 - val_mean_squared_error: 0.6778
# Epoch 14/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 00014: val_loss did not improve from 0.33951
# 3403/3403 [==============================] - 3s 947us/sample - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.6553 - val_mean_squared_error: 0.6553
# Epoch 15/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 00015: val_loss did not improve from 0.33951
# 3403/3403 [==============================] - 4s 1ms/sample - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.6400 - val_mean_squared_error: 0.6400
# Epoch 16/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 00016: val_loss did not improve from 0.33951
# 3403/3403 [==============================] - 3s 948us/sample - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.6204 - val_mean_squared_error: 0.6204
# Epoch 17/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 00017: val_loss did not improve from 0.33951
# 3403/3403 [==============================] - 3s 989us/sample - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.5840 - val_mean_squared_error: 0.5840
# Epoch 18/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 00018: val_loss did not improve from 0.33951
# 3403/3403 [==============================] - 3s 933us/sample - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.5340 - val_mean_squared_error: 0.5340
# Epoch 19/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0041 - mean_squared_error: 0.0041
# Epoch 00019: val_loss did not improve from 0.33951
# 3403/3403 [==============================] - 3s 956us/sample - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.4733 - val_mean_squared_error: 0.4733
# Epoch 20/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0040 - mean_squared_error: 0.0040
# Epoch 00020: val_loss did not improve from 0.33951
# 3403/3403 [==============================] - 4s 1ms/sample - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.3893 - val_mean_squared_error: 0.3893
# Epoch 21/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0039 - mean_squared_error: 0.0039
# Epoch 00021: val_loss improved from 0.33951 to 0.30865, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 3s 1ms/sample - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.3086 - val_mean_squared_error: 0.3086
# Epoch 22/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0037 - mean_squared_error: 0.0037
# Epoch 00022: val_loss improved from 0.30865 to 0.24121, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 3s 965us/sample - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.2412 - val_mean_squared_error: 0.2412
# Epoch 23/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0036 - mean_squared_error: 0.0036
# Epoch 00023: val_loss improved from 0.24121 to 0.18878, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 3s 998us/sample - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.1888 - val_mean_squared_error: 0.1888
# Epoch 24/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0036 - mean_squared_error: 0.0036
# Epoch 00024: val_loss improved from 0.18878 to 0.15374, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 3s 1ms/sample - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.1537 - val_mean_squared_error: 0.1537
# Epoch 25/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0036 - mean_squared_error: 0.0036
# Epoch 00025: val_loss improved from 0.15374 to 0.13261, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 3s 968us/sample - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.1326 - val_mean_squared_error: 0.1326
# Epoch 26/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0035 - mean_squared_error: 0.0035
# Epoch 00026: val_loss improved from 0.13261 to 0.12207, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 3s 960us/sample - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.1221 - val_mean_squared_error: 0.1221
# Epoch 27/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0034 - mean_squared_error: 0.0034
# Epoch 00027: val_loss improved from 0.12207 to 0.11816, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 4s 1ms/sample - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.1182 - val_mean_squared_error: 0.1182
# Epoch 28/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0034 - mean_squared_error: 0.0034
# Epoch 00028: val_loss did not improve from 0.11816
# 3403/3403 [==============================] - 3s 977us/sample - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.1209 - val_mean_squared_error: 0.1209
# Epoch 29/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0034 - mean_squared_error: 0.0034
# Epoch 00029: val_loss did not improve from 0.11816
# 3403/3403 [==============================] - 4s 1ms/sample - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.1238 - val_mean_squared_error: 0.1238
# Epoch 30/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0033 - mean_squared_error: 0.0033
# Epoch 00030: val_loss did not improve from 0.11816
# 3403/3403 [==============================] - 4s 1ms/sample - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.1264 - val_mean_squared_error: 0.1264
# Epoch 31/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0032 - mean_squared_error: 0.0032
# Epoch 00031: val_loss did not improve from 0.11816
# 3403/3403 [==============================] - 4s 1ms/sample - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.1267 - val_mean_squared_error: 0.1267
# Epoch 32/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0033 - mean_squared_error: 0.0033
# Epoch 00032: val_loss did not improve from 0.11816
# 3403/3403 [==============================] - 4s 1ms/sample - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.1237 - val_mean_squared_error: 0.1237
# Epoch 33/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0032 - mean_squared_error: 0.0032
# Epoch 00033: val_loss did not improve from 0.11816
# 3403/3403 [==============================] - 4s 1ms/sample - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.1203 - val_mean_squared_error: 0.1203
# Epoch 34/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0032 - mean_squared_error: 0.0032
# Epoch 00034: val_loss improved from 0.11816 to 0.11736, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 4s 1ms/sample - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.1174 - val_mean_squared_error: 0.1174
# Epoch 35/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0031 - mean_squared_error: 0.0031
# Epoch 00035: val_loss improved from 0.11736 to 0.11496, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 4s 1ms/sample - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.1150 - val_mean_squared_error: 0.1150
# Epoch 36/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0032 - mean_squared_error: 0.0032
# Epoch 00036: val_loss improved from 0.11496 to 0.11248, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 3s 1ms/sample - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.1125 - val_mean_squared_error: 0.1125
# Epoch 37/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0033 - mean_squared_error: 0.0033
# Epoch 00037: val_loss improved from 0.11248 to 0.11227, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 3s 977us/sample - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.1123 - val_mean_squared_error: 0.1123
# Epoch 38/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0031 - mean_squared_error: 0.0031
# Epoch 00038: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 3s 967us/sample - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.1135 - val_mean_squared_error: 0.1135
# Epoch 39/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0031 - mean_squared_error: 0.0031
# Epoch 00039: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 3s 1ms/sample - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.1156 - val_mean_squared_error: 0.1156
# Epoch 40/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0031 - mean_squared_error: 0.0031
# Epoch 00040: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 3s 980us/sample - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.1186 - val_mean_squared_error: 0.1186
# Epoch 41/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 00041: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 3s 1ms/sample - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.1220 - val_mean_squared_error: 0.1220
# Epoch 42/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0031 - mean_squared_error: 0.0031
# Epoch 00042: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 3s 997us/sample - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.1244 - val_mean_squared_error: 0.1244
# Epoch 43/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0031 - mean_squared_error: 0.0031
# Epoch 00043: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 3s 971us/sample - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.1268 - val_mean_squared_error: 0.1268
# Epoch 44/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0029 - mean_squared_error: 0.0029
# Epoch 00044: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 3s 994us/sample - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.1297 - val_mean_squared_error: 0.1297
# Epoch 45/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 00045: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 3s 959us/sample - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.1328 - val_mean_squared_error: 0.1328
# Epoch 46/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 00046: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 3s 952us/sample - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.1364 - val_mean_squared_error: 0.1364
# Epoch 47/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0029 - mean_squared_error: 0.0029
# Epoch 00047: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 3s 952us/sample - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.1396 - val_mean_squared_error: 0.1396
# Epoch 48/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 00048: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 3s 942us/sample - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.1429 - val_mean_squared_error: 0.1429
# Epoch 49/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 00049: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 3s 941us/sample - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.1458 - val_mean_squared_error: 0.1458
# Epoch 50/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0029 - mean_squared_error: 0.0029
# Epoch 00050: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 3s 964us/sample - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.1484 - val_mean_squared_error: 0.1484
# Epoch 51/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0029 - mean_squared_error: 0.0029
# Epoch 00051: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 3s 977us/sample - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.1507 - val_mean_squared_error: 0.1507
# Epoch 52/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0029 - mean_squared_error: 0.0029
# Epoch 00052: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 3s 986us/sample - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.1526 - val_mean_squared_error: 0.1526
# Epoch 53/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0029 - mean_squared_error: 0.0029
# Epoch 00053: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 3s 934us/sample - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.1540 - val_mean_squared_error: 0.1540
# Epoch 54/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0029 - mean_squared_error: 0.0029
# Epoch 00054: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 3s 1ms/sample - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.1553 - val_mean_squared_error: 0.1553
# Epoch 55/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 00055: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 3s 996us/sample - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.1568 - val_mean_squared_error: 0.1568
# Epoch 56/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 00056: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 3s 995us/sample - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.1586 - val_mean_squared_error: 0.1586
# Epoch 57/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 00057: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 3s 964us/sample - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.1597 - val_mean_squared_error: 0.1597
# Epoch 58/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0029 - mean_squared_error: 0.0029
# Epoch 00058: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 3s 960us/sample - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.1593 - val_mean_squared_error: 0.1593
# Epoch 59/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 00059: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 3s 993us/sample - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.1585 - val_mean_squared_error: 0.1585
# Epoch 60/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 00060: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 4s 1ms/sample - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.1580 - val_mean_squared_error: 0.1580
# Epoch 61/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0029 - mean_squared_error: 0.0029
# Epoch 00061: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 3s 1ms/sample - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.1578 - val_mean_squared_error: 0.1578
# Epoch 62/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0029 - mean_squared_error: 0.0029
# Epoch 00062: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 4s 1ms/sample - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.1573 - val_mean_squared_error: 0.1573
# Epoch 63/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 00063: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 5s 2ms/sample - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.1563 - val_mean_squared_error: 0.1563
# Epoch 64/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 00064: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.1548 - val_mean_squared_error: 0.1548
# Epoch 65/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0029 - mean_squared_error: 0.0029
# Epoch 00065: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.1537 - val_mean_squared_error: 0.1537
# Epoch 66/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 00066: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.1529 - val_mean_squared_error: 0.1529
# Epoch 67/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 00067: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.1525 - val_mean_squared_error: 0.1525
# Epoch 68/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 00068: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.1517 - val_mean_squared_error: 0.1517
# Epoch 69/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00069: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.1510 - val_mean_squared_error: 0.1510
# Epoch 70/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 00070: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.1507 - val_mean_squared_error: 0.1507
# Epoch 71/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0029 - mean_squared_error: 0.0029
# Epoch 00071: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 5s 2ms/sample - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.1501 - val_mean_squared_error: 0.1501
# Epoch 72/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00072: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.1497 - val_mean_squared_error: 0.1497
# Epoch 73/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00073: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.1490 - val_mean_squared_error: 0.1490
# Epoch 74/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00074: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.1476 - val_mean_squared_error: 0.1476
# Epoch 75/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 00075: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.1458 - val_mean_squared_error: 0.1458
# Epoch 76/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 00076: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.1446 - val_mean_squared_error: 0.1446
# Epoch 77/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00077: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.1437 - val_mean_squared_error: 0.1437
# Epoch 78/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 00078: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.1426 - val_mean_squared_error: 0.1426
# Epoch 79/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00079: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.1416 - val_mean_squared_error: 0.1416
# Epoch 80/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00080: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.1398 - val_mean_squared_error: 0.1398
# Epoch 81/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00081: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.1376 - val_mean_squared_error: 0.1376
# Epoch 82/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 00082: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.1361 - val_mean_squared_error: 0.1361
# Epoch 83/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00083: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.1344 - val_mean_squared_error: 0.1344
# Epoch 84/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00084: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.1328 - val_mean_squared_error: 0.1328
# Epoch 85/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00085: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.1308 - val_mean_squared_error: 0.1308
# Epoch 86/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00086: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.1280 - val_mean_squared_error: 0.1280
# Epoch 87/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00087: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.1251 - val_mean_squared_error: 0.1251
# Epoch 88/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 00088: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.1222 - val_mean_squared_error: 0.1222
# Epoch 89/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00089: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.1200 - val_mean_squared_error: 0.1200
# Epoch 90/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00090: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.1183 - val_mean_squared_error: 0.1183
# Epoch 91/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00091: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.1160 - val_mean_squared_error: 0.1160
# Epoch 92/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00092: val_loss did not improve from 0.11227
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.1138 - val_mean_squared_error: 0.1138
# Epoch 93/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00093: val_loss improved from 0.11227 to 0.11187, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.1119 - val_mean_squared_error: 0.1119
# Epoch 94/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 00094: val_loss improved from 0.11187 to 0.11043, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.1104 - val_mean_squared_error: 0.1104
# Epoch 95/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00095: val_loss improved from 0.11043 to 0.10854, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.1085 - val_mean_squared_error: 0.1085
# Epoch 96/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00096: val_loss improved from 0.10854 to 0.10623, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.1062 - val_mean_squared_error: 0.1062
# Epoch 97/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00097: val_loss improved from 0.10623 to 0.10438, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.1044 - val_mean_squared_error: 0.1044
# Epoch 98/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00098: val_loss improved from 0.10438 to 0.10295, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.1030 - val_mean_squared_error: 0.1030
# Epoch 99/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00099: val_loss improved from 0.10295 to 0.10139, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.1014 - val_mean_squared_error: 0.1014
# Epoch 100/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00100: val_loss improved from 0.10139 to 0.09998, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.1000 - val_mean_squared_error: 0.1000
# Epoch 101/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00101: val_loss improved from 0.09998 to 0.09887, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0989 - val_mean_squared_error: 0.0989
# Epoch 102/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00102: val_loss improved from 0.09887 to 0.09780, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0978 - val_mean_squared_error: 0.0978
# Epoch 103/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00103: val_loss improved from 0.09780 to 0.09676, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0968 - val_mean_squared_error: 0.0968
# Epoch 104/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00104: val_loss improved from 0.09676 to 0.09569, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0957 - val_mean_squared_error: 0.0957
# Epoch 105/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00105: val_loss improved from 0.09569 to 0.09463, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0946 - val_mean_squared_error: 0.0946
# Epoch 106/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00106: val_loss improved from 0.09463 to 0.09365, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0937 - val_mean_squared_error: 0.0937
# Epoch 107/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00107: val_loss improved from 0.09365 to 0.09254, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0925 - val_mean_squared_error: 0.0925
# Epoch 108/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00108: val_loss improved from 0.09254 to 0.09157, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0916 - val_mean_squared_error: 0.0916
# Epoch 109/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00109: val_loss improved from 0.09157 to 0.09055, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0905 - val_mean_squared_error: 0.0905
# Epoch 110/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00110: val_loss improved from 0.09055 to 0.08942, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0894 - val_mean_squared_error: 0.0894
# Epoch 111/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00111: val_loss improved from 0.08942 to 0.08854, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0885 - val_mean_squared_error: 0.0885
# Epoch 112/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00112: val_loss improved from 0.08854 to 0.08795, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0879 - val_mean_squared_error: 0.0879
# Epoch 113/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00113: val_loss improved from 0.08795 to 0.08760, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0876 - val_mean_squared_error: 0.0876
# Epoch 114/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00114: val_loss did not improve from 0.08760
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0877 - val_mean_squared_error: 0.0877
# Epoch 115/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00115: val_loss improved from 0.08760 to 0.08733, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0873 - val_mean_squared_error: 0.0873
# Epoch 116/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00116: val_loss improved from 0.08733 to 0.08689, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0869 - val_mean_squared_error: 0.0869
# Epoch 117/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00117: val_loss improved from 0.08689 to 0.08613, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0861 - val_mean_squared_error: 0.0861
# Epoch 118/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00118: val_loss improved from 0.08613 to 0.08523, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0852 - val_mean_squared_error: 0.0852
# Epoch 119/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00119: val_loss improved from 0.08523 to 0.08406, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0841 - val_mean_squared_error: 0.0841
# Epoch 120/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00120: val_loss improved from 0.08406 to 0.08290, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0829 - val_mean_squared_error: 0.0829
# Epoch 121/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00121: val_loss improved from 0.08290 to 0.08157, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0816 - val_mean_squared_error: 0.0816
# Epoch 122/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00122: val_loss improved from 0.08157 to 0.08036, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0804 - val_mean_squared_error: 0.0804
# Epoch 123/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00123: val_loss improved from 0.08036 to 0.07910, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0791 - val_mean_squared_error: 0.0791
# Epoch 124/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00124: val_loss improved from 0.07910 to 0.07805, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0780 - val_mean_squared_error: 0.0780
# Epoch 125/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00125: val_loss improved from 0.07805 to 0.07692, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0769 - val_mean_squared_error: 0.0769
# Epoch 126/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00126: val_loss improved from 0.07692 to 0.07541, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0754 - val_mean_squared_error: 0.0754
# Epoch 127/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00127: val_loss improved from 0.07541 to 0.07382, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0738 - val_mean_squared_error: 0.0738
# Epoch 128/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00128: val_loss improved from 0.07382 to 0.07223, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0722 - val_mean_squared_error: 0.0722
# Epoch 129/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00129: val_loss improved from 0.07223 to 0.07097, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0710 - val_mean_squared_error: 0.0710
# Epoch 130/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00130: val_loss improved from 0.07097 to 0.06951, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0695 - val_mean_squared_error: 0.0695
# Epoch 131/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00131: val_loss improved from 0.06951 to 0.06786, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0679 - val_mean_squared_error: 0.0679
# Epoch 132/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00132: val_loss improved from 0.06786 to 0.06617, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0662 - val_mean_squared_error: 0.0662
# Epoch 133/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00133: val_loss improved from 0.06617 to 0.06445, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0645 - val_mean_squared_error: 0.0645
# Epoch 134/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00134: val_loss improved from 0.06445 to 0.06304, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0630 - val_mean_squared_error: 0.0630
# Epoch 135/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00135: val_loss improved from 0.06304 to 0.06190, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0619 - val_mean_squared_error: 0.0619
# Epoch 136/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00136: val_loss improved from 0.06190 to 0.06082, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# 3403/3403 [==============================] - 6s 2ms/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0608 - val_mean_squared_error: 0.0608
# Epoch 137/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00137: val_loss improved from 0.06082 to 0.05921, saving model to saved_model/model_djia_support_nikkei_sync_period.h5
# ...
# Epoch 451/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00451: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 935us/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 452/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 00452: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 917us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 453/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00453: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 940us/sample - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 454/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00454: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 914us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 455/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00455: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 918us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 456/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00456: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 928us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 457/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00457: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 947us/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 458/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00458: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 926us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 459/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00459: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 919us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 460/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00460: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 915us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 461/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00461: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 914us/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 462/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00462: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 908us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 463/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00463: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 918us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 464/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00464: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 917us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 465/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00465: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 922us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 466/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00466: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 919us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 467/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 00467: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 918us/sample - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 468/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00468: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 909us/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 469/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00469: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 923us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 470/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00470: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 925us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 471/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 00471: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 918us/sample - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 472/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00472: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 912us/sample - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 473/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00473: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 912us/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 474/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00474: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 913us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 475/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 00475: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 912us/sample - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 476/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00476: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 920us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 477/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00477: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 915us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 478/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00478: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 910us/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 479/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 00479: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 909us/sample - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 480/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00480: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 915us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 481/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00481: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 915us/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 482/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00482: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 936us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 483/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00483: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 932us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 484/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00484: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 941us/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 485/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 00485: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 916us/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 486/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00486: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 913us/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 487/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00487: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 916us/sample - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 488/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00488: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 921us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 489/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00489: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 918us/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 490/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00490: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 935us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 491/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00491: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 940us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 492/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00492: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 923us/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 493/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00493: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 925us/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 494/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00494: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 910us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 495/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00495: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 938us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 496/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00496: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 916us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 497/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00497: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 928us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 498/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 00498: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 923us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 499/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 00499: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 920us/sample - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 500/500
# 3000/3403 [=========================>....] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 00500: val_loss did not improve from 0.00216
# 3403/3403 [==============================] - 3s 918us/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0023 - val_mean_squared_error: 0.0023

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'mean_squared_error', 'val_loss', 'val_mean_squared_error', 'lr'])

# %%
plt.title("Loss (MSE)")
plt.plot(history.history['loss'],color = 'blue',label="train_loss")
plt.plot(history.history['val_loss'],color = 'red',label="val_loss")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.legend()
plt.savefig('loss_support_sync_data.png')

# %%
y2_train_pred = model.predict(x2_train)
y2_val_pred = model.predict(x2_val)
y2_test_pred = model.predict(x2_test)

# %%
#fix!
def plot_compare(x, event_col):
#     Col = {'Open':0, 'High':1, 'Low':2, 'Close':3}
    Col = dict()
    count = 0
    for i, col in enumerate(event_col):
        Col[col] = i
    ft = Col[x]
    plt.figure(figsize=(15, 5))
    plt.subplot(1, 2, 1)

    plt.plot(np.arange(y2_train.shape[0]), y2_train[:, ft], color='blue', label='train target')

    plt.plot(np.arange(y2_train.shape[0], y2_train.shape[0] + y2_val.shape[0]), y2_val[:, ft], 
             color='gray', label='val target')
    plt.plot(np.arange(y2_train.shape[0] + y2_val.shape[0], y2_train.shape[0] + y2_val.shape[0] + y2_test.shape[0]),
            y2_test[:, ft], color='black', label='test target')
    plt.plot(np.arange(y2_train_pred.shape[0]), y2_train_pred[:, ft],
            color='red', label='train prediction') 
    plt.plot(np.arange(y2_train_pred.shape[0], y2_train_pred.shape[0] + y2_val_pred.shape[0]),
            y2_val_pred[:, ft], color='orange', label='val prediction')
    plt.plot(np.arange(y2_train_pred.shape[0] + y2_val_pred.shape[0],
            y2_train_pred.shape[0] + y2_val_pred.shape[0] + y2_test_pred.shape[0]),
            y2_test_pred[:, ft], color ='green', label='test prediction')
    plt.title('past and future stock price :' + x)
    plt.xlabel('Time [Days]')
    plt.ylabel('Normalized price')
    plt.legend(loc='best')

    plt.subplot(1, 2, 2)
    plt.plot(np.arange(y2_train.shape[0], y2_train.shape[0] + y2_test.shape[0]),
            y2_test[:, ft], color='black', label='test target')
    plt.plot(np.arange(y2_train.shape[0], y2_train.shape[0] + y2_test_pred.shape[0]),
            y2_test_pred[:, ft], color='green', label='test prediction')
    plt.title('future stock prices :' + x)
    plt.xlabel('Time [Days]')
    plt.ylabel('Normalized price')
    plt.legend(loc='best')

# %%
plot_compare('Close(Nikkei)', event_col)

# %%
model.evaluate(x_test,y_test)
# Out:
# 689/689 [==============================] - 0s 458us/sample - loss: 0.0051 - mean_squared_error: 0.0051
# [0.005143441396382879, 0.0051434413]
