# %%
import numpy as np
import pandas as pd
import math
import sklearn
import sklearn.preprocessing
import os
import h5py
import matplotlib.pyplot as plt
import tensorflow as tf
import utils

from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LSTM, GRU, Bidirectional, Dense, Dropout, Input, TimeDistributed, RepeatVector, Reshape, Lambda, concatenate
from tensorflow.keras.layers import Flatten, LeakyReLU, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K

tf.__version__
pd.__version__
# Out:
# '0.25.3'

# %%
os.listdir('./data')
# Out:
# ['DJI_fe.csv',
#  'DJI_STO_20period_sma10.csv',
#  'N225.csv',
#  'DJI_modified_features - DJI.csv',
#  'N225fillVOL.csv',
#  'DJI_modified_sma.csv',
#  'downjone5y.csv',
#  'N225withoutNULL.csv',
#  'dowjone1985_2019.csv',
#  '.ipynb_checkpoints',
#  'DJI_ema.csv',
#  'DJI_denoise.csv']

# %%
# data stats parameter
val_set_size_percentage = 10
test_set_size_percentage = 10
seq_len = 20

# hyperparameter
batch_size = 1024
epochs = 100
lr = 1e-3
decay = 1e-2

# %%
df = pd.read_csv('./data/DJI_fe.csv')
df = df.drop('Unnamed: 0', axis=1)
df = df.drop('Unnamed: 0.1', axis=1)
df.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  1985-01-29  1277.719971  1295.489990  1266.890015  1292.619995
# 1  1985-01-30  1297.369995  1305.099976  1278.930054  1287.880005
# 2  1985-01-31  1283.239990  1293.400024  1272.640015  1286.770020
# 3  1985-02-01  1276.939941  1286.109985  1269.770020  1277.719971
# 4  1985-02-04  1272.079956  1294.939941  1268.989990  1290.079956
#
#      Adj Close    Volume        sma_5  sma_10  sma_25  ...  sma_125  sma_200  \
# 0  1292.619995  13560000          NaN     NaN     NaN  ...      NaN      NaN
# 1  1287.880005  16820000          NaN     NaN     NaN  ...      NaN      NaN
# 2  1286.770020  14070000          NaN     NaN     NaN  ...      NaN      NaN
# 3  1277.719971  10980000          NaN     NaN     NaN  ...      NaN      NaN
# 4  1290.079956  11630000  1287.013989     NaN     NaN  ...      NaN      NaN
#
#    %K  %D        ema_5       ema_10       ema_25       ema_75      ema_125  \
# 0 NaN NaN  1292.619995  1292.619995  1292.619995  1292.619995  1292.619995
# 1 NaN NaN  1291.039998  1291.758179  1292.255380  1292.495258  1292.544757
# 2 NaN NaN  1289.616672  1290.851241  1291.833430  1292.344594  1292.453095
# 3 NaN NaN  1285.651105  1288.463737  1290.747779  1291.959736  1292.219235
# 4 NaN NaN  1287.127389  1288.757595  1290.696408  1291.910268  1292.185279
#
#        ema_200
# 0  1292.619995
# 1  1292.572831
# 2  1292.515092
# 3  1292.367876
# 4  1292.345111
#
# [5 rows x 21 columns]

# %%
utils.plot_raw(df)

# %%
df = df.dropna()
df = df.drop('Date', axis=1)
df = df.drop('Adj Close', axis=1)
df = df.drop('Volume', axis=1)

# %%
cols = ['Open', 'Close', 'High', 'Low']
# range_ma = [5, 10, 25, 75, 125, 200]
# for ma in range_ma:
#     cols.append('sma_' + str(ma))
#     cols.append('ema_' + str(ma))

print(cols)
print(len(cols))


df_norm = utils.normalize_data(df,cols)

x_train, y_train, x_val, y_val, x_test, y_test = utils.load_data(df_norm[cols])
# Out:
# ['Open', 'Close', 'High', 'Low']
# 4
# /Users/2two2/Documents/MultimodelStockPrediction/utils.py:44: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   data_raw = stock.as_matrix()

# %%
print('x_train.shape = ', x_train.shape)
print('y_train.shape = ', y_train.shape)
print('x_val.shape = ', x_val.shape)
print('y_val.shape = ', y_val.shape)
print('x_test.shape = ', x_test.shape)
print('y_test.shape = ', y_test.shape)
# Out:
# x_train.shape =  (6835, 19, 4)
# y_train.shape =  (6835, 4)
# x_val.shape =  (854, 19, 4)
# y_val.shape =  (854, 4)
# x_test.shape =  (854, 19, 4)
# y_test.shape =  (854, 4)

# %%
weight_path_model = "saved_model/model_seq2seq.h5"
callbacks_list_model = [
    ModelCheckpoint(
             weight_path_model,
            save_best_only=True,
            save_weights_only=True,
            monitor='val_loss',
            mode='min',
            verbose=1
        )
]

# %%
K.clear_session()


# ! seq2word not real seq2seq
def seq2seq_model():
    seq_len = 20 - 1
    
    # Encoder
    encoder_inputs = Input(shape=(19, 4))
    encoder = LSTM(100, return_state=True, name='encoder')
    encoder_outputs, state_h, state_c = encoder(encoder_inputs)
    states = [state_h, state_c]
    
    # Decoder
    reshaper = Reshape((1, 100), name='reshaper')
    decoder = LSTM(100, return_sequences=True, return_state=True,
                  name='decoder')
    
    # Fully-connected
    fc_output = Dense(4, activation='linear', 
              name='fc')
    
    # Reshape output
    reshaper_output = Reshape((4,), name='reshaper_output')
    
    inputs = reshaper(encoder_outputs)
    outputs, h, c = decoder(inputs, initial_state=states)
        
    inputs = outputs
    states = [h, c]

    outputs = reshaper_output(fc_output(outputs))

#     all_outputs = list()
    
#     for _ in range(seq_len):
#         outputs, h, c = decoder(inputs, initial_state=states)
        
#         inputs = outputs
#         states = [h, c]
        
#         outputs = fc_output(outputs)
#         all_outputs.append(outputs)
        
#     decoder_outputs = Lambda(lambda x: concatenate(x, axis=1))(all_outputs)
    model = Model(inputs=encoder_inputs, outputs=outputs)
    
    model.compile(optimizer=Adam(learning_rate=lr, decay=decay),
                loss='mse',
                metrics=['mse'])   
    
    model.summary()
    
    return model

model = seq2seq_model()

history = model.fit(x_train, y_train, epochs=epochs,
                   validation_data=(x_val, y_val), 
                   batch_size=batch_size, callbacks=callbacks_list_model)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 19, 4)]      0
# __________________________________________________________________________________________________
# encoder (LSTM)                  [(None, 100), (None, 42000       input_1[0][0]
# __________________________________________________________________________________________________
# reshaper (Reshape)              (None, 1, 100)       0           encoder[0][0]
# __________________________________________________________________________________________________
# decoder (LSTM)                  [(None, 1, 100), (No 80400       reshaper[0][0]
#                                                                  encoder[0][1]
#                                                                  encoder[0][2]
# __________________________________________________________________________________________________
# fc (Dense)                      (None, 1, 4)         404         decoder[0][0]
# __________________________________________________________________________________________________
# reshaper_output (Reshape)       (None, 4)            0           fc[0][0]
# ==================================================================================================
# Total params: 122,804
# Trainable params: 122,804
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 6835 samples, validate on 854 samples
# Epoch 1/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 0.0306 - mse: 0.0306
# Epoch 00001: val_loss improved from inf to 0.00933, saving model to saved_model/model_seq2seq.h5
# 6835/6835 [==============================] - 7s 1ms/sample - loss: 0.0279 - mse: 0.0279 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 2/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 0.0036 - mse: 0.0036
# Epoch 00002: val_loss did not improve from 0.00933
# 6835/6835 [==============================] - 2s 244us/sample - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0145 - val_mse: 0.0145
# Epoch 3/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 0.0019 - mse: 0.0019
# Epoch 00003: val_loss improved from 0.00933 to 0.00512, saving model to saved_model/model_seq2seq.h5
# 6835/6835 [==============================] - 2s 223us/sample - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 4/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 9.2331e-04 - mse: 9.2331e-04
# Epoch 00004: val_loss improved from 0.00512 to 0.00275, saving model to saved_model/model_seq2seq.h5
# 6835/6835 [==============================] - 2s 254us/sample - loss: 9.2478e-04 - mse: 9.2478e-04 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 5/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 4.0119e-04 - mse: 4.0119e-04
# Epoch 00005: val_loss improved from 0.00275 to 0.00184, saving model to saved_model/model_seq2seq.h5
# 6835/6835 [==============================] - 2s 246us/sample - loss: 3.8128e-04 - mse: 3.8128e-04 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 6/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 2.7628e-04 - mse: 2.7628e-04
# Epoch 00006: val_loss improved from 0.00184 to 0.00079, saving model to saved_model/model_seq2seq.h5
# 6835/6835 [==============================] - 2s 269us/sample - loss: 2.7253e-04 - mse: 2.7253e-04 - val_loss: 7.8720e-04 - val_mse: 7.8720e-04
# Epoch 7/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 1.2640e-04 - mse: 1.2640e-04
# Epoch 00007: val_loss improved from 0.00079 to 0.00049, saving model to saved_model/model_seq2seq.h5
# 6835/6835 [==============================] - 2s 233us/sample - loss: 1.2205e-04 - mse: 1.2205e-04 - val_loss: 4.8946e-04 - val_mse: 4.8946e-04
# Epoch 8/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 8.5822e-05 - mse: 8.5822e-05
# Epoch 00008: val_loss did not improve from 0.00049
# 6835/6835 [==============================] - 2s 229us/sample - loss: 8.5570e-05 - mse: 8.5570e-05 - val_loss: 6.3305e-04 - val_mse: 6.3305e-04
# Epoch 9/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 6.2864e-05 - mse: 6.2864e-05
# Epoch 00009: val_loss improved from 0.00049 to 0.00029, saving model to saved_model/model_seq2seq.h5
# 6835/6835 [==============================] - 2s 311us/sample - loss: 6.2625e-05 - mse: 6.2625e-05 - val_loss: 2.9484e-04 - val_mse: 2.9484e-04
# Epoch 10/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 4.7125e-05 - mse: 4.7125e-05
# Epoch 00010: val_loss improved from 0.00029 to 0.00022, saving model to saved_model/model_seq2seq.h5
# 6835/6835 [==============================] - 2s 234us/sample - loss: 4.7099e-05 - mse: 4.7099e-05 - val_loss: 2.2016e-04 - val_mse: 2.2016e-04
# Epoch 11/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 4.4999e-05 - mse: 4.4999e-05
# Epoch 00011: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 233us/sample - loss: 4.4703e-05 - mse: 4.4703e-05 - val_loss: 2.2651e-04 - val_mse: 2.2651e-04
# Epoch 12/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.9562e-05 - mse: 3.9562e-05
# Epoch 00012: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 255us/sample - loss: 4.0066e-05 - mse: 4.0066e-05 - val_loss: 2.6713e-04 - val_mse: 2.6713e-04
# Epoch 13/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.9598e-05 - mse: 3.9598e-05
# Epoch 00013: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 263us/sample - loss: 3.9271e-05 - mse: 3.9271e-05 - val_loss: 2.3388e-04 - val_mse: 2.3388e-04
# Epoch 14/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.7740e-05 - mse: 3.7740e-05
# Epoch 00014: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 223us/sample - loss: 3.8108e-05 - mse: 3.8108e-05 - val_loss: 2.2760e-04 - val_mse: 2.2760e-04
# Epoch 15/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.7564e-05 - mse: 3.7564e-05
# Epoch 00015: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 255us/sample - loss: 3.7745e-05 - mse: 3.7745e-05 - val_loss: 2.4871e-04 - val_mse: 2.4871e-04
# Epoch 16/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.8327e-05 - mse: 3.8327e-05
# Epoch 00016: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 253us/sample - loss: 3.7367e-05 - mse: 3.7367e-05 - val_loss: 2.3455e-04 - val_mse: 2.3455e-04
# Epoch 17/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.7173e-05 - mse: 3.7173e-05
# Epoch 00017: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 246us/sample - loss: 3.7175e-05 - mse: 3.7175e-05 - val_loss: 2.5230e-04 - val_mse: 2.5230e-04
# Epoch 18/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.7318e-05 - mse: 3.7318e-05
# Epoch 00018: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 251us/sample - loss: 3.7043e-05 - mse: 3.7043e-05 - val_loss: 2.3822e-04 - val_mse: 2.3822e-04
# Epoch 19/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6422e-05 - mse: 3.6422e-05
# Epoch 00019: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 254us/sample - loss: 3.6980e-05 - mse: 3.6980e-05 - val_loss: 2.4623e-04 - val_mse: 2.4623e-04
# Epoch 20/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6365e-05 - mse: 3.6365e-05
# Epoch 00020: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 262us/sample - loss: 3.6955e-05 - mse: 3.6955e-05 - val_loss: 2.4050e-04 - val_mse: 2.4050e-04
# Epoch 21/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6452e-05 - mse: 3.6452e-05
# Epoch 00021: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 244us/sample - loss: 3.6929e-05 - mse: 3.6929e-05 - val_loss: 2.4483e-04 - val_mse: 2.4483e-04
# Epoch 22/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.7373e-05 - mse: 3.7373e-05
# Epoch 00022: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 250us/sample - loss: 3.6845e-05 - mse: 3.6845e-05 - val_loss: 2.4143e-04 - val_mse: 2.4143e-04
# Epoch 23/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.7027e-05 - mse: 3.7027e-05
# Epoch 00023: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 236us/sample - loss: 3.6826e-05 - mse: 3.6826e-05 - val_loss: 2.4616e-04 - val_mse: 2.4616e-04
# Epoch 24/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6956e-05 - mse: 3.6956e-05
# Epoch 00024: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 223us/sample - loss: 3.6775e-05 - mse: 3.6775e-05 - val_loss: 2.3802e-04 - val_mse: 2.3802e-04
# Epoch 25/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6330e-05 - mse: 3.6330e-05
# Epoch 00025: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 244us/sample - loss: 3.6745e-05 - mse: 3.6745e-05 - val_loss: 2.4706e-04 - val_mse: 2.4706e-04
# Epoch 26/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6541e-05 - mse: 3.6541e-05
# Epoch 00026: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 276us/sample - loss: 3.6721e-05 - mse: 3.6721e-05 - val_loss: 2.4592e-04 - val_mse: 2.4592e-04
# Epoch 27/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.7031e-05 - mse: 3.7031e-05
# Epoch 00027: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 244us/sample - loss: 3.6706e-05 - mse: 3.6706e-05 - val_loss: 2.4367e-04 - val_mse: 2.4367e-04
# Epoch 28/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6195e-05 - mse: 3.6195e-05
# Epoch 00028: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 268us/sample - loss: 3.6676e-05 - mse: 3.6676e-05 - val_loss: 2.4690e-04 - val_mse: 2.4690e-04
# Epoch 29/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6881e-05 - mse: 3.6881e-05
# Epoch 00029: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 234us/sample - loss: 3.6669e-05 - mse: 3.6669e-05 - val_loss: 2.4368e-04 - val_mse: 2.4368e-04
# Epoch 30/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6621e-05 - mse: 3.6621e-05
# Epoch 00030: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 229us/sample - loss: 3.6641e-05 - mse: 3.6641e-05 - val_loss: 2.4818e-04 - val_mse: 2.4818e-04
# Epoch 31/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6085e-05 - mse: 3.6085e-05
# Epoch 00031: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 250us/sample - loss: 3.6587e-05 - mse: 3.6587e-05 - val_loss: 2.4231e-04 - val_mse: 2.4231e-04
# Epoch 32/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6317e-05 - mse: 3.6317e-05
# Epoch 00032: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 240us/sample - loss: 3.6570e-05 - mse: 3.6570e-05 - val_loss: 2.4521e-04 - val_mse: 2.4521e-04
# Epoch 33/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6615e-05 - mse: 3.6615e-05
# Epoch 00033: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 232us/sample - loss: 3.6558e-05 - mse: 3.6558e-05 - val_loss: 2.4824e-04 - val_mse: 2.4824e-04
# Epoch 34/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.7447e-05 - mse: 3.7447e-05
# Epoch 00034: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 248us/sample - loss: 3.6544e-05 - mse: 3.6544e-05 - val_loss: 2.4793e-04 - val_mse: 2.4793e-04
# Epoch 35/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6088e-05 - mse: 3.6088e-05
# Epoch 00035: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 220us/sample - loss: 3.6514e-05 - mse: 3.6514e-05 - val_loss: 2.4492e-04 - val_mse: 2.4492e-04
# Epoch 36/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6800e-05 - mse: 3.6800e-05
# Epoch 00036: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 1s 219us/sample - loss: 3.6481e-05 - mse: 3.6481e-05 - val_loss: 2.5627e-04 - val_mse: 2.5627e-04
# Epoch 37/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6394e-05 - mse: 3.6394e-05
# Epoch 00037: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 1s 219us/sample - loss: 3.6473e-05 - mse: 3.6473e-05 - val_loss: 2.4514e-04 - val_mse: 2.4514e-04
# Epoch 38/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6883e-05 - mse: 3.6883e-05
# Epoch 00038: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 220us/sample - loss: 3.6427e-05 - mse: 3.6427e-05 - val_loss: 2.5250e-04 - val_mse: 2.5250e-04
# Epoch 39/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6679e-05 - mse: 3.6679e-05
# Epoch 00039: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 220us/sample - loss: 3.6393e-05 - mse: 3.6393e-05 - val_loss: 2.4710e-04 - val_mse: 2.4710e-04
# Epoch 40/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6239e-05 - mse: 3.6239e-05
# Epoch 00040: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 1s 219us/sample - loss: 3.6371e-05 - mse: 3.6371e-05 - val_loss: 2.5219e-04 - val_mse: 2.5219e-04
# Epoch 41/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6531e-05 - mse: 3.6531e-05
# Epoch 00041: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 293us/sample - loss: 3.6351e-05 - mse: 3.6351e-05 - val_loss: 2.5250e-04 - val_mse: 2.5250e-04
# Epoch 42/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5210e-05 - mse: 3.5210e-05
# Epoch 00042: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 287us/sample - loss: 3.6336e-05 - mse: 3.6336e-05 - val_loss: 2.5161e-04 - val_mse: 2.5161e-04
# Epoch 43/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6689e-05 - mse: 3.6689e-05
# Epoch 00043: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 3s 478us/sample - loss: 3.6306e-05 - mse: 3.6306e-05 - val_loss: 2.5121e-04 - val_mse: 2.5121e-04
# Epoch 44/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6264e-05 - mse: 3.6264e-05
# Epoch 00044: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 3s 404us/sample - loss: 3.6284e-05 - mse: 3.6284e-05 - val_loss: 2.5499e-04 - val_mse: 2.5499e-04
# Epoch 45/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6205e-05 - mse: 3.6205e-05
# Epoch 00045: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 360us/sample - loss: 3.6260e-05 - mse: 3.6260e-05 - val_loss: 2.5071e-04 - val_mse: 2.5071e-04
# Epoch 46/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6177e-05 - mse: 3.6177e-05
# Epoch 00046: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 349us/sample - loss: 3.6244e-05 - mse: 3.6244e-05 - val_loss: 2.5148e-04 - val_mse: 2.5148e-04
# Epoch 47/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6378e-05 - mse: 3.6378e-05
# Epoch 00047: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 280us/sample - loss: 3.6220e-05 - mse: 3.6220e-05 - val_loss: 2.5613e-04 - val_mse: 2.5613e-04
# Epoch 48/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6394e-05 - mse: 3.6394e-05
# Epoch 00048: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 275us/sample - loss: 3.6213e-05 - mse: 3.6213e-05 - val_loss: 2.4867e-04 - val_mse: 2.4867e-04
# Epoch 49/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6165e-05 - mse: 3.6165e-05
# Epoch 00049: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 292us/sample - loss: 3.6198e-05 - mse: 3.6198e-05 - val_loss: 2.5859e-04 - val_mse: 2.5859e-04
# Epoch 50/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6661e-05 - mse: 3.6661e-05
# Epoch 00050: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 274us/sample - loss: 3.6147e-05 - mse: 3.6147e-05 - val_loss: 2.4813e-04 - val_mse: 2.4813e-04
# Epoch 51/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6242e-05 - mse: 3.6242e-05
# Epoch 00051: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 251us/sample - loss: 3.6158e-05 - mse: 3.6158e-05 - val_loss: 2.5328e-04 - val_mse: 2.5328e-04
# Epoch 52/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6575e-05 - mse: 3.6575e-05
# Epoch 00052: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 307us/sample - loss: 3.6126e-05 - mse: 3.6126e-05 - val_loss: 2.5457e-04 - val_mse: 2.5457e-04
# Epoch 53/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5868e-05 - mse: 3.5868e-05
# Epoch 00053: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 244us/sample - loss: 3.6123e-05 - mse: 3.6123e-05 - val_loss: 2.4979e-04 - val_mse: 2.4979e-04
# Epoch 54/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6052e-05 - mse: 3.6053e-05
# Epoch 00054: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 243us/sample - loss: 3.6120e-05 - mse: 3.6120e-05 - val_loss: 2.5989e-04 - val_mse: 2.5989e-04
# Epoch 55/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6334e-05 - mse: 3.6334e-05
# Epoch 00055: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 243us/sample - loss: 3.6061e-05 - mse: 3.6061e-05 - val_loss: 2.5078e-04 - val_mse: 2.5078e-04
# Epoch 56/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6220e-05 - mse: 3.6220e-05
# Epoch 00056: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 221us/sample - loss: 3.6048e-05 - mse: 3.6048e-05 - val_loss: 2.5706e-04 - val_mse: 2.5706e-04
# Epoch 57/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6278e-05 - mse: 3.6278e-05
# Epoch 00057: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 297us/sample - loss: 3.6025e-05 - mse: 3.6025e-05 - val_loss: 2.5452e-04 - val_mse: 2.5452e-04
# Epoch 58/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5840e-05 - mse: 3.5840e-05
# Epoch 00058: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 256us/sample - loss: 3.6002e-05 - mse: 3.6002e-05 - val_loss: 2.5323e-04 - val_mse: 2.5323e-04
# Epoch 59/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6073e-05 - mse: 3.6073e-05
# Epoch 00059: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 239us/sample - loss: 3.5985e-05 - mse: 3.5985e-05 - val_loss: 2.5632e-04 - val_mse: 2.5632e-04
# Epoch 60/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6310e-05 - mse: 3.6310e-05
# Epoch 00060: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 256us/sample - loss: 3.6006e-05 - mse: 3.6006e-05 - val_loss: 2.5409e-04 - val_mse: 2.5409e-04
# Epoch 61/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6092e-05 - mse: 3.6092e-05
# Epoch 00061: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 240us/sample - loss: 3.5985e-05 - mse: 3.5985e-05 - val_loss: 2.6199e-04 - val_mse: 2.6199e-04
# Epoch 62/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6101e-05 - mse: 3.6101e-05
# Epoch 00062: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 1s 218us/sample - loss: 3.5960e-05 - mse: 3.5960e-05 - val_loss: 2.4652e-04 - val_mse: 2.4652e-04
# Epoch 63/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5701e-05 - mse: 3.5701e-05
# Epoch 00063: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 1s 219us/sample - loss: 3.5915e-05 - mse: 3.5915e-05 - val_loss: 2.6267e-04 - val_mse: 2.6267e-04
# Epoch 64/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6271e-05 - mse: 3.6271e-05
# Epoch 00064: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 1s 218us/sample - loss: 3.5908e-05 - mse: 3.5908e-05 - val_loss: 2.5732e-04 - val_mse: 2.5732e-04
# Epoch 65/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6117e-05 - mse: 3.6117e-05
# Epoch 00065: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 1s 218us/sample - loss: 3.5882e-05 - mse: 3.5882e-05 - val_loss: 2.5590e-04 - val_mse: 2.5590e-04
# Epoch 66/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5098e-05 - mse: 3.5098e-05
# Epoch 00066: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 220us/sample - loss: 3.5869e-05 - mse: 3.5869e-05 - val_loss: 2.5284e-04 - val_mse: 2.5284e-04
# Epoch 67/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5368e-05 - mse: 3.5368e-05
# Epoch 00067: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 219us/sample - loss: 3.5832e-05 - mse: 3.5832e-05 - val_loss: 2.6334e-04 - val_mse: 2.6334e-04
# Epoch 68/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6094e-05 - mse: 3.6094e-05
# Epoch 00068: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 1s 218us/sample - loss: 3.5835e-05 - mse: 3.5835e-05 - val_loss: 2.5468e-04 - val_mse: 2.5468e-04
# Epoch 69/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5708e-05 - mse: 3.5708e-05
# Epoch 00069: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 226us/sample - loss: 3.5818e-05 - mse: 3.5818e-05 - val_loss: 2.5569e-04 - val_mse: 2.5569e-04
# Epoch 70/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5975e-05 - mse: 3.5975e-05
# Epoch 00070: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 251us/sample - loss: 3.5817e-05 - mse: 3.5817e-05 - val_loss: 2.6374e-04 - val_mse: 2.6374e-04
# Epoch 71/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5935e-05 - mse: 3.5935e-05
# Epoch 00071: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 1s 219us/sample - loss: 3.5800e-05 - mse: 3.5800e-05 - val_loss: 2.4930e-04 - val_mse: 2.4930e-04
# Epoch 72/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5726e-05 - mse: 3.5726e-05
# Epoch 00072: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 221us/sample - loss: 3.5759e-05 - mse: 3.5759e-05 - val_loss: 2.6031e-04 - val_mse: 2.6031e-04
# Epoch 73/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5542e-05 - mse: 3.5542e-05
# Epoch 00073: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 254us/sample - loss: 3.5743e-05 - mse: 3.5743e-05 - val_loss: 2.5754e-04 - val_mse: 2.5754e-04
# Epoch 74/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5770e-05 - mse: 3.5770e-05
# Epoch 00074: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 220us/sample - loss: 3.5735e-05 - mse: 3.5735e-05 - val_loss: 2.5598e-04 - val_mse: 2.5598e-04
# Epoch 75/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.4740e-05 - mse: 3.4740e-05
# Epoch 00075: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 1s 219us/sample - loss: 3.5728e-05 - mse: 3.5728e-05 - val_loss: 2.6120e-04 - val_mse: 2.6120e-04
# Epoch 76/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5424e-05 - mse: 3.5424e-05
# Epoch 00076: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 221us/sample - loss: 3.5683e-05 - mse: 3.5683e-05 - val_loss: 2.5603e-04 - val_mse: 2.5603e-04
# Epoch 77/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5674e-05 - mse: 3.5674e-05
# Epoch 00077: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 229us/sample - loss: 3.5672e-05 - mse: 3.5672e-05 - val_loss: 2.5723e-04 - val_mse: 2.5723e-04
# Epoch 78/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5711e-05 - mse: 3.5711e-05
# Epoch 00078: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 247us/sample - loss: 3.5681e-05 - mse: 3.5681e-05 - val_loss: 2.5625e-04 - val_mse: 2.5625e-04
# Epoch 79/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5123e-05 - mse: 3.5123e-05
# Epoch 00079: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 1s 215us/sample - loss: 3.5636e-05 - mse: 3.5636e-05 - val_loss: 2.6341e-04 - val_mse: 2.6341e-04
# Epoch 80/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5699e-05 - mse: 3.5699e-05
# Epoch 00080: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 231us/sample - loss: 3.5633e-05 - mse: 3.5633e-05 - val_loss: 2.5893e-04 - val_mse: 2.5893e-04
# Epoch 81/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6183e-05 - mse: 3.6183e-05
# Epoch 00081: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 242us/sample - loss: 3.5689e-05 - mse: 3.5689e-05 - val_loss: 2.5011e-04 - val_mse: 2.5011e-04
# Epoch 82/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5805e-05 - mse: 3.5805e-05
# Epoch 00082: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 232us/sample - loss: 3.5610e-05 - mse: 3.5610e-05 - val_loss: 2.6940e-04 - val_mse: 2.6940e-04
# Epoch 83/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5277e-05 - mse: 3.5277e-05
# Epoch 00083: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 260us/sample - loss: 3.5590e-05 - mse: 3.5590e-05 - val_loss: 2.5418e-04 - val_mse: 2.5418e-04
# Epoch 84/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5929e-05 - mse: 3.5929e-05
# Epoch 00084: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 251us/sample - loss: 3.5570e-05 - mse: 3.5570e-05 - val_loss: 2.5716e-04 - val_mse: 2.5716e-04
# Epoch 85/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5738e-05 - mse: 3.5738e-05
# Epoch 00085: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 252us/sample - loss: 3.5546e-05 - mse: 3.5546e-05 - val_loss: 2.5690e-04 - val_mse: 2.5690e-04
# Epoch 86/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5435e-05 - mse: 3.5435e-05
# Epoch 00086: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 251us/sample - loss: 3.5528e-05 - mse: 3.5528e-05 - val_loss: 2.5621e-04 - val_mse: 2.5621e-04
# Epoch 87/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.4554e-05 - mse: 3.4554e-05
# Epoch 00087: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 225us/sample - loss: 3.5509e-05 - mse: 3.5509e-05 - val_loss: 2.5956e-04 - val_mse: 2.5956e-04
# Epoch 88/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5372e-05 - mse: 3.5372e-05
# Epoch 00088: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 250us/sample - loss: 3.5501e-05 - mse: 3.5501e-05 - val_loss: 2.5979e-04 - val_mse: 2.5979e-04
# Epoch 89/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5984e-05 - mse: 3.5984e-05
# Epoch 00089: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 224us/sample - loss: 3.5495e-05 - mse: 3.5495e-05 - val_loss: 2.5636e-04 - val_mse: 2.5636e-04
# Epoch 90/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5132e-05 - mse: 3.5132e-05
# Epoch 00090: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 237us/sample - loss: 3.5474e-05 - mse: 3.5474e-05 - val_loss: 2.6310e-04 - val_mse: 2.6310e-04
# Epoch 91/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5891e-05 - mse: 3.5891e-05
# Epoch 00091: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 274us/sample - loss: 3.5452e-05 - mse: 3.5452e-05 - val_loss: 2.5393e-04 - val_mse: 2.5393e-04
# Epoch 92/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.6174e-05 - mse: 3.6174e-05
# Epoch 00092: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 241us/sample - loss: 3.5451e-05 - mse: 3.5451e-05 - val_loss: 2.6062e-04 - val_mse: 2.6062e-04
# Epoch 93/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.4909e-05 - mse: 3.4909e-05
# Epoch 00093: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 226us/sample - loss: 3.5427e-05 - mse: 3.5427e-05 - val_loss: 2.5469e-04 - val_mse: 2.5469e-04
# Epoch 94/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5943e-05 - mse: 3.5943e-05
# Epoch 00094: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 247us/sample - loss: 3.5435e-05 - mse: 3.5435e-05 - val_loss: 2.5635e-04 - val_mse: 2.5635e-04
# Epoch 95/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5462e-05 - mse: 3.5462e-05
# Epoch 00095: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 227us/sample - loss: 3.5385e-05 - mse: 3.5385e-05 - val_loss: 2.6249e-04 - val_mse: 2.6249e-04
# Epoch 96/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5758e-05 - mse: 3.5758e-05
# Epoch 00096: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 292us/sample - loss: 3.5387e-05 - mse: 3.5387e-05 - val_loss: 2.6081e-04 - val_mse: 2.6081e-04
# Epoch 97/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5375e-05 - mse: 3.5375e-05
# Epoch 00097: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 274us/sample - loss: 3.5398e-05 - mse: 3.5398e-05 - val_loss: 2.5138e-04 - val_mse: 2.5138e-04
# Epoch 98/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5334e-05 - mse: 3.5334e-05
# Epoch 00098: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 304us/sample - loss: 3.5351e-05 - mse: 3.5351e-05 - val_loss: 2.6291e-04 - val_mse: 2.6291e-04
# Epoch 99/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.4936e-05 - mse: 3.4936e-05
# Epoch 00099: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 238us/sample - loss: 3.5342e-05 - mse: 3.5342e-05 - val_loss: 2.5773e-04 - val_mse: 2.5773e-04
# Epoch 100/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 3.5179e-05 - mse: 3.5179e-05
# Epoch 00100: val_loss did not improve from 0.00022
# 6835/6835 [==============================] - 2s 231us/sample - loss: 3.5338e-05 - mse: 3.5338e-05 - val_loss: 2.5682e-04 - val_mse: 2.5682e-04

# %%
y_train_pred = model.predict(x_train)
y_val_pred = model.predict(x_val)
y_test_pred = model.predict(x_test)

# %%
utils.plot_result(y_train, y_val, y_test, y_train_pred, y_val_pred, y_test_pred, ft=0)
