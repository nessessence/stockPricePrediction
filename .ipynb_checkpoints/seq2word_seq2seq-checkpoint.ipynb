# %%
import numpy as np
import pandas as pd
import math
import sklearn
import sklearn.preprocessing
import os
import h5py
import matplotlib.pyplot as plt
import tensorflow as tf
import utils

from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LSTM, GRU, Bidirectional, Dense, Dropout, Input, TimeDistributed, RepeatVector, Reshape, Lambda, concatenate
from tensorflow.keras.layers import Flatten, LeakyReLU, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K

tf.__version__
pd.__version__
# Out:
# '0.25.3'

# %%
os.listdir('./data')
# Out:
# ['DJI_fe.csv',
#  'DJI_STO_20period_sma10.csv',
#  'N225.csv',
#  'DJI_modified_features - DJI.csv',
#  'N225fillVOL.csv',
#  'DJI_modified_sma.csv',
#  'downjone5y.csv',
#  'N225withoutNULL.csv',
#  'dowjone1985_2019.csv',
#  '.ipynb_checkpoints',
#  'DJI_ema.csv',
#  'DJI_denoise.csv']

# %%
# data stats parameter
val_set_size_percentage = 10
test_set_size_percentage = 10
seq_len = 20

# hyperparameter
batch_size = 1024
epochs = 100
lr = 1e-3
decay = 1e-2

# %%
df = pd.read_csv('./data/DJI_fe.csv')
df = df.drop('Unnamed: 0', axis=1)
df = df.drop('Unnamed: 0.1', axis=1)
df.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  1985-01-29  1277.719971  1295.489990  1266.890015  1292.619995
# 1  1985-01-30  1297.369995  1305.099976  1278.930054  1287.880005
# 2  1985-01-31  1283.239990  1293.400024  1272.640015  1286.770020
# 3  1985-02-01  1276.939941  1286.109985  1269.770020  1277.719971
# 4  1985-02-04  1272.079956  1294.939941  1268.989990  1290.079956
#
#      Adj Close    Volume        sma_5  sma_10  sma_25  ...  sma_125  sma_200  \
# 0  1292.619995  13560000          NaN     NaN     NaN  ...      NaN      NaN
# 1  1287.880005  16820000          NaN     NaN     NaN  ...      NaN      NaN
# 2  1286.770020  14070000          NaN     NaN     NaN  ...      NaN      NaN
# 3  1277.719971  10980000          NaN     NaN     NaN  ...      NaN      NaN
# 4  1290.079956  11630000  1287.013989     NaN     NaN  ...      NaN      NaN
#
#    %K  %D        ema_5       ema_10       ema_25       ema_75      ema_125  \
# 0 NaN NaN  1292.619995  1292.619995  1292.619995  1292.619995  1292.619995
# 1 NaN NaN  1291.039998  1291.758179  1292.255380  1292.495258  1292.544757
# 2 NaN NaN  1289.616672  1290.851241  1291.833430  1292.344594  1292.453095
# 3 NaN NaN  1285.651105  1288.463737  1290.747779  1291.959736  1292.219235
# 4 NaN NaN  1287.127389  1288.757595  1290.696408  1291.910268  1292.185279
#
#        ema_200
# 0  1292.619995
# 1  1292.572831
# 2  1292.515092
# 3  1292.367876
# 4  1292.345111
#
# [5 rows x 21 columns]

# %%
utils.plot_raw(df)

# %%
df = df.dropna()
df = df.drop('Date', axis=1)
df = df.drop('Adj Close', axis=1)
df = df.drop('Volume', axis=1)

# %%
cols = ['Open', 'Close', 'High', 'Low']
# range_ma = [5, 10, 25, 75, 125, 200]
# for ma in range_ma:
#     cols.append('sma_' + str(ma))
#     cols.append('ema_' + str(ma))

print(cols)
print(len(cols))


df_norm = utils.normalize_data(df,cols)

x_train, y_train, x_val, y_val, x_test, y_test = utils.load_data(df_norm[cols])
# Out:
# ['Open', 'Close', 'High', 'Low']
# 4
# /Users/2two2/Documents/MultimodelStockPrediction/utils.py:44: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   data_raw = stock.as_matrix()

# %%
print('x_train.shape = ', x_train.shape)
print('y_train.shape = ', y_train.shape)
print('x_val.shape = ', x_val.shape)
print('y_val.shape = ', y_val.shape)
print('x_test.shape = ', x_test.shape)
print('y_test.shape = ', y_test.shape)
# Out:
# x_train.shape =  (6835, 19, 4)
# y_train.shape =  (6835, 4)
# x_val.shape =  (854, 19, 4)
# y_val.shape =  (854, 4)
# x_test.shape =  (854, 19, 4)
# y_test.shape =  (854, 4)

# %%
weight_path_model = "saved_model/model_seq2seq.h5"
callbacks_list_model = [
    ModelCheckpoint(
             weight_path_model,
            save_best_only=True,
            save_weights_only=True,
            monitor='val_loss',
            mode='min',
            verbose=1
        )
]

# %%
# ! seq2word not real seq2seq
def seq2word_model():
    seq_len = 20 - 1
    
    # Encoder
    encoder_inputs = Input(shape=(19, 4))
    encoder = LSTM(100, return_state=True, name='encoder')
    encoder_outputs, state_h, state_c = encoder(encoder_inputs)
    states = [state_h, state_c]
    
    # Decoder
    reshaper = Reshape((1, 100), name='reshaper')
    decoder = LSTM(100, return_sequences=True, return_state=True,
                  name='decoder')
    
    # Fully-connected
    fc_output = Dense(4, activation='linear', 
              name='fc')
    
    # Reshape output
    reshaper_output = Reshape((4,), name='reshaper_output')
    
    inputs = reshaper(encoder_outputs)
    outputs, h, c = decoder(inputs, initial_state=states)
        
    inputs = outputs
    states = [h, c]

    outputs = reshaper_output(fc_output(outputs))

#     all_outputs = list()
    
#     for _ in range(seq_len):
#         outputs, h, c = decoder(inputs, initial_state=states)
        
#         inputs = outputs
#         states = [h, c]
        
#         outputs = fc_output(outputs)
#         all_outputs.append(outputs)
        
#     decoder_outputs = Lambda(lambda x: concatenate(x, axis=1))(all_outputs)
    model = Model(inputs=encoder_inputs, outputs=outputs)
    
    model.compile(optimizer=Adam(learning_rate=lr, decay=decay),
                loss='mse',
                metrics=['mse'])   
    
    model.summary()
    
    return model

def seq2seq_model():
    seq_len = 20 - 1
    
    # Encoder
    encoder_inputs = Input(shape=(19, 4))
    encoder = LSTM(100, return_state=True, name='encoder')
    encoder_outputs, state_h, state_c = encoder(encoder_inputs)
    states = [state_h, state_c]
    
    # Decoder
    reshaper = Reshape((1, 100), name='reshaper')
    decoder = LSTM(100, return_sequences=True, return_state=True,
                  name='decoder')
    
    # Fully-connected
    fc_output = Dense(4, activation='linear', 
              name='fc')

    inputs = reshaper(encoder_outputs)

    all_outputs = list()
    
    for _ in range(seq_len):
        outputs, h, c = decoder(inputs, initial_state=states)
        
        inputs = outputs
        states = [h, c]
        
        outputs = fc_output(outputs)
        all_outputs.append(outputs)
        
    decoder_outputs = Lambda(lambda x: concatenate(x, axis=1))(all_outputs)
    model = Model(inputs=encoder_inputs, outputs=decoder_outputs)
    
    model.compile(optimizer=Adam(learning_rate=lr, decay=decay),
                loss='mse',
                metrics=['mse'])   
    
    model.summary()
    
    return model

# %%
K.clear_session()

# predict
# model_word = seq2word_model()

# history = model_word.fit(x_train, y_train, epochs=epochs,
#                    validation_data=(x_val, y_val), 
#                    batch_size=batch_size, callbacks=callbacks_list_model)

model_seq = seq2seq_model()

history = model_seq.fit(x_train, x_train, epochs=epochs,
                   validation_data=(x_val, x_val), 
                   batch_size=batch_size, callbacks=callbacks_list_model)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 19, 4)]      0
# __________________________________________________________________________________________________
# encoder (LSTM)                  [(None, 100), (None, 42000       input_1[0][0]
# __________________________________________________________________________________________________
# reshaper (Reshape)              (None, 1, 100)       0           encoder[0][0]
# __________________________________________________________________________________________________
# decoder (LSTM)                  [(None, 1, 100), (No 80400       reshaper[0][0]
#                                                                  encoder[0][1]
#                                                                  encoder[0][2]
#                                                                  decoder[0][0]
#                                                                  decoder[0][1]
#                                                                  decoder[0][2]
#                                                                  decoder[1][0]
#                                                                  decoder[1][1]
#                                                                  decoder[1][2]
#                                                                  decoder[2][0]
#                                                                  decoder[2][1]
#                                                                  decoder[2][2]
#                                                                  decoder[3][0]
#                                                                  decoder[3][1]
#                                                                  decoder[3][2]
#                                                                  decoder[4][0]
#                                                                  decoder[4][1]
#                                                                  decoder[4][2]
#                                                                  decoder[5][0]
#                                                                  decoder[5][1]
#                                                                  decoder[5][2]
#                                                                  decoder[6][0]
#                                                                  decoder[6][1]
#                                                                  decoder[6][2]
#                                                                  decoder[7][0]
#                                                                  decoder[7][1]
#                                                                  decoder[7][2]
#                                                                  decoder[8][0]
#                                                                  decoder[8][1]
#                                                                  decoder[8][2]
#                                                                  decoder[9][0]
#                                                                  decoder[9][1]
#                                                                  decoder[9][2]
#                                                                  decoder[10][0]
#                                                                  decoder[10][1]
#                                                                  decoder[10][2]
#                                                                  decoder[11][0]
#                                                                  decoder[11][1]
#                                                                  decoder[11][2]
#                                                                  decoder[12][0]
#                                                                  decoder[12][1]
#                                                                  decoder[12][2]
#                                                                  decoder[13][0]
#                                                                  decoder[13][1]
#                                                                  decoder[13][2]
#                                                                  decoder[14][0]
#                                                                  decoder[14][1]
#                                                                  decoder[14][2]
#                                                                  decoder[15][0]
#                                                                  decoder[15][1]
#                                                                  decoder[15][2]
#                                                                  decoder[16][0]
#                                                                  decoder[16][1]
#                                                                  decoder[16][2]
#                                                                  decoder[17][0]
#                                                                  decoder[17][1]
#                                                                  decoder[17][2]
# __________________________________________________________________________________________________
# fc (Dense)                      (None, 1, 4)         404         decoder[0][0]
#                                                                  decoder[1][0]
#                                                                  decoder[2][0]
#                                                                  decoder[3][0]
#                                                                  decoder[4][0]
#                                                                  decoder[5][0]
#                                                                  decoder[6][0]
#                                                                  decoder[7][0]
#                                                                  decoder[8][0]
#                                                                  decoder[9][0]
#                                                                  decoder[10][0]
#                                                                  decoder[11][0]
#                                                                  decoder[12][0]
#                                                                  decoder[13][0]
#                                                                  decoder[14][0]
#                                                                  decoder[15][0]
#                                                                  decoder[16][0]
#                                                                  decoder[17][0]
#                                                                  decoder[18][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 19, 4)        0           fc[0][0]
#                                                                  fc[1][0]
#                                                                  fc[2][0]
#                                                                  fc[3][0]
#                                                                  fc[4][0]
#                                                                  fc[5][0]
#                                                                  fc[6][0]
#                                                                  fc[7][0]
#                                                                  fc[8][0]
#                                                                  fc[9][0]
#                                                                  fc[10][0]
#                                                                  fc[11][0]
#                                                                  fc[12][0]
#                                                                  fc[13][0]
#                                                                  fc[14][0]
#                                                                  fc[15][0]
#                                                                  fc[16][0]
#                                                                  fc[17][0]
#                                                                  fc[18][0]
# ==================================================================================================
# Total params: 122,804
# Trainable params: 122,804
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 6835 samples, validate on 854 samples
# Epoch 1/100
# 6144/6835 [=========================>....] - ETA: 5s - loss: 0.0484 - mse: 0.0484
# Epoch 00001: val_loss improved from inf to 0.02124, saving model to saved_model/model_seq2seq.h5
# 6835/6835 [==============================] - 65s 10ms/sample - loss: 0.0444 - mse: 0.0444 - val_loss: 0.0212 - val_mse: 0.0212
# Epoch 2/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 0.0084 - mse: 0.0084
# Epoch 00002: val_loss did not improve from 0.02124
# 6835/6835 [==============================] - 3s 501us/sample - loss: 0.0083 - mse: 0.0083 - val_loss: 0.
val_loss did not improve from 0.00035
# 6835/6835 [==============================] - 4s 574us/sample - loss: 4.5166e-05 - mse: 4.5166e-05 - val_loss: 9.7623e-04 - val_mse: 9.7623e-04
# Epoch 89/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 4.5243e-05 - mse: 4.5243e-05
# Epoch 00089: val_loss did not improve from 0.00035
# 6835/6835 [==============================] - 4s 606us/sample - loss: 4.5133e-05 - mse: 4.5133e-05 - val_loss: 9.7486e-04 - val_mse: 9.7486e-04
# Epoch 90/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 4.5435e-05 - mse: 4.5435e-05
# Epoch 00090: val_loss did not improve from 0.00035
# 6835/6835 [==============================] - 4s 551us/sample - loss: 4.5117e-05 - mse: 4.5117e-05 - val_loss: 9.5121e-04 - val_mse: 9.5121e-04
# Epoch 91/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 4.5497e-05 - mse: 4.5497e-05
# Epoch 00091: val_loss did not improve from 0.00035
# 6835/6835 [==============================] - 4s 559us/sample - loss: 4.5081e-05 - mse: 4.5081e-05 - val_loss: 9.7737e-04 - val_mse: 9.7737e-04
# Epoch 92/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 4.5933e-05 - mse: 4.5933e-05
# Epoch 00092: val_loss did not improve from 0.00035
# 6835/6835 [==============================] - 4s 550us/sample - loss: 4.5051e-05 - mse: 4.5051e-05 - val_loss: 9.5773e-04 - val_mse: 9.5773e-04
# Epoch 93/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 4.5323e-05 - mse: 4.5323e-05
# Epoch 00093: val_loss did not improve from 0.00035
# 6835/6835 [==============================] - 4s 544us/sample - loss: 4.5027e-05 - mse: 4.5027e-05 - val_loss: 9.6238e-04 - val_mse: 9.6238e-04
# Epoch 94/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 4.5604e-05 - mse: 4.5604e-05
# Epoch 00094: val_loss did not improve from 0.00035
# 6835/6835 [==============================] - 4s 544us/sample - loss: 4.4990e-05 - mse: 4.4990e-05 - val_loss: 9.6758e-04 - val_mse: 9.6758e-04
# Epoch 95/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 4.5287e-05 - mse: 4.5287e-05
# Epoch 00095: val_loss did not improve from 0.00035
# 6835/6835 [==============================] - 4s 568us/sample - loss: 4.4964e-05 - mse: 4.4964e-05 - val_loss: 9.6147e-04 - val_mse: 9.6147e-04
# Epoch 96/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 4.4879e-05 - mse: 4.4879e-05
# Epoch 00096: val_loss did not improve from 0.00035
# 6835/6835 [==============================] - 4s 612us/sample - loss: 4.4939e-05 - mse: 4.4939e-05 - val_loss: 9.6445e-04 - val_mse: 9.6445e-04
# Epoch 97/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 4.5028e-05 - mse: 4.5028e-05
# Epoch 00097: val_loss did not improve from 0.00035
# 6835/6835 [==============================] - 5s 726us/sample - loss: 4.4919e-05 - mse: 4.4919e-05 - val_loss: 9.5954e-04 - val_mse: 9.5954e-04
# Epoch 98/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 4.5575e-05 - mse: 4.5575e-05
# Epoch 00098: val_loss did not improve from 0.00035
# 6835/6835 [==============================] - 5s 720us/sample - loss: 4.4893e-05 - mse: 4.4893e-05 - val_loss: 9.6874e-04 - val_mse: 9.6874e-04
# Epoch 99/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 4.4924e-05 - mse: 4.4924e-05
# Epoch 00099: val_loss did not improve from 0.00035
# 6835/6835 [==============================] - 4s 588us/sample - loss: 4.4866e-05 - mse: 4.4866e-05 - val_loss: 9.6100e-04 - val_mse: 9.6100e-04
# Epoch 100/100
# 6144/6835 [=========================>....] - ETA: 0s - loss: 4.5442e-05 - mse: 4.5442e-05
# Epoch 00100: val_loss did not improve from 0.00035
# 6835/6835 [==============================] - 4s 562us/sample - loss: 4.4843e-05 - mse: 4.4843e-05 - val_loss: 9.7211e-04 - val_mse: 9.7211e-04

# %%
y_train_pred = model_seq.predict(x_train)
y_val_pred = model_seq.predict(x_val)
y_test_pred = model_seq.predict(x_test)

# %%
# utils.plot_result(y_train, y_val, y_test, y_train_pred, y_val_pred, y_test_pred, ft=0)
# y_train_pred = y_train_pred.reshape(-1, 4)
# y_train_pred = y_train_pred[:, 0]
# print('shape : ', y_train_pred.shape)
# y_train = y_train.reshape(-1, 4)
# y_train = y_train[:, 0]
plt.plot(y_train_pred, label='pred')
plt.plot(y_train, label='actual')

# %%
plt.plot(y_train)
