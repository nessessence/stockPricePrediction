# %%
import numpy as np
import pandas as pd
import math
import sklearn
import sklearn.preprocessing
import os
import h5py
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LSTM, GRU, Bidirectional, Dense, Dropout, Input

tf.__version__
# Out:
# '2.0.0'

# %%
print("\n".join(os.listdir("./")))
df = pd.read_csv('data/N225withoutNULL.csv')
# Out:
# AIAlpha.ipynb
# DJI_STO_20period_sma10.csv
# .DS_Store
# saved_model
# Untitled.ipynb
# preprocess
# __pycache__
# README.md
# baseline.ipynb
# utils.py
# model_FE.ipynb
# .ipynb_checkpoints
# model_fe_too.ipynb
# data
# tmp

# %%
df.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  1985-01-29  11843.070313  11843.070313  11843.070313  11843.070313
# 1  1985-01-30  11960.629883  11960.629883  11960.629883  11960.629883
# 2  1985-01-31  11992.309570  11992.309570  11992.309570  11992.309570
# 3  1985-02-01  11946.959961  11946.959961  11946.959961  11946.959961
# 4  1985-02-04  11891.080078  11891.080078  11891.080078  11891.080078
#
#       Adj Close  Volume
# 0  11843.070313       0
# 1  11960.629883       0
# 2  11992.309570       0
# 3  11946.959961       0
# 4  11891.080078       0

# %%
df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count   8880.000000   8880.000000   8880.000000   8880.000000   8880.000000
# mean   17127.378178  17230.332515  17015.456662  17123.019021  17123.019021
# std     6094.196832   6114.941481   6070.241283   6093.569176   6093.569176
# min     7059.770020   7100.770020   6994.899902   7054.979980   7054.979980
# 25%    12331.404785  12386.577393  12270.609619  12321.304932  12321.304932
# 50%    16802.924804  16923.285157  16656.660156  16790.860352  16790.860352
# 75%    20442.700684  20560.332519  20328.775391  20454.067871  20454.067871
# max    38921.648438  38957.441406  38827.710938  38915.871094  38915.871094
#
#               Volume
# count    8880.000000
# mean    59729.515766
# std     71179.395395
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%    117200.000000
# max    595200.000000

# %%
df = df.drop('Adj Close', axis=1)

# %%
plt.figure(figsize=(15, 10))
plt.subplot(2, 1, 1)
plt.plot(df['Close'], color='black', label='close')
plt.title('Stock price')
plt.xlabel('Time [days]')
plt.ylabel('Price')
plt.legend(loc='best')


plt.subplot(2, 1, 2)
plt.plot(df['Volume'], color='black', label='volume')
plt.title('Stock volume')
plt.xlabel('Time [days]')
plt.ylabel('Volume')
plt.legend(loc='best')

# %%
def normalize_data(df):
    min_max_scaler = sklearn.preprocessing.MinMaxScaler()
    df['Open'] = min_max_scaler.fit_transform(df['Open'].to_numpy().reshape(-1, 1))
    df['Low'] = min_max_scaler.fit_transform(df['Low'].to_numpy().reshape(-1, 1))    
    df['High'] = min_max_scaler.fit_transform(df['High'].to_numpy().reshape(-1, 1))    
    df['Close'] = min_max_scaler.fit_transform(df['Close'].to_numpy().reshape(-1, 1))
#     df['sma5'] = min_max_scaler.fit_transform(df['sma5'].to_numpy().reshape(-1, 1))
#     df['sma10'] = min_max_scaler.fit_transform(df['sma10'].to_numpy().reshape(-1, 1))
#     df['sma25'] = min_max_scaler.fit_transform(df['sma25'].to_numpy().reshape(-1, 1))
#     df['sma75'] = min_max_scaler.fit_transform(df['sma75'].to_numpy().reshape(-1, 1))
#     df['sma125'] = min_max_scaler.fit_transform(df['sma125'].to_numpy().reshape(-1, 1))
#     df['sma200'] = min_max_scaler.fit_transform(df['sma200'].to_numpy().reshape(-1, 1))
    #df['Volume'] = min_max_scaler.fit_transform(df['Volume'].to_numpy().reshape(-1, 1))  
    return df

def load_data(stock, seq_len):
    data_raw = stock.as_matrix()
    data = list()
    for index in range(len(data_raw) - seq_len):
        data.append(data_raw[index: index+seq_len])
    data = np.array(data)
    val_set_size = int(np.round(val_set_size_percentage/100*data.shape[0]))
    test_set_size = int(np.round(test_set_size_percentage/100*data.shape[0]))
    train_set_size = data.shape[0] - (val_set_size + test_set_size)
    
    x_train = data[:train_set_size, :-1, :]
    y_train = data[:train_set_size, -1, :]
    
    x_val = data[train_set_size:train_set_size + val_set_size, :-1, :]
    y_val = data[train_set_size:train_set_size + val_set_size, -1, :]
    
    x_test = data[train_set_size+val_set_size:,:-1,:]
    y_test = data[train_set_size+val_set_size:,-1,:]
    
    return [x_train, y_train, x_val, y_val, x_test, y_test]

# %%
df_index = df.drop('Date', axis=1)
df_index = df_index.drop('Volume', axis=1)


cols = list(df_index.columns.values)
print('Col : ', cols)

# rearrange columns ,for training with volume
# n_cols = cols[:3] + [cols[-1]] + [cols[-2]]
# df_index = df_index[n_cols] 

# print("new Cols: ",list(df_index.columns.values))





# parameter for preprocessing #

val_set_size_percentage = 10
test_set_size_percentage = 10
seq_len = 20

#*****************************#

# normalize index
df_index_norm = normalize_data(df_index)

# split train, val, test data

x_train, y_train, x_val, y_val, x_test, y_test = load_data(df_index_norm, seq_len)

print('x_train.shape = ', x_train.shape)
print('y_train.shape = ', y_train.shape)
print('x_val.shape = ', x_val.shape)
print('y_val.shape = ', y_val.shape)
print('x_test.shape = ', x_test.shape)
print('y_test.shape = ', y_test.shape)
# Out:
# Col :  ['Open', 'High', 'Low', 'Close']
# x_train.shape =  (7088, 19, 4)
# y_train.shape =  (7088, 4)
# x_val.shape =  (886, 19, 4)
# y_val.shape =  (886, 4)
# x_test.shape =  (886, 19, 4)
# y_test.shape =  (886, 4)
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
print(y_train[0]);
print("\n")
print(x_train[0]);
# Out:
# [0.16136117 0.16010053 0.16354635 0.16151651]
#
#
# [[0.15012612 0.14886365 0.15230105 0.15028112]
#  [0.15381579 0.15255391 0.15599408 0.15397089]
#  [0.15481007 0.15354836 0.15698927 0.15496521]
#  [0.15338675 0.15212481 0.15556465 0.15354184]
#  [0.15163293 0.1503707  0.15380923 0.15178797]
#  [0.14950969 0.14824712 0.15168405 0.14966467]
#  [0.1508825  0.14962015 0.15305811 0.15103752]
#  [0.15319341 0.15193143 0.15537113 0.1533485 ]
#  [0.15533421 0.15407259 0.15751389 0.15548937]
#  [0.15533421 0.15407259 0.15751389 0.15548937]
#  [0.15592676 0.15466524 0.15810698 0.15608194]
#  [0.15585835 0.15459682 0.15803851 0.15601353]
#  [0.15761533 0.15635408 0.15979709 0.15777055]
#  [0.15970559 0.15844468 0.16188926 0.15986088]
#  [0.15973259 0.15847168 0.16191628 0.15988788]
#  [0.15996764 0.15870678 0.16215155 0.16012294]
#  [0.15983364 0.15857275 0.16201743 0.15998894]
#  [0.15908321 0.1578222  0.16126631 0.15923848]
#  [0.15966697 0.15840605 0.1618506  0.15982226]]

# %%
df_index.head(20)
# Out:
#         Open      High       Low     Close
# 0   0.150126  0.148864  0.152301  0.150281
# 1   0.153816  0.152554  0.155994  0.153971
# 2   0.154810  0.153548  0.156989  0.154965
# 3   0.153387  0.152125  0.155565  0.153542
# 4   0.151633  0.150371  0.153809  0.151788
# 5   0.149510  0.148247  0.151684  0.149665
# 6   0.150883  0.149620  0.153058  0.151038
# 7   0.153193  0.151931  0.155371  0.153348
# 8   0.155334  0.154073  0.157514  0.155489
# 9   0.155334  0.154073  0.157514  0.155489
# 10  0.155927  0.154665  0.158107  0.156082
# 11  0.155858  0.154597  0.158039  0.156014
# 12  0.157615  0.156354  0.159797  0.157771
# 13  0.159706  0.158445  0.161889  0.159861
# 14  0.159733  0.158472  0.161916  0.159888
# 15  0.159968  0.158707  0.162152  0.160123
# 16  0.159834  0.158573  0.162017  0.159989
# 17  0.159083  0.157822  0.161266  0.159238
# 18  0.159667  0.158406  0.161851  0.159822
# 19  0.161361  0.160101  0.163546  0.161517

# %%
plt.figure(figsize=(15, 10))
plt.grid(True)
plt.plot(df_index_norm['Close'], color='black', label='close')
# plt.plot(df_index_norm['sma5'], color='cyan', label='sma5')
# plt.plot(df_index_norm['sma10'], color='red', label='sma10')
# plt.plot(df_index_norm['sma25'], color='gray', label='sma25')
# plt.plot(df_index_norm['sma75'], color='purple', label='sma75')
# plt.plot(df_index_norm['sma125'], color='yellow', label='sma125')
# plt.plot(df_index_norm['sma200'], color='green', label='sma200')
plt.title('Stock')
plt.xlabel('Time [days]')
plt.ylabel('Normalized price / volume')
plt.legend(loc='best')
plt.show()

# %%
from tensorflow.keras import backend as K
K.clear_session()

# %%
from tensorflow.keras.layers import Bidirectional,TimeDistributed,BatchNormalization,Flatten,LeakyReLU,Dropout

def get_bi_gru():
    
    input1 = Input(shape=(19,4,))
    x = Bidirectional(LSTM(256, return_sequences=True,  kernel_initializer='Orthogonal'))(input1)
    x = TimeDistributed(LeakyReLU())(x)
    x = TimeDistributed(BatchNormalization())(x)
    x = GRU(128,kernel_initializer='Orthogonal')(x)
    x =(LeakyReLU())(x)
    x = (BatchNormalization())(x)
    x = (Dropout(0.25))(x)
    out = Dense(4,kernel_initializer='he_normal')(x)

    
    
    model = Model(inputs=input1, outputs=out)
    model.compile(optimizer=Adam(0.005),
                loss='mse',
                metrics=['mse'])   
    
    return model

# %%
model = get_bi_gru()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 19, 4)]           0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 19, 512)           534528
# _________________________________________________________________
# time_distributed (TimeDistri (None, 19, 512)           0
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 19, 512)           2048
# _________________________________________________________________
# gru (GRU)                    (None, 128)               246528
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 516
# =================================================================
# Total params: 784,132
# Trainable params: 782,852
# Non-trainable params: 1,280
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
print('start training ')


weight_path_model = "saved_model/model_sma_NoVOL.h5"
callbacks_list_model = [
    ModelCheckpoint(
             weight_path_model,
            save_best_only=True,
            save_weights_only=True,
            monitor='val_loss',
            mode='min',
            verbose=2
        ),
    ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=4, min_lr=0.0001)
]

#################
batch_size = 64
epochs = 300
#################

history = model.fit(x_train, y_train, epochs=epochs, verbose=2, callbacks=callbacks_list_model,
          validation_data=(x_val, y_val),batch_size=batch_size) #batch_size=batch_size
# Out:
# start training
# Train on 7088 samples, validate on 886 samples
# Epoch 1/300
#
# Epoch 00001: val_loss improved from inf to 0.22586, saving model to saved_model/model_sma_NoVOL.h5
# 7088/7088 - 21s - loss: 0.1581 - mse: 0.1581 - val_loss: 0.2259 - val_mse: 0.2259
# Epoch 2/300
#
# Epoch 00002: val_loss improved from 0.22586 to 0.03837, saving model to saved_model/model_sma_NoVOL.h5
# 7088/7088 - 16s - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0384 - val_mse: 0.0384
# Epoch 3/300
#
# Epoch 00003: val_loss improved from 0.03837 to 0.01537, saving model to saved_model/model_sma_NoVOL.h5
# 7088/7088 - 17s - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0154 - val_mse: 0.0154
# Epoch 4/300
#
# Epoch 00004: val_loss improved from 0.01537 to 0.00742, saving model to saved_model/model_sma_NoVOL.h5
# 7088/7088 - 16s - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 5/300
#
# Epoch 00005: val_loss did not improve from 0.00742
# 7088/7088 - 17s - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0145 - val_mse: 0.0145
# Epoch 6/300
#
# Epoch 00006: val_loss did not improve from 0.00742
# 7088/7088 - 17s - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0164 - val_mse: 0.0164
# Epoch 7/300
#
# Epoch 00007: val_loss improved from 0.00742 to 0.00445, saving model to saved_model/model_sma_NoVOL.h5
# 7088/7088 - 17s - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 8/300
#
# Epoch 00008: val_loss did not improve from 0.00445
# 7088/7088 - 17s - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0375 - val_mse: 0.0375
# Epoch 9/300
#
# Epoch 00009: val_loss did not improve from 0.00445
# 7088/7088 - 16s - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 10/300
#
# Epoch 00010: val_loss improved from 0.00445 to 0.00335, saving model to saved_model/model_sma_NoVOL.h5
# 7088/7088 - 18s - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 11/300
#
# Epoch 00011: val_loss did not improve from 0.00335
# 7088/7088 - 16s - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 12/300
#
# Epoch 00012: val_loss improved from 0.00335 to 0.00162, saving model to saved_model/model_sma_NoVOL.h5
# 7088/7088 - 16s - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 13/300
#
# Epoch 00013: val_loss did not improve from 0.00162
# 7088/7088 - 14s - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0383 - val_mse: 0.0383
# Epoch 14/300
#
# Epoch 00014: val_loss did not improve from 0.00162
# 7088/7088 - 15s - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0405 - val_mse: 0.0405
# Epoch 15/300
#
# Epoch 00015: val_loss did not improve from 0.00162
# 7088/7088 - 15s - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0260 - val_mse: 0.0260
# Epoch 16/300
#
# Epoch 00016: val_loss improved from 0.00162 to 0.00132, saving model to saved_model/model_sma_NoVOL.h5
# 7088/7088 - 16s - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 17/300
#
# Epoch 00017: val_loss did not improve from 0.00132
# 7088/7088 - 15s - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0163 - val_mse: 0.0163
# Epoch 18/300
#
# Epoch 00018: val_loss improved from 0.00132 to 0.00124, saving model to saved_model/model_sma_NoVOL.h5
# 7088/7088 - 15s - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 19/300
#
# Epoch 00019: val_loss did not improve from 0.00124
# 7088/7088 - 16s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 20/300
#
# Epoch 00020: val_loss did not improve from 0.00124
# 7088/7088 - 18s - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 21/300
#
# Epoch 00021: val_loss did not improve from 0.00124
# 7088/7088 - 20s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0128 - val_mse: 0.0128
# Epoch 22/300
#
# Epoch 00022: val_loss did not improve from 0.00124
# 7088/7088 - 19s - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0208 - val_mse: 0.0208
# Epoch 23/300
#
# Epoch 00023: val_loss did not improve from 0.00124
# 7088/7088 - 19s - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 24/300
#
# Epoch 00024: val_loss did not improve from 0.00124
# 7088/7088 - 18s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0211 - val_mse: 0.0211
# Epoch 25/300
#
# Epoch 00025: val_loss did not improve from 0.00124
# 7088/7088 - 17s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 26/300
#
# Epoch 00026: val_loss did not improve from 0.00124
# 7088/7088 - 18s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0268 - val_mse: 0.0268
# Epoch 27/300
#
# Epoch 00027: val_loss did not improve from 0.00124
# 7088/7088 - 18s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0499 - val_mse: 0.0499
# Epoch 28/300
#
# Epoch 00028: val_loss did not improve from 0.00124
# 7088/7088 - 17s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 29/300
#
# Epoch 00029: val_loss improved from 0.00124 to 0.00037, saving model to saved_model/model_sma_NoVOL.h5
# 7088/7088 - 16s - loss: 0.0017 - mse: 0.0017 - val_loss: 3.7455e-04 - val_mse: 3.7455e-04
# Epoch 30/300
#
# Epoch 00030: val_loss did not improve from 0.00037
# 7088/7088 - 15s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 31/300
#
# Epoch 00031: val_loss did not improve from 0.00037
# 7088/7088 - 15s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 32/300
#
# Epoch 00032: val_loss did not improve from 0.00037
# 7088/7088 - 16s - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 33/300
#
# Epoch 00033: val_loss did not improve from 0.00037
# 7088/7088 - 17s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 34/300
#
# Epoch 00034: val_loss did not improve from 0.00037
# 7088/7088 - 16s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 35/300
#
# Epoch 00035: val_loss did not improve from 0.00037
# 7088/7088 - 21s - loss: 0.0018 - mse: 0.0018 - val_loss: 9.2664e-04 - val_mse: 9.2664e-04
# Epoch 36/300
#
# Epoch 00036: val_loss did not improve from 0.00037
# 7088/7088 - 21s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 37/300
#
# Epoch 00037: val_loss did not improve from 0.00037
# 7088/7088 - 20s - loss: 0.0016 - mse: 0.0016 - val_loss: 9.4203e-04 - val_mse: 9.4203e-04
# Epoch 38/300
#
# Epoch 00038: val_loss did not improve from 0.00037
# 7088/7088 - 22s - loss: 0.0013 - mse: 0.0013 - val_loss: 7.1000e-04 - val_mse: 7.1000e-04
# Epoch 39/300
#
# Epoch 00039: val_loss did not improve from 0.00037
# 7088/7088 - 19s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 40/300
#
# Epoch 00040: val_loss did not improve from 0.00037
# 7088/7088 - 18s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0128 - val_mse: 0.0128
# Epoch 41/300
#
# Epoch 00041: val_loss did not improve from 0.00037
# 7088/7088 - 17s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 42/300
#
# Epoch 00042: val_loss improved from 0.00037 to 0.00026, saving model to saved_model/model_sma_NoVOL.h5
# 7088/7088 - 16s - loss: 0.0012 - mse: 0.0012 - val_loss: 2.6293e-04 - val_mse: 2.6293e-04
# Epoch 43/300
#
# Epoch 00043: val_loss did not improve from 0.00026
# 7088/7088 - 16s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 44/300
#
# Epoch 00044: val_loss did not improve from 0.00026
# 7088/7088 - 16s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 45/300
#
# Epoch 00045: val_loss did not improve from 0.00026
# 7088/7088 - 16s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 46/300
#
# Epoch 00046: val_loss did not improve from 0.00026
# 7088/7088 - 16s - loss: 0.0016 - mse: 0.0016 - val_loss: 8.2628e-04 - val_mse: 8.2628e-04
# Epoch 47/300
#
# Epoch 00047: val_loss did not improve from 0.00026
# 7088/7088 - 15s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 48/300
#
# Epoch 00048: val_loss did not improve from 0.00026
# 7088/7088 - 15s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 49/300
#
# Epoch 00049: val_loss did not improve from 0.00026
# 7088/7088 - 16s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 50/300
#
# Epoch 00050: val_loss did not improve from 0.00026
# 7088/7088 - 17s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 51/300
#
# Epoch 00051: val_loss did not improve from 0.00026
# 7088/7088 - 16s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 52/300
#
# Epoch 00052: val_loss did not improve from 0.00026
# 7088/7088 - 176s - loss: 0.0014 - mse: 0.0014 - val_loss: 7.4905e-04 - val_mse: 7.4905e-04
# Epoch 53/300
#
# Epoch 00053: val_loss did not improve from 0.00026
# 7088/7088 - 14s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 54/300
#
# Epoch 00054: val_loss did not improve from 0.00026
# 7088/7088 - 14s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0159 - val_mse: 0.0159
# Epoch 55/300
#
# Epoch 00055: val_loss did not improve from 0.00026
# 7088/7088 - 14s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 56/300
#
# Epoch 00056: val_loss did not improve from 0.00026
# 7088/7088 - 15s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 57/300
#
# Epoch 00057: val_loss did not improve from 0.00026
# 7088/7088 - 15s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 58/300
#
# Epoch 00058: val_loss did not improve from 0.00026
# 7088/7088 - 15s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 59/300
#
# Epoch 00059: val_loss did not improve from 0.00026
# 7088/7088 - 15s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 60/300
#
# Epoch 00060: val_loss improved from 0.00026 to 0.00021, saving model to saved_model/model_sma_NoVOL.h5
# 7088/7088 - 15s - loss: 0.0012 - mse: 0.0012 - val_loss: 2.1133e-04 - val_mse: 2.1133e-04
# Epoch 61/300
#
# Epoch 00061: val_loss did not improve from 0.00021
# 7088/7088 - 14s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 62/300
#
# Epoch 00062: val_loss did not improve from 0.00021
# 7088/7088 - 17s - loss: 0.0014 - mse: 0.0014 - val_loss: 5.8194e-04 - val_mse: 5.8194e-04
# Epoch 63/300
#
# Epoch 00063: val_loss did not improve from 0.00021
# 7088/7088 - 18s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 64/300
#
# Epoch 00064: val_loss did not improve from 0.00021
# 7088/7088 - 15s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 65/300
#
# Epoch 00065: val_loss did not improve from 0.00021
# 7088/7088 - 15s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 66/300
#
# Epoch 00066: val_loss did not improve from 0.00021
# 7088/7088 - 15s - loss: 0.0013 - mse: 0.0013 - val_loss: 8.5732e-04 - val_mse: 8.5732e-04
# Epoch 67/300
#
# Epoch 00067: val_loss did not improve from 0.00021
# 7088/7088 - 15s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 68/300
#
# Epoch 00068: val_loss did not improve from 0.00021
# 7088/7088 - 16s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 69/300
#
# Epoch 00069: val_loss did not improve from 0.00021
# 7088/7088 - 16s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 70/300
#
# Epoch 00070: val_loss improved from 0.00021 to 0.00019, saving model to saved_model/model_sma_NoVOL.h5
# 7088/7088 - 16s - loss: 0.0010 - mse: 0.0010 - val_loss: 1.9385e-04 - val_mse: 1.9385e-04
# Epoch 71/300
#
# Epoch 00071: val_loss did not improve from 0.00019
# 7088/7088 - 16s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 72/300
#
# Epoch 00072: val_loss did not improve from 0.00019
# 7088/7088 - 16s - loss: 0.0013 - mse: 0.0013 - val_loss: 6.7464e-04 - val_mse: 6.7464e-04
# Epoch 73/300
#
# Epoch 00073: val_loss did not improve from 0.00019
# 7088/7088 - 16s - loss: 0.0013 - mse: 0.0013 - val_loss: 9.8187e-04 - val_mse: 9.8187e-04
# Epoch 74/300
#
# Epoch 00074: val_loss did not improve from 0.00019
# 7088/7088 - 17s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 75/300
#
# Epoch 00075: val_loss did not improve from 0.00019
# 7088/7088 - 151s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 76/300
#
# Epoch 00076: val_loss did not improve from 0.00019
# 7088/7088 - 13s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 77/300
#
# Epoch 00077: val_loss did not improve from 0.00019
# 7088/7088 - 14s - loss: 0.0013 - mse: 0.0013 - val_loss: 9.2294e-04 - val_mse: 9.2294e-04
# Epoch 78/300
#
# Epoch 00078: val_loss did not improve from 0.00019
# 7088/7088 - 14s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 79/300
#
# Epoch 00079: val_loss did not improve from 0.00019
# 7088/7088 - 15s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 80/300
#
# Epoch 00080: val_loss did not improve from 0.00019
# 7088/7088 - 22s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 81/300
#
# Epoch 00081: val_loss did not improve from 0.00019
# 7088/7088 - 15s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 82/300
#
# Epoch 00082: val_loss did not improve from 0.00019
# 7088/7088 - 20s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 83/300
#
# Epoch 00083: val_loss did not improve from 0.00019
# 7088/7088 - 23s - loss: 0.0012 - mse: 0.0012 - val_loss: 7.0011e-04 - val_mse: 7.0011e-04
# Epoch 84/300
#
# Epoch 00084: val_loss improved from 0.00019 to 0.00015, saving model to saved_model/model_sma_NoVOL.h5
# 7088/7088 - 23s - loss: 9.6634e-04 - mse: 9.6634e-04 - val_loss: 1.5178e-04 - val_mse: 1.5178e-04
# Epoch 85/300
#
# Epoch 00085: val_loss did not improve from 0.00015
# 7088/7088 - 23s - loss: 0.0012 - mse: 0.0012 - val_loss: 2.2689e-04 - val_mse: 2.2689e-04
# Epoch 86/300
#
# Epoch 00086: val_loss did not improve from 0.00015
# 7088/7088 - 23s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 87/300
#
# Epoch 00087: val_loss improved from 0.00015 to 0.00009, saving model to saved_model/model_sma_NoVOL.h5
# 7088/7088 - 16s - loss: 0.0010 - mse: 0.0010 - val_loss: 9.3932e-05 - val_mse: 9.3932e-05
# Epoch 88/300
#
# Epoch 00088: val_loss did not improve from 0.00009
# 7088/7088 - 15s - loss: 0.0012 - mse: 0.0012 - val_loss: 4.4991e-04 - val_mse: 4.4991e-04
# Epoch 89/300
#
# Epoch 00089: val_loss did not improve from 0.00009
# 7088/7088 - 13s - loss: 0.0012 - mse: 0.0012 - val_loss: 4.3296e-04 - val_mse: 4.3296e-04
# Epoch 90/300
#
# Epoch 00090: val_loss did not improve from 0.00009
# 7088/7088 - 14s - loss: 9.6518e-04 - mse: 9.6518e-04 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 91/300
#
# Epoch 00091: val_loss did not improve from 0.00009
# 7088/7088 - 14s - loss: 0.0012 - mse: 0.0012 - val_loss: 2.6955e-04 - val_mse: 2.6955e-04
# Epoch 92/300
#
# Epoch 00092: val_loss did not improve from 0.00009
# 7088/7088 - 14s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 93/300
#
# Epoch 00093: val_loss did not improve from 0.00009
# 7088/7088 - 14s - loss: 0.0012 - mse: 0.0012 - val_loss: 5.0243e-04 - val_mse: 5.0243e-04
# Epoch 94/300
#
# Epoch 00094: val_loss did not improve from 0.00009
# 7088/7088 - 16s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 95/300
#
# Epoch 00095: val_loss did not improve from 0.00009
# 7088/7088 - 18s - loss: 0.0011 - mse: 0.0011 - val_loss: 6.2507e-04 - val_mse: 6.2507e-04
# Epoch 96/300
#
# Epoch 00096: val_loss did not improve from 0.00009
# 7088/7088 - 19s - loss: 0.0014 - mse: 0.0014 - val_loss: 2.9700e-04 - val_mse: 2.9700e-04
# Epoch 97/300
#
# Epoch 00097: val_loss did not improve from 0.00009
# 7088/7088 - 18s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 98/300
#
# Epoch 00098: val_loss did not improve from 0.00009
# 7088/7088 - 19s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 99/300
#
# Epoch 00099: val_loss did not improve from 0.00009
# 7088/7088 - 17s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 100/300
#
# Epoch 00100: val_loss did not improve from 0.00009
# 7088/7088 - 17s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 101/300
#
# Epoch 00101: val_loss did not improve from 0.00009
# 7088/7088 - 20s - loss: 0.0013 - mse: 0.0013 - val_loss: 3.8021e-04 - val_mse: 3.8021e-04
# Epoch 102/300
#
# Epoch 00102: val_loss did not improve from 0.00009
# 7088/7088 - 20s - loss: 9.5321e-04 - mse: 9.5321e-04 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 103/300
#
# Epoch 00103: val_loss did not improve from 0.00009
# 7088/7088 - 18s - loss: 9.5559e-04 - mse: 9.5559e-04 - val_loss: 5.9749e-04 - val_mse: 5.9749e-04
# Epoch 104/300
#
# Epoch 00104: val_loss did not improve from 0.00009
# 7088/7088 - 18s - loss: 9.5852e-04 - mse: 9.5852e-04 - val_loss: 8.7434e-04 - val_mse: 8.7434e-04
# Epoch 105/300
#
# Epoch 00105: val_loss did not improve from 0.00009
# 7088/7088 - 19s - loss: 0.0011 - mse: 0.0011 - val_loss: 1.4975e-04 - val_mse: 1.4975e-04
# Epoch 106/300
#
# Epoch 00106: val_loss did not improve from 0.00009
# 7088/7088 - 19s - loss: 0.0011 - mse: 0.0011 - val_loss: 2.5693e-04 - val_mse: 2.5693e-04
# Epoch 107/300
#
# Epoch 00107: val_loss did not improve from 0.00009
# 7088/7088 - 18s - loss: 0.0011 - mse: 0.0011 - val_loss: 7.9740e-04 - val_mse: 7.9740e-04
# Epoch 108/300
#
# Epoch 00108: val_loss did not improve from 0.00009
# 7088/7088 - 19s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 109/300
#
# Epoch 00109: val_loss did not improve from 0.00009
# 7088/7088 - 19s - loss: 0.0012 - mse: 0.0012 - val_loss: 4.7078e-04 - val_mse: 4.7078e-04
# Epoch 110/300
#
# Epoch 00110: val_loss did not improve from 0.00009
# 7088/7088 - 19s - loss: 0.0011 - mse: 0.0011 - val_loss: 1.8486e-04 - val_mse: 1.8486e-04
# Epoch 111/300
#
# Epoch 00111: val_loss did not improve from 0.00009
# 7088/7088 - 19s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 112/300
#
# Epoch 00112: val_loss did not improve from 0.00009
# 7088/7088 - 18s - loss: 0.0012 - mse: 0.0012 - val_loss: 2.9166e-04 - val_mse: 2.9166e-04
# Epoch 113/300
#
# Epoch 00113: val_loss did not improve from 0.00009
# 7088/7088 - 18s - loss: 0.0011 - mse: 0.0011 - val_loss: 3.9370e-04 - val_mse: 3.9370e-04
# Epoch 114/300
#
# Epoch 00114: val_loss did not improve from 0.00009
# 7088/7088 - 18s - loss: 9.5605e-04 - mse: 9.5605e-04 - val_loss: 6.5494e-04 - val_mse: 6.5494e-04
# Epoch 115/300
#
# Epoch 00115: val_loss did not improve from 0.00009
# 7088/7088 - 19s - loss: 8.7916e-04 - mse: 8.7916e-04 - val_loss: 1.0134e-04 - val_mse: 1.0134e-04
# Epoch 116/300
#
# Epoch 00116: val_loss did not improve from 0.00009
# 7088/7088 - 19s - loss: 0.0011 - mse: 0.0011 - val_loss: 9.4001e-04 - val_mse: 9.4001e-04
# Epoch 117/300
#
# Epoch 00117: val_loss did not improve from 0.00009
# 7088/7088 - 19s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 118/300
#
# Epoch 00118: val_loss did not improve from 0.00009
# 7088/7088 - 19s - loss: 0.0012 - mse: 0.0012 - val_loss: 2.0943e-04 - val_mse: 2.0943e-04
# Epoch 119/300
#
# Epoch 00119: val_loss did not improve from 0.00009
# 7088/7088 - 18s - loss: 0.0011 - mse: 0.0011 - val_loss: 3.2630e-04 - val_mse: 3.2630e-04
# Epoch 120/300
#
# Epoch 00120: val_loss did not improve from 0.00009
# 7088/7088 - 18s - loss: 9.7349e-04 - mse: 9.7349e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 121/300
#
# Epoch 00121: val_loss improved from 0.00009 to 0.00007, saving model to saved_model/model_sma_NoVOL.h5
# 7088/7088 - 19s - loss: 0.0010 - mse: 0.0010 - val_loss: 7.3250e-05 - val_mse: 7.3250e-05
# Epoch 122/300
#
# Epoch 00122: val_loss did not improve from 0.00007
# 7088/7088 - 19s - loss: 8.8884e-04 - mse: 8.8884e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 123/300
#
# Epoch 00123: val_loss did not improve from 0.00007
# 7088/7088 - 18s - loss: 0.0012 - mse: 0.0012 - val_loss: 2.1839e-04 - val_mse: 2.1839e-04
# Epoch 124/300
#
# Epoch 00124: val_loss did not improve from 0.00007
# 7088/7088 - 19s - loss: 9.5999e-04 - mse: 9.5999e-04 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 125/300
#
# Epoch 00125: val_loss did not improve from 0.00007
# 7088/7088 - 19s - loss: 9.7450e-04 - mse: 9.7450e-04 - val_loss: 3.5517e-04 - val_mse: 3.5517e-04
# Epoch 126/300
#
# Epoch 00126: val_loss did not improve from 0.00007
# 7088/7088 - 19s - loss: 0.0010 - mse: 0.0010 - val_loss: 3.9642e-04 - val_mse: 3.9642e-04
# Epoch 127/300
#
# Epoch 00127: val_loss did not improve from 0.00007
# 7088/7088 - 20s - loss: 0.0011 - mse: 0.0011 - val_loss: 2.7770e-04 - val_mse: 2.7770e-04
# Epoch 128/300
#
# Epoch 00128: val_loss did not improve from 0.00007
# 7088/7088 - 19s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 129/300
#
# Epoch 00129: val_loss did not improve from 0.00007
# 7088/7088 - 17s - loss: 9.8879e-04 - mse: 9.8879e-04 - val_loss: 5.9591e-04 - val_mse: 5.9591e-04
# Epoch 130/300
#
# Epoch 00130: val_loss did not improve from 0.00007
# 7088/7088 - 19s - loss: 0.0013 - mse: 0.0013 - val_loss: 4.2877e-04 - val_mse: 4.2877e-04
# Epoch 131/300
#
# Epoch 00131: val_loss did not improve from 0.00007
# 7088/7088 - 22s - loss: 0.0010 - mse: 0.0010 - val_loss: 1.4761e-04 - val_mse: 1.4761e-04
# Epoch 132/300
#
# Epoch 00132: val_loss did not improve from 0.00007
# 7088/7088 - 23s - loss: 9.8927e-04 - mse: 9.8927e-04 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 133/300
#
# Epoch 00133: val_loss did not improve from 0.00007
# 7088/7088 - 23s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 134/300
#
# Epoch 00134: val_loss did not improve from 0.00007
# 7088/7088 - 24s - loss: 0.0010 - mse: 0.0010 - val_loss: 2.8023e-04 - val_mse: 2.8023e-04
# Epoch 135/300
#
# Epoch 00135: val_loss did not improve from 0.00007
# 7088/7088 - 23s - loss: 0.0011 - mse: 0.0011 - val_loss: 4.8916e-04 - val_mse: 4.8916e-04
# Epoch 136/300
#
# Epoch 00136: val_loss did not improve from 0.00007
# 7088/7088 - 33s - loss: 0.0011 - mse: 0.0011 - val_loss: 4.9618e-04 - val_mse: 4.9618e-04
# Epoch 137/300
#
# Epoch 00137: val_loss did not improve from 0.00007
# 7088/7088 - 30s - loss: 0.0010 - mse: 0.0010 - val_loss: 3.2041e-04 - val_mse: 3.2041e-04
# Epoch 138/300
#
# Epoch 00138: val_loss did not improve from 0.00007
# 7088/7088 - 23s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 139/300
#
# Epoch 00139: val_loss did not improve from 0.00007
# 7088/7088 - 23s - loss: 9.5280e-04 - mse: 9.5280e-04 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 140/300
#
# Epoch 00140: val_loss did not improve from 0.00007
# 7088/7088 - 25s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 141/300
#
# Epoch 00141: val_loss did not improve from 0.00007
# 7088/7088 - 25s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 142/300
#
# Epoch 00142: val_loss did not improve from 0.00007
# 7088/7088 - 20s - loss: 9.8294e-04 - mse: 9.8294e-04 - val_loss: 2.4700e-04 - val_mse: 2.4700e-04
# Epoch 143/300
#
# Epoch 00143: val_loss did not improve from 0.00007
# 7088/7088 - 19s - loss: 8.9231e-04 - mse: 8.9231e-04 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 144/300
#
# Epoch 00144: val_loss did not improve from 0.00007
# 7088/7088 - 22s - loss: 9.8834e-04 - mse: 9.8834e-04 - val_loss: 4.3376e-04 - val_mse: 4.3376e-04
# Epoch 145/300
#
# Epoch 00145: val_loss did not improve from 0.00007
# 7088/7088 - 33s - loss: 0.0011 - mse: 0.0011 - val_loss: 4.8450e-04 - val_mse: 4.8450e-04
# Epoch 146/300
#
# Epoch 00146: val_loss did not improve from 0.00007
# 7088/7088 - 27s - loss: 0.0012 - mse: 0.0012 - val_loss: 3.3463e-04 - val_mse: 3.3463e-04
# Epoch 147/300
#
# Epoch 00147: val_loss did not improve from 0.00007
# 7088/7088 - 19s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 148/300
#
# Epoch 00148: val_loss did not improve from 0.00007
# 7088/7088 - 17s - loss: 0.0011 - mse: 0.0011 - val_loss: 7.4833e-04 - val_mse: 7.4833e-04
# Epoch 149/300
#
# Epoch 00149: val_loss did not improve from 0.00007
# 7088/7088 - 16s - loss: 0.0011 - mse: 0.0011 - val_loss: 7.6363e-04 - val_mse: 7.6363e-04
# Epoch 150/300
#
# Epoch 00150: val_loss did not improve from 0.00007
# 7088/7088 - 17s - loss: 9.6135e-04 - mse: 9.6135e-04 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 151/300
#
# Epoch 00151: val_loss did not improve from 0.00007
# 7088/7088 - 18s - loss: 8.9268e-04 - mse: 8.9268e-04 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 152/300
#
# Epoch 00152: val_loss did not improve from 0.00007
# 7088/7088 - 19s - loss: 9.5406e-04 - mse: 9.5406e-04 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 153/300
#
# Epoch 00153: val_loss did not improve from 0.00007
# 7088/7088 - 25s - loss: 9.6113e-04 - mse: 9.6113e-04 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 154/300
#
# Epoch 00154: val_loss did not improve from 0.00007
# 7088/7088 - 23s - loss: 8.8997e-04 - mse: 8.8997e-04 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 155/300
#
# Epoch 00155: val_loss did not improve from 0.00007
# 7088/7088 - 18s - loss: 9.2880e-04 - mse: 9.2880e-04 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 156/300
#
# Epoch 00156: val_loss did not improve from 0.00007
# 7088/7088 - 18s - loss: 0.0011 - mse: 0.0011 - val_loss: 1.6608e-04 - val_mse: 1.6608e-04
# Epoch 157/300
#
# Epoch 00157: val_loss did not improve from 0.00007
# 7088/7088 - 21s - loss: 9.3214e-04 - mse: 9.3214e-04 - val_loss: 1.7430e-04 - val_mse: 1.7430e-04
# Epoch 158/300
#
# Epoch 00158: val_loss improved from 0.00007 to 0.00005, saving model to saved_model/model_sma_NoVOL.h5
# 7088/7088 - 22s - loss: 0.0011 - mse: 0.0011 - val_loss: 5.0624e-05 - val_mse: 5.0624e-05
# Epoch 159/300
#
# Epoch 00159: val_loss did not improve from 0.00005
# 7088/7088 - 18s - loss: 0.0011 - mse: 0.0011 - val_loss: 2.3768e-04 - val_mse: 2.3768e-04
# Epoch 160/300
#
# Epoch 00160: val_loss did not improve from 0.00005
# 7088/7088 - 17s - loss: 9.0779e-04 - mse: 9.0779e-04 - val_loss: 5.9315e-04 - val_mse: 5.9315e-04
# Epoch 161/300
#
# Epoch 00161: val_loss did not improve from 0.00005
# 7088/7088 - 22s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 162/300
#
# Epoch 00162: val_loss did not improve from 0.00005
# 7088/7088 - 20s - loss: 9.8600e-04 - mse: 9.8600e-04 - val_loss: 1.7011e-04 - val_mse: 1.7011e-04
# Epoch 163/300
#
# Epoch 00163: val_loss did not improve from 0.00005
# 7088/7088 - 20s - loss: 0.0012 - mse: 0.0012 - val_loss: 3.3553e-04 - val_mse: 3.3553e-04
# Epoch 164/300
#
# Epoch 00164: val_loss did not improve from 0.00005
# 7088/7088 - 20s - loss: 0.0011 - mse: 0.0011 - val_loss: 8.0355e-04 - val_mse: 8.0355e-04
# Epoch 165/300
#
# Epoch 00165: val_loss did not improve from 0.00005
# 7088/7088 - 18s - loss: 0.0010 - mse: 0.0010 - val_loss: 1.7975e-04 - val_mse: 1.7975e-04
# Epoch 166/300
#
# Epoch 00166: val_loss did not improve from 0.00005
# 7088/7088 - 18s - loss: 9.6777e-04 - mse: 9.6777e-04 - val_loss: 1.5703e-04 - val_mse: 1.5703e-04
# Epoch 167/300
#
# Epoch 00167: val_loss did not improve from 0.00005
# 7088/7088 - 19s - loss: 0.0011 - mse: 0.0011 - val_loss: 5.9360e-04 - val_mse: 5.9360e-04
# Epoch 168/300
#
# Epoch 00168: val_loss did not improve from 0.00005
# 7088/7088 - 20s - loss: 8.8078e-04 - mse: 8.8078e-04 - val_loss: 3.9598e-04 - val_mse: 3.9598e-04
# Epoch 169/300
#
# Epoch 00169: val_loss did not improve from 0.00005
# 7088/7088 - 18s - loss: 8.8102e-04 - mse: 8.8102e-04 - val_loss: 4.6265e-04 - val_mse: 4.6265e-04
# Epoch 170/300
#
# Epoch 00170: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 9.3646e-04 - mse: 9.3646e-04 - val_loss: 8.1737e-04 - val_mse: 8.1737e-04
# Epoch 171/300
#
# Epoch 00171: val_loss did not improve from 0.00005
# 7088/7088 - 14s - loss: 0.0010 - mse: 0.0010 - val_loss: 1.9322e-04 - val_mse: 1.9322e-04
# Epoch 172/300
#
# Epoch 00172: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 9.7106e-04 - mse: 9.7106e-04 - val_loss: 1.1059e-04 - val_mse: 1.1059e-04
# Epoch 173/300
#
# Epoch 00173: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 174/300
#
# Epoch 00174: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 9.5437e-04 - mse: 9.5437e-04 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 175/300
#
# Epoch 00175: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 0.0012 - mse: 0.0012 - val_loss: 5.1646e-05 - val_mse: 5.1646e-05
# Epoch 176/300
#
# Epoch 00176: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 9.8357e-04 - mse: 9.8357e-04 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 177/300
#
# Epoch 00177: val_loss did not improve from 0.00005
# 7088/7088 - 19s - loss: 0.0010 - mse: 0.0010 - val_loss: 5.7065e-04 - val_mse: 5.7065e-04
# Epoch 178/300
#
# Epoch 00178: val_loss did not improve from 0.00005
# 7088/7088 - 20s - loss: 8.7118e-04 - mse: 8.7118e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 179/300
#
# Epoch 00179: val_loss did not improve from 0.00005
# 7088/7088 - 18s - loss: 9.8120e-04 - mse: 9.8120e-04 - val_loss: 5.5888e-05 - val_mse: 5.5888e-05
# Epoch 180/300
#
# Epoch 00180: val_loss did not improve from 0.00005
# 7088/7088 - 17s - loss: 8.6147e-04 - mse: 8.6147e-04 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 181/300
#
# Epoch 00181: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 0.0010 - mse: 0.0010 - val_loss: 1.5736e-04 - val_mse: 1.5736e-04
# Epoch 182/300
#
# Epoch 00182: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 8.9348e-04 - mse: 8.9348e-04 - val_loss: 8.5471e-04 - val_mse: 8.5471e-04
# Epoch 183/300
#
# Epoch 00183: val_loss did not improve from 0.00005
# 7088/7088 - 18s - loss: 9.9384e-04 - mse: 9.9384e-04 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 184/300
#
# Epoch 00184: val_loss did not improve from 0.00005
# 7088/7088 - 20s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 185/300
#
# Epoch 00185: val_loss did not improve from 0.00005
# 7088/7088 - 19s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 186/300
#
# Epoch 00186: val_loss did not improve from 0.00005
# 7088/7088 - 17s - loss: 9.2693e-04 - mse: 9.2693e-04 - val_loss: 5.6126e-04 - val_mse: 5.6126e-04
# Epoch 187/300
#
# Epoch 00187: val_loss did not improve from 0.00005
# 7088/7088 - 17s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 188/300
#
# Epoch 00188: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 0.0010 - mse: 0.0010 - val_loss: 2.4680e-04 - val_mse: 2.4680e-04
# Epoch 189/300
#
# Epoch 00189: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 9.5650e-04 - mse: 9.5650e-04 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 190/300
#
# Epoch 00190: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 9.9263e-04 - mse: 9.9263e-04 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 191/300
#
# Epoch 00191: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 0.0010 - mse: 0.0010 - val_loss: 8.4479e-05 - val_mse: 8.4479e-05
# Epoch 192/300
#
# Epoch 00192: val_loss did not improve from 0.00005
# 7088/7088 - 18s - loss: 9.6489e-04 - mse: 9.6489e-04 - val_loss: 1.2854e-04 - val_mse: 1.2854e-04
# Epoch 193/300
#
# Epoch 00193: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 0.0012 - mse: 0.0012 - val_loss: 7.4329e-05 - val_mse: 7.4329e-05
# Epoch 194/300
#
# Epoch 00194: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 8.8033e-04 - mse: 8.8033e-04 - val_loss: 8.0434e-04 - val_mse: 8.0434e-04
# Epoch 195/300
#
# Epoch 00195: val_loss did not improve from 0.00005
# 7088/7088 - 18s - loss: 0.0010 - mse: 0.0010 - val_loss: 2.7868e-04 - val_mse: 2.7868e-04
# Epoch 196/300
#
# Epoch 00196: val_loss did not improve from 0.00005
# 7088/7088 - 17s - loss: 9.3638e-04 - mse: 9.3638e-04 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 197/300
#
# Epoch 00197: val_loss did not improve from 0.00005
# 7088/7088 - 18s - loss: 9.1823e-04 - mse: 9.1823e-04 - val_loss: 2.5529e-04 - val_mse: 2.5529e-04
# Epoch 198/300
#
# Epoch 00198: val_loss did not improve from 0.00005
# 7088/7088 - 18s - loss: 8.9357e-04 - mse: 8.9357e-04 - val_loss: 2.1574e-04 - val_mse: 2.1574e-04
# Epoch 199/300
#
# Epoch 00199: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 0.0011 - mse: 0.0011 - val_loss: 5.3016e-04 - val_mse: 5.3016e-04
# Epoch 200/300
#
# Epoch 00200: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 8.9371e-04 - mse: 8.9371e-04 - val_loss: 9.1914e-04 - val_mse: 9.1914e-04
# Epoch 201/300
#
# Epoch 00201: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 0.0010 - mse: 0.0010 - val_loss: 2.6925e-04 - val_mse: 2.6925e-04
# Epoch 202/300
#
# Epoch 00202: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 9.0475e-04 - mse: 9.0475e-04 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 203/300
#
# Epoch 00203: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 8.4588e-04 - mse: 8.4588e-04 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 204/300
#
# Epoch 00204: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 9.3755e-04 - mse: 9.3755e-04 - val_loss: 3.7184e-04 - val_mse: 3.7184e-04
# Epoch 205/300
#
# Epoch 00205: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 0.0011 - mse: 0.0011 - val_loss: 3.9598e-04 - val_mse: 3.9598e-04
# Epoch 206/300
#
# Epoch 00206: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 8.7344e-04 - mse: 8.7344e-04 - val_loss: 9.7059e-04 - val_mse: 9.7059e-04
# Epoch 207/300
#
# Epoch 00207: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 208/300
#
# Epoch 00208: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 0.0011 - mse: 0.0011 - val_loss: 6.4355e-04 - val_mse: 6.4355e-04
# Epoch 209/300
#
# Epoch 00209: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 9.2492e-04 - mse: 9.2492e-04 - val_loss: 2.1064e-04 - val_mse: 2.1064e-04
# Epoch 210/300
#
# Epoch 00210: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 9.4833e-04 - mse: 9.4833e-04 - val_loss: 1.9490e-04 - val_mse: 1.9490e-04
# Epoch 211/300
#
# Epoch 00211: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 0.0011 - mse: 0.0011 - val_loss: 7.4519e-05 - val_mse: 7.4519e-05
# Epoch 212/300
#
# Epoch 00212: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 9.8946e-04 - mse: 9.8946e-04 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 213/300
#
# Epoch 00213: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 9.9161e-04 - mse: 9.9161e-04 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 214/300
#
# Epoch 00214: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 8.7274e-04 - mse: 8.7274e-04 - val_loss: 7.5998e-04 - val_mse: 7.5998e-04
# Epoch 215/300
#
# Epoch 00215: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 9.8138e-04 - mse: 9.8138e-04 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 216/300
#
# Epoch 00216: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 9.3886e-04 - mse: 9.3886e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 217/300
#
# Epoch 00217: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 218/300
#
# Epoch 00218: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 0.0011 - mse: 0.0011 - val_loss: 8.9653e-05 - val_mse: 8.9653e-05
# Epoch 219/300
#
# Epoch 00219: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 0.0010 - mse: 0.0010 - val_loss: 1.6797e-04 - val_mse: 1.6797e-04
# Epoch 220/300
#
# Epoch 00220: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 221/300
#
# Epoch 00221: val_loss did not improve from 0.00005
# 7088/7088 - 18s - loss: 8.3343e-04 - mse: 8.3343e-04 - val_loss: 5.5122e-04 - val_mse: 5.5122e-04
# Epoch 222/300
#
# Epoch 00222: val_loss did not improve from 0.00005
# 7088/7088 - 20s - loss: 9.5971e-04 - mse: 9.5971e-04 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 223/300
#
# Epoch 00223: val_loss did not improve from 0.00005
# 7088/7088 - 18s - loss: 0.0010 - mse: 0.0010 - val_loss: 6.7140e-05 - val_mse: 6.7140e-05
# Epoch 224/300
#
# Epoch 00224: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 8.3067e-04 - mse: 8.3067e-04 - val_loss: 5.9014e-05 - val_mse: 5.9014e-05
# Epoch 225/300
#
# Epoch 00225: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 9.0165e-04 - mse: 9.0165e-04 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 226/300
#
# Epoch 00226: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 0.0011 - mse: 0.0011 - val_loss: 7.6292e-05 - val_mse: 7.6292e-05
# Epoch 227/300
#
# Epoch 00227: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 0.0011 - mse: 0.0011 - val_loss: 2.7613e-04 - val_mse: 2.7613e-04
# Epoch 228/300
#
# Epoch 00228: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 9.5849e-04 - mse: 9.5849e-04 - val_loss: 1.5815e-04 - val_mse: 1.5815e-04
# Epoch 229/300
#
# Epoch 00229: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 230/300
#
# Epoch 00230: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 8.7841e-04 - mse: 8.7841e-04 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 231/300
#
# Epoch 00231: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 9.9998e-04 - mse: 9.9998e-04 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 232/300
#
# Epoch 00232: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 9.7766e-04 - mse: 9.7766e-04 - val_loss: 5.2116e-04 - val_mse: 5.2116e-04
# Epoch 233/300
#
# Epoch 00233: val_loss did not improve from 0.00005
# 7088/7088 - 17s - loss: 0.0010 - mse: 0.0010 - val_loss: 1.8807e-04 - val_mse: 1.8807e-04
# Epoch 234/300
#
# Epoch 00234: val_loss did not improve from 0.00005
# 7088/7088 - 21s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 235/300
#
# Epoch 00235: val_loss did not improve from 0.00005
# 7088/7088 - 23s - loss: 9.8772e-04 - mse: 9.8772e-04 - val_loss: 8.6147e-05 - val_mse: 8.6147e-05
# Epoch 236/300
#
# Epoch 00236: val_loss did not improve from 0.00005
# 7088/7088 - 23s - loss: 8.7876e-04 - mse: 8.7876e-04 - val_loss: 1.2691e-04 - val_mse: 1.2691e-04
# Epoch 237/300
#
# Epoch 00237: val_loss did not improve from 0.00005
# 7088/7088 - 23s - loss: 9.5912e-04 - mse: 9.5912e-04 - val_loss: 3.4419e-04 - val_mse: 3.4419e-04
# Epoch 238/300
#
# Epoch 00238: val_loss improved from 0.00005 to 0.00005, saving model to saved_model/model_sma_NoVOL.h5
# 7088/7088 - 23s - loss: 0.0011 - mse: 0.0011 - val_loss: 4.9031e-05 - val_mse: 4.9031e-05
# Epoch 239/300
#
# Epoch 00239: val_loss did not improve from 0.00005
# 7088/7088 - 23s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 240/300
#
# Epoch 00240: val_loss did not improve from 0.00005
# 7088/7088 - 23s - loss: 9.3902e-04 - mse: 9.3902e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 241/300
#
# Epoch 00241: val_loss did not improve from 0.00005
# 7088/7088 - 24s - loss: 9.0400e-04 - mse: 9.0400e-04 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 242/300
#
# Epoch 00242: val_loss did not improve from 0.00005
# 7088/7088 - 23s - loss: 0.0011 - mse: 0.0011 - val_loss: 7.0130e-05 - val_mse: 7.0130e-05
# Epoch 243/300
#
# Epoch 00243: val_loss did not improve from 0.00005
# 7088/7088 - 23s - loss: 0.0011 - mse: 0.0011 - val_loss: 1.0952e-04 - val_mse: 1.0952e-04
# Epoch 244/300
#
# Epoch 00244: val_loss did not improve from 0.00005
# 7088/7088 - 23s - loss: 8.7840e-04 - mse: 8.7840e-04 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 245/300
#
# Epoch 00245: val_loss did not improve from 0.00005
# 7088/7088 - 22s - loss: 0.0010 - mse: 0.0010 - val_loss: 8.9662e-04 - val_mse: 8.9662e-04
# Epoch 246/300
#
# Epoch 00246: val_loss did not improve from 0.00005
# 7088/7088 - 23s - loss: 9.0183e-04 - mse: 9.0183e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 247/300
#
# Epoch 00247: val_loss did not improve from 0.00005
# 7088/7088 - 13s - loss: 7.5290e-04 - mse: 7.5290e-04 - val_loss: 8.9126e-05 - val_mse: 8.9126e-05
# Epoch 248/300
#
# Epoch 00248: val_loss did not improve from 0.00005
# 7088/7088 - 13s - loss: 9.9090e-04 - mse: 9.9090e-04 - val_loss: 5.1119e-05 - val_mse: 5.1119e-05
# Epoch 249/300
#
# Epoch 00249: val_loss did not improve from 0.00005
# 7088/7088 - 14s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 250/300
#
# Epoch 00250: val_loss did not improve from 0.00005
# 7088/7088 - 14s - loss: 0.0011 - mse: 0.0011 - val_loss: 3.0771e-04 - val_mse: 3.0771e-04
# Epoch 251/300
#
# Epoch 00251: val_loss did not improve from 0.00005
# 7088/7088 - 14s - loss: 9.7358e-04 - mse: 9.7358e-04 - val_loss: 1.3237e-04 - val_mse: 1.3237e-04
# Epoch 252/300
#
# Epoch 00252: val_loss did not improve from 0.00005
# 7088/7088 - 14s - loss: 9.4833e-04 - mse: 9.4833e-04 - val_loss: 3.3783e-04 - val_mse: 3.3783e-04
# Epoch 253/300
#
# Epoch 00253: val_loss did not improve from 0.00005
# 7088/7088 - 14s - loss: 8.8793e-04 - mse: 8.8793e-04 - val_loss: 1.9164e-04 - val_mse: 1.9164e-04
# Epoch 254/300
#
# Epoch 00254: val_loss did not improve from 0.00005
# 7088/7088 - 14s - loss: 8.6859e-04 - mse: 8.6859e-04 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 255/300
#
# Epoch 00255: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 9.5371e-04 - mse: 9.5371e-04 - val_loss: 2.7150e-04 - val_mse: 2.7150e-04
# Epoch 256/300
#
# Epoch 00256: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 9.2598e-04 - mse: 9.2598e-04 - val_loss: 9.9522e-05 - val_mse: 9.9522e-05
# Epoch 257/300
#
# Epoch 00257: val_loss did not improve from 0.00005
# 7088/7088 - 17s - loss: 9.4378e-04 - mse: 9.4378e-04 - val_loss: 3.4845e-04 - val_mse: 3.4845e-04
# Epoch 258/300
#
# Epoch 00258: val_loss did not improve from 0.00005
# 7088/7088 - 17s - loss: 9.9296e-04 - mse: 9.9296e-04 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 259/300
#
# Epoch 00259: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 8.5113e-04 - mse: 8.5113e-04 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 260/300
#
# Epoch 00260: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 261/300
#
# Epoch 00261: val_loss did not improve from 0.00005
# 7088/7088 - 17s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0086 - val_mse: 0.0086
# Epoch 262/300
#
# Epoch 00262: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 8.7748e-04 - mse: 8.7748e-04 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 263/300
#
# Epoch 00263: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 264/300
#
# Epoch 00264: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 9.3483e-04 - mse: 9.3483e-04 - val_loss: 5.0529e-04 - val_mse: 5.0529e-04
# Epoch 265/300
#
# Epoch 00265: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 266/300
#
# Epoch 00266: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 267/300
#
# Epoch 00267: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 0.0010 - mse: 0.0010 - val_loss: 1.7527e-04 - val_mse: 1.7527e-04
# Epoch 268/300
#
# Epoch 00268: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 9.9937e-04 - mse: 9.9937e-04 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 269/300
#
# Epoch 00269: val_loss did not improve from 0.00005
# 7088/7088 - 17s - loss: 0.0010 - mse: 0.0010 - val_loss: 7.4501e-05 - val_mse: 7.4501e-05
# Epoch 270/300
#
# Epoch 00270: val_loss did not improve from 0.00005
# 7088/7088 - 17s - loss: 0.0010 - mse: 0.0010 - val_loss: 7.1545e-04 - val_mse: 7.1545e-04
# Epoch 271/300
#
# Epoch 00271: val_loss did not improve from 0.00005
# 7088/7088 - 17s - loss: 9.2749e-04 - mse: 9.2749e-04 - val_loss: 2.9138e-04 - val_mse: 2.9138e-04
# Epoch 272/300
#
# Epoch 00272: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 9.8998e-04 - mse: 9.8998e-04 - val_loss: 1.3101e-04 - val_mse: 1.3101e-04
# Epoch 273/300
#
# Epoch 00273: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 9.4260e-04 - mse: 9.4260e-04 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 274/300
#
# Epoch 00274: val_loss did not improve from 0.00005
# 7088/7088 - 17s - loss: 9.7936e-04 - mse: 9.7936e-04 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 275/300
#
# Epoch 00275: val_loss did not improve from 0.00005
# 7088/7088 - 17s - loss: 9.9134e-04 - mse: 9.9134e-04 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 276/300
#
# Epoch 00276: val_loss did not improve from 0.00005
# 7088/7088 - 17s - loss: 9.0708e-04 - mse: 9.0708e-04 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 277/300
#
# Epoch 00277: val_loss did not improve from 0.00005
# 7088/7088 - 17s - loss: 9.0091e-04 - mse: 9.0091e-04 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 278/300
#
# Epoch 00278: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 8.4114e-04 - mse: 8.4114e-04 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 279/300
#
# Epoch 00279: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 0.0010 - mse: 0.0010 - val_loss: 1.5719e-04 - val_mse: 1.5719e-04
# Epoch 280/300
#
# Epoch 00280: val_loss did not improve from 0.00005
# 7088/7088 - 17s - loss: 7.8551e-04 - mse: 7.8551e-04 - val_loss: 1.5617e-04 - val_mse: 1.5617e-04
# Epoch 281/300
#
# Epoch 00281: val_loss did not improve from 0.00005
# 7088/7088 - 17s - loss: 9.3067e-04 - mse: 9.3067e-04 - val_loss: 6.0629e-04 - val_mse: 6.0629e-04
# Epoch 282/300
#
# Epoch 00282: val_loss did not improve from 0.00005
# 7088/7088 - 17s - loss: 8.5148e-04 - mse: 8.5148e-04 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 283/300
#
# Epoch 00283: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 9.2309e-04 - mse: 9.2309e-04 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 284/300
#
# Epoch 00284: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 9.9874e-04 - mse: 9.9874e-04 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 285/300
#
# Epoch 00285: val_loss did not improve from 0.00005
# 7088/7088 - 17s - loss: 9.2119e-04 - mse: 9.2119e-04 - val_loss: 3.4921e-04 - val_mse: 3.4921e-04
# Epoch 286/300
#
# Epoch 00286: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 9.8567e-04 - mse: 9.8567e-04 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 287/300
#
# Epoch 00287: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 9.4569e-04 - mse: 9.4569e-04 - val_loss: 9.2509e-05 - val_mse: 9.2509e-05
# Epoch 288/300
#
# Epoch 00288: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 9.5845e-04 - mse: 9.5845e-04 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 289/300
#
# Epoch 00289: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 9.5077e-04 - mse: 9.5077e-04 - val_loss: 1.1824e-04 - val_mse: 1.1824e-04
# Epoch 290/300
#
# Epoch 00290: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 291/300
#
# Epoch 00291: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 9.5673e-04 - mse: 9.5673e-04 - val_loss: 1.2180e-04 - val_mse: 1.2180e-04
# Epoch 292/300
#
# Epoch 00292: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 293/300
#
# Epoch 00293: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 9.8835e-04 - mse: 9.8835e-04 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 294/300
#
# Epoch 00294: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 8.9311e-04 - mse: 8.9311e-04 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 295/300
#
# Epoch 00295: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 0.0010 - mse: 0.0010 - val_loss: 3.8341e-04 - val_mse: 3.8341e-04
# Epoch 296/300
#
# Epoch 00296: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 297/300
#
# Epoch 00297: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 0.0010 - mse: 0.0010 - val_loss: 5.7294e-04 - val_mse: 5.7294e-04
# Epoch 298/300
#
# Epoch 00298: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 9.0945e-04 - mse: 9.0945e-04 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 299/300
#
# Epoch 00299: val_loss did not improve from 0.00005
# 7088/7088 - 16s - loss: 8.0780e-04 - mse: 8.0780e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 300/300
#
# Epoch 00300: val_loss did not improve from 0.00005
# 7088/7088 - 15s - loss: 9.0041e-04 - mse: 9.0041e-04 - val_loss: 0.0016 - val_mse: 0.0016

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'mse', 'val_loss', 'val_mse', 'lr'])

# %%
plt.title("loss and epochs")
plt.plot(history.history['loss'],color = 'blue',label="train_loss")
plt.plot(history.history['val_loss'],color = 'red',label="val_loss")
plt.xlabel("epochs")
plt.ylabel("loss")
# Out:
# Text(0, 0.5, 'loss')

# %%
#Load the minimum loss weight 
model = get_bi_gru()
model.load_weights("./saved_model/model_sma_NoVOL.h5")

# %%
# Load saved model 
#from tensorflow.keras.models import load_model
#model = load_model("path")

# %%
model.save("best_nikkie_noFE.h5")

# %%
x_train.shape
y_train.shape
# Out:
# (7088, 4)

# %%
y_train_pred = model.predict(x_train)
y_val_pred = model.predict(x_val)
y_test_pred = model.predict(x_test)

# %%
print(y_test_pred[0])
# Out:
# [0.31133738 0.30746952 0.30576375 0.3131474 ]

# %%
print( y_test_pred[:, 1][0])
# Out:
# 0.30746952

# %%
def plot_compare(x):
    Col = {'Open':0, 'High':1, 'Low':2, 'Close':3, 'sma5':4, 'sma10':5, 'sma25':6, 'sma75':7, 'sma125':8, 'sma200':9}
    ft = Col[x]
    plt.figure(figsize=(15, 5))
    plt.subplot(1, 2, 1)

    plt.plot(np.arange(y_train.shape[0]), y_train[:, ft], color='blue', label='train target')

    plt.plot(np.arange(y_train.shape[0], y_train.shape[0] + y_val.shape[0]), y_val[:, ft], 
             color='gray', label='val target')
    plt.plot(np.arange(y_train.shape[0] + y_val.shape[0], y_train.shape[0] + y_val.shape[0] + y_test.shape[0]),
            y_test[:, ft], color='black', label='test target')
    plt.plot(np.arange(y_train_pred.shape[0]), y_train_pred[:, ft],
            color='red', label='train prediction') 
    plt.plot(np.arange(y_train_pred.shape[0], y_train_pred.shape[0] + y_val_pred.shape[0]),
            y_val_pred[:, ft], color='orange', label='val prediction')
    plt.plot(np.arange(y_train_pred.shape[0] + y_val_pred.shape[0],
            y_train_pred.shape[0] + y_val_pred.shape[0] + y_test_pred.shape[0]),
            y_test_pred[:, ft], color ='green', label='test prediction')
    plt.title('past and future stock price')
    plt.xlabel('Time [Days]')
    plt.ylabel('Normalized price')
    plt.legend(loc='best')

    plt.subplot(1, 2, 2)
    plt.plot(np.arange(y_train.shape[0], y_train.shape[0] + y_test.shape[0]),
            y_test[:, ft], color='black', label='test target')
    plt.plot(np.arange(y_train.shape[0], y_train.shape[0] + y_test_pred.shape[0]),
            y_test_pred[:, ft], color='green', label='test prediction')
    plt.title('future stock prices '+x)
    plt.xlabel('Time [Days]')
    plt.ylabel('Normalized price')
    plt.legend(loc='best')

# %%
plot_compare('Close')

# %%
#model.save("saved_model/best_one.h")

# %%
model.evaluate(x_test,y_test)
# Out:
# 874/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.0003306825029358984, 0.00033068255]
