# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

import tensorflow as tf
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model, Sequential

# %%
os.listdir('./data')
# Out:
# ['DJI_fe.csv',
#  'DJI_STO_20period_sma10.csv',
#  'N225.csv',
#  'DJI_modified_features - DJI.csv',
#  'N225fillVOL.csv',
#  'DJI_modified_sma.csv',
#  'downjone5y.csv',
#  'N225withoutNULL.csv',
#  'dowjone1985_2019.csv',
#  '.ipynb_checkpoints',
#  'DJI_ema.csv',
#  'DJI_denoise.csv']

# %%
df = pd.read_csv('./data/DJI_fe.csv')
df = df.drop('Unnamed: 0', axis=1)
df = df.drop('Unnamed: 0.1', axis=1)

df.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  1985-01-29  1277.719971  1295.489990  1266.890015  1292.619995
# 1  1985-01-30  1297.369995  1305.099976  1278.930054  1287.880005
# 2  1985-01-31  1283.239990  1293.400024  1272.640015  1286.770020
# 3  1985-02-01  1276.939941  1286.109985  1269.770020  1277.719971
# 4  1985-02-04  1272.079956  1294.939941  1268.989990  1290.079956
#
#      Adj Close    Volume        sma_5  sma_10  sma_25  ...  sma_125  sma_200  \
# 0  1292.619995  13560000          NaN     NaN     NaN  ...      NaN      NaN
# 1  1287.880005  16820000          NaN     NaN     NaN  ...      NaN      NaN
# 2  1286.770020  14070000          NaN     NaN     NaN  ...      NaN      NaN
# 3  1277.719971  10980000          NaN     NaN     NaN  ...      NaN      NaN
# 4  1290.079956  11630000  1287.013989     NaN     NaN  ...      NaN      NaN
#
#    %K  %D        ema_5       ema_10       ema_25       ema_75      ema_125  \
# 0 NaN NaN  1292.619995  1292.619995  1292.619995  1292.619995  1292.619995
# 1 NaN NaN  1291.039998  1291.758179  1292.255380  1292.495258  1292.544757
# 2 NaN NaN  1289.616672  1290.851241  1291.833430  1292.344594  1292.453095
# 3 NaN NaN  1285.651105  1288.463737  1290.747779  1291.959736  1292.219235
# 4 NaN NaN  1287.127389  1288.757595  1290.696408  1291.910268  1292.185279
#
#        ema_200
# 0  1292.619995
# 1  1292.572831
# 2  1292.515092
# 3  1292.367876
# 4  1292.345111
#
# [5 rows x 21 columns]
