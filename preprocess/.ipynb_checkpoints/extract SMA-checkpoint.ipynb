# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
os.listdir('../data')
# Out:
# ['DJI_ema.csv',
#  'DJI_STO_20period_sma10.csv',
#  'DJI_modified_sma.csv',
#  '.DS_Store',
#  'DJI_modified_features - DJI.csv',
#  'DJI_fe.csv',
#  'N225withoutNULL.csv',
#  'dowjone1985_2019.csv',
#  'N225fillVOL.csv',
#  'test_djia.csv',
#  'DJI_denoise.csv',
#  'N225.csv',
#  'stocknews',
#  'preprocessed',
#  'downjone5y.csv']

# %%
df = pd.read_csv('../data/N225withoutNULL.csv')

# %%
windows = [5, 10, 25, 75, 125, 200]
for window in windows:
    df['sma_' + str(window)] = df['Close'].rolling(window=window).mean()

# %%
cols = ['Close']
for window in windows:
    cols.append('sma_' + str(window))
df.plot(y=cols)

# %%
df.to_csv('../data/nk_fe.csv', index=False)
